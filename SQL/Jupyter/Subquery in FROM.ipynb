# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Subquery in FROM

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Description

# %% [markdown]
# In this lesson we will use a subquery like a temporary table, meaning we will do a calculation, and then reference the result of that calculation in another query.

# %% [markdown]
# ## Learning objectives
#
# In this train we will learn:
# - How to create a query using the FROM clause.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table in our `united_nations` database we created in MySQL Workbench, we want to answer some questions about our dataset. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.
#
# Note that before, for this tutorial, we will already have worked through the lessons where the `united_nations.Basic_Services` table, `united_nations.Economic_Indicators` table, and the `united_nations.Geographic_Locations` table have been created.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:WangilaP%400911@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line then the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %%
# %%sql
# SELECT
#     *
# FROM
#     Economic_indicators;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Afghanistan', 2015, 20, 34, None),
#  ('Afghanistan', 2016, 18, 35, None),
#  ('Afghanistan', 2017, 19, 36, 11),
#  ('Afghanistan', 2018, 18, 37, None),
#  ('Afghanistan', 2019, 19, 38, None),
#  ('Afghanistan', 2020, 20, 39, 12),
#  ('Algeria', 2015, 166, 40, 11),
#  ('Algeria', 2016, 160, 40, 10),
#  ('Algeria', 2017, 170, 41, 12),
#  ('Algeria', 2018, 175, 42, None),
#  ('Algeria', 2019, 172, 43, None),
#  ('Algeria', 2020, 145, 43, None),
#  ('American Samoa', 2015, 1, 0, None),
#  ('American Samoa', 2016, 1, 0, None),
#  ('American Samoa', 2017, 1, 0, None),
#  ('American Samoa', 2018, 1, 0, None),
#  ('American Samoa', 2019, 1, 0, None),
#  ('American Samoa', 2020, 1, 0, None),
#  ('Angola', 2015, 87, 28, None),
#  ('Angola', 2016, 50, 29, None),
#  ('Angola', 2017, 69, 30, None),
#  ('Angola', 2018, 78, 31, None),
#  ('Angola', 2019, 69, 32, 17),
#  ('Angola', 2020, 54, 33, None),
#  ('Anguilla', 2015, None, None, None),
#  ('Anguilla', 2016, None, None, None),
#  ('Anguilla', 2017, None, None, None),
#  ('Antigua and Barbuda', 2015, 1, 0, None),
#  ('Antigua and Barbuda', 2016, 1, 0, None),
#  ('Antigua and Barbuda', 2017, 1, 0, None),
#  ('Argentina', 2015, 595, 43, None),
#  ('Argentina', 2016, 558, 44, None),
#  ('Argentina', 2017, 644, 44, 8),
#  ('Argentina', 2018, 525, 44, 9),
#  ('Argentina', 2019, 448, 45, 10),
#  ('Argentina', 2020, 386, 45, 11),
#  ('Armenia', 2015, 11, 3, 18),
#  ('Armenia', 2016, 11, 3, 18),
#  ('Armenia', 2017, 12, 3, 18),
#  ('Armenia', 2018, 12, 3, 13),
#  ('Armenia', 2019, 14, 3, 12),
#  ('Armenia', 2020, 13, 3, 12),
#  ('Aruba', 2015, 3, 0, None),
#  ('Aruba', 2016, 3, 0, None),
#  ('Australia', 2015, 1351, 24, 6),
#  ('Australia', 2016, 1207, 24, 6),
#  ('Australia', 2017, 1327, 25, 6),
#  ('Australia', 2018, 1428, 25, 5),
#  ('Australia', 2019, 1392, 25, 5),
#  ('Australia', 2020, 1327, 26, 6),
#  ('Azerbaijan', 2015, 53, 10, 5),
#  ('Azerbaijan', 2016, 38, 10, 5),
#  ('Azerbaijan', 2017, 41, 10, 5),
#  ('Azerbaijan', 2018, 47, 10, 5),
#  ('Azerbaijan', 2019, 48, 10, 5),
#  ('Azerbaijan', 2020, 43, 10, 7),
#  ('Bahamas', 2015, None, None, None),
#  ('Bahamas', 2016, None, None, None),
#  ('Bahamas', 2017, None, None, None),
#  ('Bahamas', 2018, None, None, None),
#  ('Bahamas', 2019, None, None, None),
#  ('Bahrain', 2015, 31, 1, None),
#  ('Bahrain', 2016, 32, 1, None),
#  ('Bahrain', 2017, 35, 1, None),
#  ('Bahrain', 2018, 38, 1, None),
#  ('Bahrain', 2019, 39, 1, None),
#  ('Bahrain', 2020, 35, 1, None),
#  ('Bangladesh', 2015, 195, 158, None),
#  ('Bangladesh', 2016, 265, 160, 4),
#  ('Bangladesh', 2017, 294, 162, 4),
#  ('Bangladesh', 2018, 321, 164, None),
#  ('Bangladesh', 2019, 351, 166, None),
#  ('Bangladesh', 2020, 374, 167, None),
#  ('Barbados', 2015, 5, 0, 10),
#  ('Barbados', 2016, 5, 0, 8),
#  ('Barbados', 2017, 5, 0, 9),
#  ('Barbados', 2018, 5, 0, 8),
#  ('Barbados', 2019, 5, 0, 8),
#  ('Barbados', 2020, 5, 0, None),
#  ('Belize', 2015, 2, 0, 8),
#  ('Belize', 2016, 2, 0, 7),
#  ('Belize', 2017, 2, 0, 7),
#  ('Belize', 2018, 2, 0, None),
#  ('Belize', 2019, 2, 0, 9),
#  ('Belize', 2020, 2, 0, None),
#  ('Benin', 2015, 11, 11, None),
#  ('Benin', 2016, 12, 11, None),
#  ('Benin', 2017, 13, 12, None),
#  ('Benin', 2018, 14, 12, 1),
#  ('Benin', 2019, 14, 12, None),
#  ('Benin', 2020, 16, 13, None),
#  ('Bermuda', 2015, 7, 0, None),
#  ('Bermuda', 2016, 7, 0, None),
#  ('Bermuda', 2017, 7, 0, None),
#  ('Bermuda', 2018, 7, 0, None),
#  ('Bermuda', 2019, 7, 0, None),
#  ('Bermuda', 2020, 7, 0, None),
#  ('Bhutan', 2015, 2, 1, 2),
#  ('Bhutan', 2016, 2, 1, None),
#  ('Bhutan', 2017, 2, 1, None),
#  ('Bhutan', 2018, 2, 1, 3),
#  ('Bhutan', 2019, 3, 1, 3),
#  ('Bhutan', 2020, 2, 1, 5),
#  ('Bolivia (Plurinational State of)', 2015, None, None, None),
#  ('Bolivia (Plurinational State of)', 2016, None, None, None),
#  ('Bolivia (Plurinational State of)', 2017, None, None, None),
#  ('Bolivia (Plurinational State of)', 2018, None, None, None),
#  ('Bolivia (Plurinational State of)', 2019, None, None, None),
#  ('Bolivia (Plurinational State of)', 2020, None, None, None),
#  ('Botswana', 2015, 14, 2, None),
#  ('Botswana', 2016, 15, 2, None),
#  ('Botswana', 2017, 16, 2, None),
#  ('Botswana', 2018, 17, 2, None),
#  ('Botswana', 2019, 17, 2, 20),
#  ('Botswana', 2020, 15, 3, 21),
#  ('Brazil', 2015, 1802, 205, 9),
#  ('Brazil', 2016, 1796, 207, 12),
#  ('Brazil', 2017, 2064, 209, 13),
#  ('Brazil', 2018, 1917, 210, 12),
#  ('Brazil', 2019, 1873, 212, 12),
#  ('Brazil', 2020, 1449, 213, 14),
#  ('British Virgin Islands', 2015, None, 0, None),
#  ('British Virgin Islands', 2016, None, 0, None),
#  ('British Virgin Islands', 2017, None, 0, None),
#  ('British Virgin Islands', 2018, None, 0, None),
#  ('British Virgin Islands', 2019, None, 0, None),
#  ('British Virgin Islands', 2020, None, 0, None),
#  ('Brunei Darussalam', 2015, 13, 0, None),
#  ('Brunei Darussalam', 2016, 11, 0, None),
#  ('Brunei Darussalam', 2017, 12, 0, 9),
#  ('Brunei Darussalam', 2018, 14, 0, 9),
#  ('Brunei Darussalam', 2019, 13, 0, 7),
#  ('Brunei Darussalam', 2020, 12, 0, 7),
#  ('Burkina Faso', 2015, 12, 19, None),
#  ('Burkina Faso', 2016, 13, 19, None),
#  ('Burkina Faso', 2017, 14, 20, None),
#  ('Burkina Faso', 2018, 16, 20, 5),
#  ('Burkina Faso', 2019, 16, 21, None),
#  ('Burkina Faso', 2020, 18, 22, None),
#  ('Burundi', 2015, 3, 11, None),
#  ('Burundi', 2016, 3, 11, None),
#  ('Burundi', 2017, 3, 11, None),
#  ('Burundi', 2018, 3, 11, None),
#  ('Burundi', 2019, 3, 12, None),
#  ('Burundi', 2020, 3, 12, 1),
#  ('Cabo Verde', 2015, 2, 1, 31),
#  ('Cabo Verde', 2016, 2, 1, None),
#  ('Cabo Verde', 2017, 2, 1, 12),
#  ('Cabo Verde', 2018, 2, 1, 12),
#  ('Cabo Verde', 2019, 2, 1, 11),
#  ('Cabo Verde', 2020, 2, 1, None),
#  ('Cambodia', 2015, 18, 15, 0),
#  ('Cambodia', 2016, 20, 16, 1),
#  ('Cambodia', 2017, 22, 16, 0),
#  ('Cambodia', 2018, 25, 16, None),
#  ('Cambodia', 2019, 27, 16, 1),
#  ('Cambodia', 2020, 26, 16, None),
#  ('Cameroon', 2015, 32, 23, None),
#  ('Cameroon', 2016, 34, 24, None),
#  ('Cameroon', 2017, 36, 24, None),
#  ('Cameroon', 2018, 40, 25, None),
#  ('Cameroon', 2019, 40, 26, None),
#  ('Cameroon', 2020, 41, 26, None),
#  ('Canada', 2015, 1557, 36, 7),
#  ('Canada', 2016, 1528, 36, 7),
#  ('Canada', 2017, 1649, 37, 6),
#  ('Canada', 2018, 1725, 37, 6),
#  ('Canada', 2019, 1742, 38, 6),
#  ('Canada', 2020, 1645, 38, 9),
#  ('Cayman Islands', 2015, 5, 0, 4),
#  ('Cayman Islands', 2016, 5, 0, None),
#  ('Central African Republic', 2015, 2, 5, None),
#  ('Central African Republic', 2016, 2, 5, None),
#  ('Central African Republic', 2017, 2, 5, None),
#  ('Central African Republic', 2018, 2, 5, None),
#  ('Central African Republic', 2019, 2, 5, None),
#  ('Central African Republic', 2020, 2, 5, None),
#  ('Chad', 2015, 11, 14, None),
#  ('Chad', 2016, 10, 15, None),
#  ('Chad', 2017, 10, 15, None),
#  ('Chad', 2018, 11, 16, 1),
#  ('Chad', 2019, 11, 16, None),
#  ('Chad', 2020, 11, 17, None),
#  ('Chile', 2015, 243, 18, 6),
#  ('Chile', 2016, 249, 18, 7),
#  ('Chile', 2017, 276, 18, 7),
#  ('Chile', 2018, 295, 19, 7),
#  ('Chile', 2019, 279, 19, 7),
#  ('Chile', 2020, 253, 19, 11),
#  ('China', 2015, 11062, 1380, None),
#  ('China', 2016, 11233, 1388, None),
#  ('China', 2017, 12310, 1396, 4),
#  ('China', 2018, 13895, 1403, 5),
#  ('China', 2019, 14280, 1408, 5),
#  ('China', 2020, 14688, 1411, 6),
#  ('Colombia', 2015, 293, 47, 9),
#  ('Colombia', 2016, 283, 48, 9),
#  ('Colombia', 2017, 312, 48, 9),
#  ('Colombia', 2018, 334, 49, 9),
#  ('Colombia', 2019, 323, 50, 10),
#  ('Colombia', 2020, 270, 51, 16),
#  ('Comoros', 2015, 1, 1, None),
#  ('Comoros', 2016, 1, 1, None),
#  ('Comoros', 2017, 1, 1, None),
#  ('Comoros', 2018, 1, 1, None),
#  ('Comoros', 2019, 1, 1, None),
#  ('Congo', 2015, None, None, None),
#  ('Congo', 2016, None, None, None),
#  ('Congo', 2017, None, None, None),
#  ('Congo', 2018, None, None, None),
#  ('Congo', 2019, None, None, None),
#  ('Congo', 2020, None, None, None),
#  ('Cook Islands', 2015, None, None, None),
#  ('Cook Islands', 2016, None, None, None),
#  ('Cook Islands', 2017, None, None, None),
#  ('Cook Islands', 2018, None, None, None),
#  ('Cook Islands', 2019, None, None, None),
#  ('Cook Islands', 2020, None, None, None),
#  ('Costa Rica', 2015, 56, 5, 8),
#  ('Costa Rica', 2016, 59, 5, 8),
#  ('Costa Rica', 2017, 61, 5, 8),
#  ('Costa Rica', 2018, 62, 5, 9),
#  ('Costa Rica', 2019, 64, 5, 11),
#  ('Costa Rica', 2020, 62, 5, 16),
#  ("Côte d'Ivoire", 2015, None, None, None),
#  ("Côte d'Ivoire", 2016, None, None, None),
#  ("Côte d'Ivoire", 2017, None, None, None),
#  ("Côte d'Ivoire", 2018, None, None, None),
#  ("Côte d'Ivoire", 2019, None, None, None),
#  ("Côte d'Ivoire", 2020, None, None, None),
#  ('Cuba', 2015, 87, 11, 2),
#  ('Cuba', 2016, 91, 11, 2),
#  ('Cuba', 2017, 97, 11, 2),
#  ('Cuba', 2018, 100, 11, 2),
#  ('Cuba', 2019, 103, 11, None),
#  ('Cuba', 2020, 107, 11, None),
#  ('Curaçao', 2015, None, None, None),
#  ('Curaçao', 2016, None, None, None),
#  ('Curaçao', 2017, None, None, None),
#  ('Cyprus', 2015, 20, 1, 15),
#  ('Cyprus', 2016, 21, 1, 13),
#  ('Cyprus', 2017, 23, 1, 11),
#  ('Cyprus', 2018, 26, 1, 9),
#  ('Cyprus', 2019, 26, 1, 7),
#  ('Cyprus', 2020, 25, 1, 8),
#  ("Democratic People's Republic of Korea", 2015, None, None, None),
#  ("Democratic People's Republic of Korea", 2016, None, None, None),
#  ("Democratic People's Republic of Korea", 2017, None, None, None),
#  ("Democratic People's Republic of Korea", 2018, None, None, None),
#  ("Democratic People's Republic of Korea", 2019, None, None, None),
#  ("Democratic People's Republic of Korea", 2020, None, None, None),
#  ('Democratic Republic of the Congo', 2015, None, None, None),
#  ('Democratic Republic of the Congo', 2016, None, None, None),
#  ('Democratic Republic of the Congo', 2017, None, None, None),
#  ('Democratic Republic of the Congo', 2018, None, None, None),
#  ('Democratic Republic of the Congo', 2019, None, None, None),
#  ('Democratic Republic of the Congo', 2020, None, None, None),
#  ('Djibouti', 2015, 2, 1, None),
#  ('Djibouti', 2016, 3, 1, None),
#  ('Djibouti', 2017, 3, 1, 26),
#  ('Djibouti', 2018, 3, 1, None),
#  ('Djibouti', 2019, 3, 1, None),
#  ('Djibouti', 2020, 3, 1, None),
#  ('Dominica', 2015, 1, 0, None),
#  ('Dominica', 2016, 1, 0, None),
#  ('Dominica', 2017, 1, 0, None),
#  ('Dominican Republic', 2015, 71, 10, 8),
#  ('Dominican Republic', 2016, 76, 11, 7),
#  ('Dominican Republic', 2017, 80, 11, 6),
#  ('Dominican Republic', 2018, 86, 11, 6),
#  ('Dominican Republic', 2019, 89, 11, 6),
#  ('Dominican Republic', 2020, 79, 11, 6),
#  ('Ecuador', 2015, 99, 16, 4),
#  ('Ecuador', 2016, 100, 16, 5),
#  ('Ecuador', 2017, 104, 17, 4),
#  ('Ecuador', 2018, 108, 17, 4),
#  ('Ecuador', 2019, 108, 17, 4),
#  ('Ecuador', 2020, 99, 18, 6),
#  ('Egypt', 2015, None, None, None),
#  ('Egypt', 2016, None, None, None),
#  ('Egypt', 2017, None, None, None),
#  ('Egypt', 2018, None, None, None),
#  ('Egypt', 2019, None, None, None),
#  ('Egypt', 2020, None, None, None),
#  ('El Salvador', 2015, 23, 6, 4),
#  ('El Salvador', 2016, 24, 6, 4),
#  ('El Salvador', 2017, 25, 6, 4),
#  ('El Salvador', 2018, 26, 6, 4),
#  ('El Salvador', 2019, 27, 6, 4),
#  ('El Salvador', 2020, 25, 6, 5),
#  ('Equatorial Guinea', 2015, 13, 1, None),
#  ('Equatorial Guinea', 2016, 11, 1, None),
#  ('Equatorial Guinea', 2017, 12, 1, None),
#  ('Eritrea', 2015, None, 3, None),
#  ('Eritrea', 2016, None, 3, None),
#  ('Eswatini', 2015, 4, 1, None),
#  ('Eswatini', 2016, 4, 1, 23),
#  ('Eswatini', 2017, 4, 1, None),
#  ('Eswatini', 2018, 5, 1, None),
#  ('Eswatini', 2019, 5, 1, None),
#  ('Eswatini', 2020, 4, 1, None),
#  ('Ethiopia', 2015, 65, 102, None),
#  ('Ethiopia', 2016, 74, 105, None),
#  ('Ethiopia', 2017, 82, 108, None),
#  ('Ethiopia', 2018, 84, 111, None),
#  ('Ethiopia', 2019, 96, 114, None),
#  ('Ethiopia', 2020, 108, 117, None),
#  ('Falkland Islands (Malvinas)', 2015, None, None, None),
#  ('Falkland Islands (Malvinas)', 2016, None, None, None),
#  ('Falkland Islands (Malvinas)', 2017, None, None, None),
#  ('Falkland Islands (Malvinas)', 2018, None, None, None),
#  ('Falkland Islands (Malvinas)', 2019, None, None, None),
#  ('Falkland Islands (Malvinas)', 2020, None, None, None),
#  ('Fiji', 2015, 5, 1, None),
#  ('Fiji', 2016, 5, 1, 4),
#  ('Fiji', 2017, 5, 1, None),
#  ('Fiji', 2018, 6, 1, None),
#  ('Fiji', 2019, 5, 1, None),
#  ('Fiji', 2020, 4, 1, None),
#  ('French Guiana', 2015, None, None, None),
#  ('French Guiana', 2016, None, None, None),
#  ('French Guiana', 2017, None, None, None),
#  ('French Guiana', 2018, None, None, None),
#  ('French Guiana', 2019, None, None, None),
#  ('French Guiana', 2020, None, None, None),
#  ('French Polynesia', 2015, 5, 0, None),
#  ('French Polynesia', 2016, 6, 0, None),
#  ('French Polynesia', 2017, 6, 0, None),
#  ('French Polynesia', 2018, 6, 0, None),
#  ('French Polynesia', 2019, 6, 0, None),
#  ('French Polynesia', 2020, 6, 0, None),
#  ('Gabon', 2015, 14, 2, None),
#  ('Gabon', 2016, 14, 2, None),
#  ('Gabon', 2017, 15, 2, None),
#  ('Gabon', 2018, 17, 2, None),
#  ('Gabon', 2019, 17, 2, None),
#  ('Gabon', 2020, 15, 2, None),
#  ('Gambia', 2015, None, None, None),
#  ('Gambia', 2016, None, None, None),
#  ('Gambia', 2017, None, None, None),
#  ('Gambia', 2018, None, None, None),
#  ('Gambia', 2019, None, None, None),
#  ('Gambia', 2020, None, None, None),
#  ('Georgia', 2015, 15, 4, 17),
#  ('Georgia', 2016, 15, 4, 17),
#  ('Georgia', 2017, 16, 4, 14),
#  ('Georgia', 2018, 18, 4, 13),
#  ('Georgia', 2019, 17, 4, 12),
#  ('Georgia', 2020, 16, 4, 12),
#  ('Ghana', 2015, 49, 29, 7),
#  ('Ghana', 2016, 56, 30, None),
#  ('Ghana', 2017, 60, 30, 3),
#  ('Ghana', 2018, 67, 31, None),
#  ('Ghana', 2019, 68, 32, None),
#  ('Ghana', 2020, 70, 32, None),
#  ('Greenland', 2015, 3, 0, 9),
#  ('Greenland', 2016, 3, 0, None),
#  ('Greenland', 2017, 3, 0, None),
#  ('Greenland', 2018, 3, 0, None),
#  ('Greenland', 2019, 3, 0, None),
#  ('Greenland', 2020, 3, 0, None),
#  ('Grenada', 2015, 1, 0, 23),
#  ('Grenada', 2016, 1, 0, None),
#  ('Grenada', 2017, 1, 0, None),
#  ('Guadeloupe', 2015, None, None, None),
#  ('Guadeloupe', 2016, None, None, None),
#  ('Guadeloupe', 2017, None, None, None),
#  ('Guadeloupe', 2018, None, None, None),
#  ('Guadeloupe', 2019, None, None, None),
#  ('Guadeloupe', 2020, None, None, None),
#  ('Guam', 2015, 6, 0, 7),
#  ('Guam', 2016, 6, 0, 5),
#  ('Guam', 2017, 6, 0, None),
#  ('Guam', 2018, 6, 0, None),
#  ('Guam', 2019, 6, 0, None),
#  ('Guam', 2020, 6, 0, None),
#  ('Guatemala', 2015, 62, 16, 3),
#  ('Guatemala', 2016, 66, 16, 3),
#  ('Guatemala', 2017, 72, 16, 2),
#  ('Guatemala', 2018, 73, 16, 2),
#  ('Guatemala', 2019, 77, 17, 2),
#  ('Guatemala', 2020, 78, 17, None),
#  ('Guinea', 2015, 9, 12, None),
#  ('Guinea', 2016, 9, 12, None),
#  ('Guinea', 2017, 10, 12, None),
#  ('Guinea', 2018, 12, 13, None),
#  ('Guinea', 2019, 13, 13, 5),
#  ('Guinea', 2020, 14, 13, None),
#  ('Guinea-Bissau', 2015, 1, 2, None),
#  ('Guinea-Bissau', 2016, 1, 2, None),
#  ('Guinea-Bissau', 2017, 1, 2, None),
#  ('Guinea-Bissau', 2018, 2, 2, 3),
#  ('Guinea-Bissau', 2019, 1, 2, None),
#  ('Guinea-Bissau', 2020, 1, 2, None),
#  ('Guyana', 2015, 4, 1, None),
#  ('Guyana', 2016, 4, 1, None),
#  ('Guyana', 2017, 5, 1, None),
#  ('Guyana', 2018, 5, 1, 14),
#  ('Guyana', 2019, 5, 1, 14),
#  ('Guyana', 2020, 5, 1, None),
#  ('Haiti', 2015, 15, 11, None),
#  ('Haiti', 2016, 14, 11, None),
#  ('Haiti', 2017, 15, 11, None),
#  ('Haiti', 2018, 16, 11, None),
#  ('Haiti', 2019, 15, 11, None),
#  ('Haiti', 2020, 15, 11, None),
#  ('Honduras', 2015, 21, 9, 6),
#  ('Honduras', 2016, 22, 9, 7),
#  ('Honduras', 2017, 23, 10, 6),
#  ('Honduras', 2018, 24, 10, 6),
#  ('Honduras', 2019, 25, 10, 6),
#  ('Honduras', 2020, 24, 10, 11),
#  ('India', 2015, 2104, 1323, None),
#  ('India', 2016, 2295, 1339, None),
#  ('India', 2017, 2651, 1354, None),
#  ('India', 2018, 2703, 1369, 8),
#  ('India', 2019, 2832, 1383, 7),
#  ('India', 2020, 2668, 1396, 8),
#  ('Indonesia', 2015, 861, 259, 5),
#  ('Indonesia', 2016, 932, 262, 4),
#  ('Indonesia', 2017, 1016, 264, 4),
#  ('Indonesia', 2018, 1042, 267, 4),
#  ('Indonesia', 2019, 1119, 270, 4),
#  ('Indonesia', 2020, 1059, 272, 4),
#  ('Iran (Islamic Republic of)', 2015, None, None, None),
#  ('Iran (Islamic Republic of)', 2016, None, None, None),
#  ('Iran (Islamic Republic of)', 2017, None, None, None),
#  ('Iran (Islamic Republic of)', 2018, None, None, None),
#  ('Iran (Islamic Republic of)', 2019, None, None, None),
#  ('Iran (Islamic Republic of)', 2020, None, None, None),
#  ('Iraq', 2015, 167, 38, None),
#  ('Iraq', 2016, 167, 39, 11),
#  ('Iraq', 2017, 187, 40, 13),
#  ('Iraq', 2018, 227, 41, None),
#  ('Iraq', 2019, 234, 42, None),
#  ('Iraq', 2020, 184, 43, None),
#  ('Israel', 2015, 303, 8, 5),
#  ('Israel', 2016, 322, 9, 5),
#  ('Israel', 2017, 358, 9, 4),
#  ('Israel', 2018, 377, 9, 4),
#  ('Israel', 2019, 402, 9, 4),
#  ('Israel', 2020, 413, 9, 4),
#  ('Jamaica', 2015, 14, 3, 14),
#  ('Jamaica', 2016, 14, 3, 9),
#  ('Jamaica', 2017, 15, 3, 7),
#  ('Jamaica', 2018, 16, 3, 5),
#  ('Jamaica', 2019, 16, 3, 5),
#  ('Jamaica', 2020, 14, 3, 7),
#  ('Japan', 2015, 4445, 127, 3),
#  ('Japan', 2016, 5004, 127, 3),
#  ('Japan', 2017, 4931, 127, 3),
#  ('Japan', 2018, 5038, 127, 2),
#  ('Japan', 2019, 5123, 127, 2),
#  ('Japan', 2020, 5040, 126, 3),
#  ('Jordan', 2015, 39, 9, 13),
#  ('Jordan', 2016, 40, 10, 15),
#  ('Jordan', 2017, 42, 10, 18),
#  ('Jordan', 2018, 43, 10, 18),
#  ('Jordan', 2019, 45, 11, 17),
#  ('Jordan', 2020, 44, 11, 19),
#  ('Kazakhstan', 2015, 184, 18, 5),
#  ('Kazakhstan', 2016, 137, 18, 5),
#  ('Kazakhstan', 2017, 167, 18, 5),
#  ('Kazakhstan', 2018, 179, 18, 5),
#  ('Kazakhstan', 2019, 182, 19, 5),
#  ('Kazakhstan', 2020, 171, 19, 5),
#  ('Kenya', 2015, 70, 47, None),
#  ('Kenya', 2016, 75, 48, 3),
#  ('Kenya', 2017, 82, 49, None),
#  ('Kenya', 2018, 92, 50, None),
#  ('Kenya', 2019, 100, 51, 5),
#  ('Kenya', 2020, 101, 52, None),
#  ('Kiribati', 2015, 0, 0, 9),
#  ('Kiribati', 2016, 0, 0, None),
#  ('Kiribati', 2017, 0, 0, None),
#  ('Kiribati', 2018, 0, 0, None),
#  ('Kiribati', 2019, 0, 0, 9),
#  ('Kiribati', 2020, 0, 0, 11),
#  ('Kuwait', 2015, 115, 4, 2),
#  ('Kuwait', 2016, 109, 4, 2),
#  ('Kuwait', 2017, 121, 4, None),
#  ('Kuwait', 2018, 138, 4, None),
#  ('Kuwait', 2019, 136, 4, None),
#  ('Kuwait', 2020, 106, 4, None),
#  ('Kyrgyzstan', 2015, None, None, None),
#  ('Kyrgyzstan', 2016, None, None, None),
#  ('Kyrgyzstan', 2017, None, None, None),
#  ('Kyrgyzstan', 2018, None, None, None),
#  ('Kyrgyzstan', 2019, None, None, None),
#  ('Kyrgyzstan', 2020, None, None, None),
#  ("Lao People's Democratic Republic", 2015, None, None, None),
#  ("Lao People's Democratic Republic", 2016, None, None, None),
#  ("Lao People's Democratic Republic", 2017, None, None, None),
#  ("Lao People's Democratic Republic", 2018, None, None, None),
#  ("Lao People's Democratic Republic", 2019, None, None, None),
#  ("Lao People's Democratic Republic", 2020, None, None, None),
#  ('Lebanon', 2015, 50, 6, None),
#  ('Lebanon', 2016, 51, 6, None),
#  ('Lebanon', 2017, 53, 6, None),
#  ('Lebanon', 2018, 55, 6, None),
#  ('Lebanon', 2019, 52, 6, 11),
#  ('Lebanon', 2020, 32, 6, None),
#  ('Lesotho', 2015, 2, 2, None),
#  ('Lesotho', 2016, 2, 2, None),
#  ('Lesotho', 2017, 2, 2, None),
#  ('Lesotho', 2018, 3, 2, None),
#  ('Lesotho', 2019, 2, 2, 17),
#  ('Lesotho', 2020, 2, 2, None),
#  ('Liberia', 2015, 3, 5, None),
#  ('Liberia', 2016, 3, 5, 3),
#  ('Liberia', 2017, 3, 5, 6),
#  ('Liberia', 2018, 3, 5, None),
#  ('Liberia', 2019, 3, 5, None),
#  ('Liberia', 2020, 3, 5, None),
#  ('Libya', 2015, 49, 6, None),
#  ('Libya', 2016, 50, 6, None),
#  ('Libya', 2017, 67, 6, None),
#  ('Libya', 2018, 77, 6, None),
#  ('Libya', 2019, 69, 7, None),
#  ('Libya', 2020, 50, 7, None),
#  ('Madagascar', 2015, 11, 25, 2),
#  ('Madagascar', 2016, 12, 26, None),
#  ('Madagascar', 2017, 13, 26, None),
#  ('Madagascar', 2018, 14, 27, None),
#  ('Madagascar', 2019, 14, 28, None),
#  ('Madagascar', 2020, 13, 28, None),
#  ('Malawi', 2015, 6, 17, None),
#  ('Malawi', 2016, 5, 17, None),
#  ('Malawi', 2017, 9, 18, 4),
#  ('Malawi', 2018, 10, 18, None),
#  ('Malawi', 2019, 11, 19, None),
#  ('Malawi', 2020, 12, 19, 1),
#  ('Malaysia', 2015, 301, 31, 3),
#  ('Malaysia', 2016, 301, 32, 3),
#  ('Malaysia', 2017, 319, 32, 3),
#  ('Malaysia', 2018, 359, 32, 3),
#  ('Malaysia', 2019, 365, 33, 3),
#  ('Malaysia', 2020, 337, 33, 5),
#  ('Maldives', 2015, 4, 0, None),
#  ('Maldives', 2016, 4, 0, 6),
#  ('Maldives', 2017, 5, 0, None),
#  ('Maldives', 2018, 5, 0, None),
#  ('Maldives', 2019, 6, 1, 5),
#  ('Maldives', 2020, 4, 1, None),
#  ('Mali', 2015, 13, 18, 8),
#  ('Mali', 2016, 14, 19, 1),
#  ('Mali', 2017, 15, 19, 7),
#  ('Mali', 2018, 17, 20, 2),
#  ('Mali', 2019, 17, 21, None),
#  ('Mali', 2020, 17, 21, 4),
#  ('Marshall Islands', 2015, 0, 0, None),
#  ('Marshall Islands', 2016, 0, 0, None),
#  ('Marshall Islands', 2017, 0, 0, None),
#  ('Marshall Islands', 2018, 0, 0, None),
#  ('Marshall Islands', 2019, 0, 0, 6),
#  ('Marshall Islands', 2020, 0, 0, None),
#  ('Martinique', 2015, None, None, None),
#  ('Martinique', 2016, None, None, None),
#  ('Martinique', 2017, None, None, None),
#  ('Martinique', 2018, None, None, None),
#  ('Martinique', 2019, None, None, None),
#  ('Martinique', 2020, None, None, None),
#  ('Mauritania', 2015, 6, 4, None),
#  ('Mauritania', 2016, 6, 4, None),
#  ('Mauritania', 2017, 7, 4, 10),
#  ('Mauritania', 2018, 7, 4, None),
#  ('Mauritania', 2019, 8, 4, 10),
#  ('Mauritania', 2020, 8, 4, None),
#  ('Mauritius', 2015, 12, 1, 7),
#  ('Mauritius', 2016, 13, 1, 7),
#  ('Mauritius', 2017, 14, 1, 7),
#  ('Mauritius', 2018, 15, 1, 6),
#  ('Mauritius', 2019, 14, 1, 6),
#  ('Mauritius', 2020, 11, 1, 9),
#  ('Mayotte', 2015, None, None, None),
#  ('Mayotte', 2016, None, None, None),
#  ('Mayotte', 2017, None, None, None),
#  ('Mayotte', 2018, None, None, None),
#  ('Mayotte', 2019, None, None, None),
#  ('Mayotte', 2020, None, None, None),
#  ('Mexico', 2015, 1172, 120, 4),
#  ('Mexico', 2016, 1078, 122, 4),
#  ('Mexico', 2017, 1159, 123, 3),
#  ('Mexico', 2018, 1222, 124, 3),
#  ('Mexico', 2019, 1269, 125, 3),
#  ('Mexico', 2020, 1091, 126, 4),
#  ('Micronesia (Federated States of)', 2015, None, None, None),
#  ('Micronesia (Federated States of)', 2016, None, None, None),
#  ('Micronesia (Federated States of)', 2017, None, None, None),
#  ('Micronesia (Federated States of)', 2018, None, None, None),
#  ('Micronesia (Federated States of)', 2019, None, None, None),
#  ('Mongolia', 2015, 12, 3, 5),
#  ('Mongolia', 2016, 11, 3, 7),
#  ('Mongolia', 2017, 11, 3, 6),
#  ('Mongolia', 2018, 13, 3, 5),
#  ('Mongolia', 2019, 14, 3, 9),
#  ('Mongolia', 2020, 13, 3, 7),
#  ('Montserrat', 2015, None, None, None),
#  ('Montserrat', 2016, None, None, None),
#  ('Montserrat', 2017, None, None, None),
#  ('Montserrat', 2018, None, None, None),
#  ('Montserrat', 2019, None, None, None),
#  ('Montserrat', 2020, None, None, None),
#  ('Morocco', 2015, 110, 35, 9),
#  ('Morocco', 2016, 112, 35, 9),
#  ('Morocco', 2017, 119, 36, None),
#  ('Morocco', 2018, 127, 36, None),
#  ('Morocco', 2019, 129, 36, None),
#  ('Morocco', 2020, 121, 37, None),
#  ('Mozambique', 2015, 16, 27, 3),
#  ('Mozambique', 2016, 12, 28, None),
#  ('Mozambique', 2017, 13, 29, None),
#  ('Mozambique', 2018, 15, 29, None),
#  ('Mozambique', 2019, 15, 30, None),
#  ('Mozambique', 2020, 14, 31, None),
#  ('Myanmar', 2015, 63, 51, 1),
#  ('Myanmar', 2016, 60, 52, None),
#  ('Myanmar', 2017, 61, 52, 1),
#  ('Myanmar', 2018, 67, 53, 1),
#  ('Myanmar', 2019, 69, 53, 0),
#  ('Myanmar', 2020, 79, 53, 1),
#  ('Namibia', 2015, 11, 2, None),
#  ('Namibia', 2016, 11, 2, 23),
#  ('Namibia', 2017, 13, 2, None),
#  ('Namibia', 2018, 14, 2, 20),
#  ('Namibia', 2019, 13, 2, None),
#  ('Namibia', 2020, 11, 2, None),
#  ('Nauru', 2015, 0, 0, None),
#  ('Nauru', 2016, 0, 0, None),
#  ('Nauru', 2017, 0, 0, None),
#  ('Nauru', 2018, 0, 0, None),
#  ('Nauru', 2019, 0, 0, None),
#  ('Nauru', 2020, 0, 0, None),
#  ('Nepal', 2015, 24, 28, 3),
#  ('Nepal', 2016, 25, 28, None),
#  ('Nepal', 2017, 29, 28, 11),
#  ('Nepal', 2018, 33, 29, None),
#  ('Nepal', 2019, 34, 29, None),
#  ('Nepal', 2020, 33, 29, None),
#  ('New Caledonia', 2015, 9, 0, None),
#  ('New Caledonia', 2016, 9, 0, None),
#  ('New Caledonia', 2017, 9, 0, 12),
#  ('New Caledonia', 2018, 10, 0, 12),
#  ('New Caledonia', 2019, 9, 0, 11),
#  ('New Caledonia', 2020, 9, 0, 14),
#  ('New Zealand', 2015, 178, 5, 5),
#  ('New Zealand', 2016, 189, 5, 5),
#  ('New Zealand', 2017, 207, 5, 5),
#  ('New Zealand', 2018, 212, 5, 4),
#  ('New Zealand', 2019, 213, 5, 4),
#  ('New Zealand', 2020, 212, 5, 5),
#  ('Nicaragua', 2015, 13, 6, 5),
#  ('Nicaragua', 2016, 13, 6, 4),
#  ('Nicaragua', 2017, 14, 6, 3),
#  ('Nicaragua', 2018, 13, 7, 5),
#  ('Nicaragua', 2019, 13, 7, None),
#  ('Nicaragua', 2020, 13, 7, None),
#  ('Niger', 2015, 10, 20, None),
#  ('Niger', 2016, 10, 21, None),
#  ('Niger', 2017, 11, 22, 8),
#  ('Niger', 2018, 13, 23, None),
#  ('Niger', 2019, 13, 23, None),
#  ('Niger', 2020, 14, 24, None),
#  ('Nigeria', 2015, 493, 184, 4),
#  ('Nigeria', 2016, 405, 189, 7),
#  ('Nigeria', 2017, 376, 193, 8),
#  ('Nigeria', 2018, 422, 198, None),
#  ('Nigeria', 2019, 448, 203, 11),
#  ('Nigeria', 2020, 432, 208, None),
#  ('Niue', 2015, None, None, None),
#  ('Niue', 2016, None, None, None),
#  ('Niue', 2017, None, None, None),
#  ('Niue', 2018, None, None, None),
#  ('Niue', 2019, None, None, None),
#  ('Niue', 2020, None, None, None),
#  ('Northern Mariana Islands', 2015, 1, 0, None),
#  ('Northern Mariana Islands', 2016, 1, 0, None),
#  ('Northern Mariana Islands', 2017, 2, 0, None),
#  ('Northern Mariana Islands', 2018, 1, 0, None),
#  ('Northern Mariana Islands', 2019, 1, 0, None),
#  ('Northern Mariana Islands', 2020, None, 0, None),
#  ('Oman', 2015, 79, 4, None),
#  ('Oman', 2016, 75, 4, 3),
#  ('Oman', 2017, 81, 5, None),
#  ('Oman', 2018, 92, 5, 2),
#  ('Oman', 2019, 88, 5, None),
#  ('Oman', 2020, 76, 5, 3),
#  ('Pakistan', 2015, 271, 211, 4),
#  ('Pakistan', 2016, 314, 214, None),
#  ('Pakistan', 2017, 339, 216, None),
#  ('Pakistan', 2018, 356, 220, 4),
#  ('Pakistan', 2019, 321, 223, 5),
#  ('Pakistan', 2020, 300, 227, None),
#  ('Palau', 2015, 0, 0, None),
#  ('Palau', 2016, 0, 0, None),
#  ('Palau', 2017, 0, 0, None),
#  ('Palau', 2018, 0, 0, None),
#  ('Palau', 2019, 0, 0, None),
#  ('Palau', 2020, 0, 0, 1),
#  ('Panama', 2015, 54, 4, 4),
#  ('Panama', 2016, 58, 4, 5),
#  ('Panama', 2017, 62, 4, 5),
#  ('Panama', 2018, 65, 4, 5),
#  ('Panama', 2019, 67, 4, 6),
#  ('Panama', 2020, 54, 4, 19),
#  ('Papua New Guinea', 2015, 22, 9, None),
#  ('Papua New Guinea', 2016, 21, 9, None),
#  ('Papua New Guinea', 2017, 23, 9, None),
#  ('Papua New Guinea', 2018, 24, 9, None),
#  ('Papua New Guinea', 2019, 25, 10, None),
#  ('Papua New Guinea', 2020, 24, 10, None),
#  ('Paraguay', 2015, 36, 6, 5),
#  ('Paraguay', 2016, 36, 6, 5),
#  ('Paraguay', 2017, 39, 6, 5),
#  ('Paraguay', 2018, 40, 6, 6),
#  ('Paraguay', 2019, 38, 7, 7),
#  ('Paraguay', 2020, 35, 7, 8),
#  ('Peru', 2015, 190, 31, 3),
#  ('Peru', 2016, 192, 31, 4),
#  ('Peru', 2017, 211, 32, 4),
#  ('Peru', 2018, 223, 32, 3),
#  ('Peru', 2019, 228, 33, 3),
#  ('Peru', 2020, 202, 33, 7),
#  ('Philippines', 2015, 306, 103, 3),
#  ('Philippines', 2016, 319, 105, 3),
#  ('Philippines', 2017, 328, 107, 3),
#  ('Philippines', 2018, 347, 109, 2),
#  ('Philippines', 2019, 377, 110, 2),
#  ('Philippines', 2020, 362, 112, 3),
#  ('Puerto Rico', 2015, 103, 3, 12),
#  ('Puerto Rico', 2016, 104, 3, 12),
#  ('Puerto Rico', 2017, 103, 3, 11),
#  ('Puerto Rico', 2018, 101, 3, 9),
#  ('Puerto Rico', 2019, 105, 3, 8),
#  ('Puerto Rico', 2020, 103, 3, None),
#  ('Qatar', 2015, 162, 2, 0),
#  ('Qatar', 2016, 152, 3, 0),
#  ('Qatar', 2017, 161, 3, 0),
#  ('Qatar', 2018, 183, 3, 0),
#  ('Qatar', 2019, 176, 3, 0),
#  ('Qatar', 2020, 144, 3, 0),
#  ('Republic of Korea', 2015, None, None, None),
#  ('Republic of Korea', 2016, None, None, None),
#  ('Republic of Korea', 2017, None, None, None),
#  ('Republic of Korea', 2018, None, None, None),
#  ('Republic of Korea', 2019, None, None, None),
#  ('Republic of Korea', 2020, None, None, None),
#  ('Réunion', 2015, None, None, None),
#  ('Réunion', 2016, None, None, None),
#  ('Réunion', 2017, None, None, None),
#  ('Réunion', 2018, None, None, None),
#  ('Réunion', 2019, None, None, None),
#  ('Réunion', 2020, None, None, None),
#  ('Rwanda', 2015, 9, 12, None),
#  ('Rwanda', 2016, 9, 12, None),
#  ('Rwanda', 2017, 9, 12, 12),
#  ('Rwanda', 2018, 10, 13, 11),
#  ('Rwanda', 2019, 10, 13, 11),
#  ('Rwanda', 2020, 10, 13, 12),
#  ('Saint Barthélemy', 2015, None, None, None),
#  ('Saint Barthélemy', 2016, None, None, None),
#  ('Saint Barthélemy', 2017, None, None, None),
#  ('Saint Barthélemy', 2018, None, None, None),
#  ('Saint Barthélemy', 2019, None, None, None),
#  ('Saint Barthélemy', 2020, None, None, None),
#  ('Saint Helena', 2015, None, None, None),
#  ('Saint Helena', 2016, None, None, None),
#  ('Saint Helena', 2017, None, None, None),
#  ('Saint Helena', 2018, None, None, None),
#  ('Saint Helena', 2019, None, None, None),
#  ('Saint Helena', 2020, None, None, None),
#  ('Saint Kitts and Nevis', 2015, None, None, None),
#  ('Saint Kitts and Nevis', 2016, None, None, None),
#  ('Saint Kitts and Nevis', 2017, None, None, None),
#  ('Saint Lucia', 2015, None, None, None),
#  ('Saint Lucia', 2016, None, None, None),
#  ('Saint Lucia', 2017, None, None, None),
#  ('Saint Lucia', 2018, None, None, None),
#  ('Saint Lucia', 2019, None, None, None),
#  ('Saint Lucia', 2020, None, None, None),
#  ('Saint Martin (French Part)', 2015, None, None, None),
#  ('Saint Martin (French Part)', 2016, None, None, None),
#  ('Saint Martin (French Part)', 2017, None, None, None),
#  ('Saint Martin (French Part)', 2018, None, None, None),
#  ('Saint Martin (French Part)', 2019, None, None, None),
#  ('Saint Martin (French Part)', 2020, None, None, None),
#  ('Saint Pierre and Miquelon', 2015, None, None, None),
#  ('Saint Pierre and Miquelon', 2016, None, None, None),
#  ('Saint Pierre and Miquelon', 2017, None, None, None),
#  ('Saint Pierre and Miquelon', 2018, None, None, None),
#  ('Saint Pierre and Miquelon', 2019, None, None, None),
#  ('Saint Pierre and Miquelon', 2020, None, None, None),
#  ('Saint Vincent and the Grenadines', 2015, None, None, None),
#  ('Saint Vincent and the Grenadines', 2016, None, None, None),
#  ('Saint Vincent and the Grenadines', 2017, None, None, None),
#  ('Saint Vincent and the Grenadines', 2018, None, None, None),
#  ('Samoa', 2015, 1, 0, None),
#  ('Samoa', 2016, 1, 0, None),
#  ('Samoa', 2017, 1, 0, 9),
#  ('Samoa', 2018, 1, 0, None),
#  ('Samoa', 2019, 1, 0, None),
#  ('Samoa', 2020, 1, 0, None),
#  ('Sao Tome and Principe', 2015, 0, 0, None),
#  ('Sao Tome and Principe', 2016, 0, 0, None),
#  ('Sao Tome and Principe', 2017, 0, 0, None),
#  ('Sao Tome and Principe', 2018, 0, 0, None),
#  ('Sao Tome and Principe', 2019, 0, 0, None),
#  ('Sao Tome and Principe', 2020, 0, 0, None),
#  ('Saudi Arabia', 2015, 654, 33, 6),
#  ('Saudi Arabia', 2016, 645, 33, 6),
#  ('Saudi Arabia', 2017, 689, 34, 6),
#  ('Saudi Arabia', 2018, 817, 35, 6),
#  ('Saudi Arabia', 2019, 804, 36, 6),
#  ('Saudi Arabia', 2020, 703, 36, 8),
#  ('Senegal', 2015, 18, 14, 7),
#  ('Senegal', 2016, 19, 15, 4),
#  ('Senegal', 2017, 21, 15, 4),
#  ('Senegal', 2018, 23, 16, 4),
#  ('Senegal', 2019, 23, 16, 3),
#  ('Senegal', 2020, 24, 16, None),
#  ('Seychelles', 2015, 1, 0, 4),
#  ('Seychelles', 2016, 1, 0, 4),
#  ('Seychelles', 2017, 2, 0, 4),
#  ('Seychelles', 2018, 2, 0, 4),
#  ('Seychelles', 2019, 2, 0, 3),
#  ('Sierra Leone', 2015, 4, 7, None),
#  ('Sierra Leone', 2016, 4, 7, None),
#  ('Sierra Leone', 2017, 4, 8, None),
#  ('Sierra Leone', 2018, 4, 8, 3),
#  ('Sierra Leone', 2019, 4, 8, None),
#  ('Sierra Leone', 2020, 4, 8, None),
#  ('Singapore', 2015, 308, 6, 4),
#  ('Singapore', 2016, 319, 6, 4),
#  ('Singapore', 2017, 343, 6, 4),
#  ('Singapore', 2018, 377, 6, None),
#  ('Singapore', 2019, 375, 6, 3),
#  ('Singapore', 2020, 345, 6, 4),
#  ('Sint Maarten (Dutch part)', 2015, 1, 0, None),
#  ('Sint Maarten (Dutch part)', 2016, 1, 0, None),
#  ('Sint Maarten (Dutch part)', 2017, 1, 0, None),
#  ('Solomon Islands', 2015, 1, 1, None),
#  ('Solomon Islands', 2016, 1, 1, None),
#  ('Solomon Islands', 2017, 1, 1, None),
#  ('Solomon Islands', 2018, 2, 1, None),
#  ('Solomon Islands', 2019, 2, 1, None),
#  ('Solomon Islands', 2020, 2, 1, None),
#  ('Somalia', 2015, 5, 14, None),
#  ('Somalia', 2016, 6, 14, None),
#  ('Somalia', 2017, 6, 15, None),
#  ('Somalia', 2018, 6, 15, None),
#  ('Somalia', 2019, 6, 16, 19),
#  ('Somalia', 2020, 7, 17, None),
#  ('South Africa', 2015, 347, 56, 23),
#  ('South Africa', 2016, 324, 56, 24),
#  ('South Africa', 2017, 381, 57, 24),
#  ('South Africa', 2018, 404, 57, 24),
#  ('South Africa', 2019, 389, 58, 26),
#  ('South Africa', 2020, 338, 59, 24),
#  ('South Sudan', 2015, 12, 11, None),
#  ('South Sudan', 2016, None, 11, None),
#  ('South Sudan', 2017, None, 11, None),
#  ('South Sudan', 2018, None, 10, None),
#  ('South Sudan', 2019, None, 10, None),
#  ('South Sudan', 2020, None, 11, None),
#  ('Sri Lanka', 2015, 85, 21, 5),
#  ('Sri Lanka', 2016, 88, 21, 4),
#  ('Sri Lanka', 2017, 94, 21, 4),
#  ('Sri Lanka', 2018, 94, 22, 4),
#  ('Sri Lanka', 2019, 89, 22, 5),
#  ('Sri Lanka', 2020, 85, 22, 5),
#  ('State of Palestine', 2015, None, None, None),
#  ('State of Palestine', 2016, None, None, None),
#  ('State of Palestine', 2017, None, None, None),
#  ('State of Palestine', 2018, None, None, None),
#  ('State of Palestine', 2019, None, None, None),
#  ('State of Palestine', 2020, None, None, None),
#  ('Sudan', 2015, 85, 38, None),
#  ('Sudan', 2016, 103, 39, None),
#  ('Sudan', 2017, 130, 41, None),
#  ('Sudan', 2018, 32, 42, None),
#  ('Sudan', 2019, 32, 43, None),
#  ('Sudan', 2020, 27, 44, None),
#  ('Suriname', 2015, 5, 1, 7),
#  ('Suriname', 2016, 3, 1, 8),
#  ('Suriname', 2017, 4, 1, None),
#  ('Suriname', 2018, 4, 1, None),
#  ('Suriname', 2019, 4, 1, None),
#  ('Suriname', 2020, 3, 1, None),
#  ('Syrian Arab Republic', 2015, 16, 19, None),
#  ('Syrian Arab Republic', 2016, 13, 19, None),
#  ('Syrian Arab Republic', 2017, 16, 19, None),
#  ('Syrian Arab Republic', 2018, 21, 19, None),
#  ('Syrian Arab Republic', 2019, 22, 20, None),
#  ('Syrian Arab Republic', 2020, 11, 21, None),
#  ('Tajikistan', 2015, 8, 9, None),
#  ('Tajikistan', 2016, 7, 9, 7),
#  ('Tajikistan', 2017, 8, 9, None),
#  ('Tajikistan', 2018, 8, 9, None),
#  ('Tajikistan', 2019, 8, 9, None),
#  ('Tajikistan', 2020, 8, 10, None),
#  ('Thailand', 2015, 401, 70, 1),
#  ('Thailand', 2016, 413, 71, 1),
#  ('Thailand', 2017, 456, 71, 1),
#  ('Thailand', 2018, 507, 71, 1),
#  ('Thailand', 2019, 544, 71, 1),
#  ('Thailand', 2020, 500, 71, 1),
#  ('Timor-Leste', 2015, 2, 1, None),
#  ('Timor-Leste', 2016, 2, 1, 5),
#  ('Timor-Leste', 2017, 2, 1, None),
#  ('Timor-Leste', 2018, 2, 1, None),
#  ('Timor-Leste', 2019, 2, 1, None),
#  ('Timor-Leste', 2020, 2, 1, None),
#  ('Togo', 2015, 4, 7, 2),
#  ('Togo', 2016, 6, 8, None),
#  ('Togo', 2017, 6, 8, 4),
#  ('Togo', 2018, 7, 8, None),
#  ('Togo', 2019, 7, 8, None),
#  ('Togo', 2020, 8, 8, None),
#  ('Tokelau', 2015, None, None, None),
#  ('Tokelau', 2016, None, None, None),
#  ('Tokelau', 2017, None, None, None),
#  ('Tokelau', 2018, None, None, None),
#  ('Tokelau', 2019, None, None, None),
#  ('Tokelau', 2020, None, None, None),
#  ('Tonga', 2015, 0, 0, None),
#  ('Tonga', 2016, 0, 0, None),
#  ('Tonga', 2017, 0, 0, None),
#  ('Tonga', 2018, 0, 0, 2),
#  ('Tonga', 2019, 1, 0, None),
#  ('Tonga', 2020, 0, 0, None),
#  ('Trinidad and Tobago', 2015, 27, 1, 2),
#  ('Trinidad and Tobago', 2016, 24, 1, 3),
#  ('Trinidad and Tobago', 2017, 24, 1, None),
#  ('Trinidad and Tobago', 2018, 24, 2, None),
#  ('Trinidad and Tobago', 2019, 24, 2, 4),
#  ('Trinidad and Tobago', 2020, 21, 2, 4),
#  ('Tunisia', 2015, 46, 12, 15),
#  ('Tunisia', 2016, 44, 12, 16),
#  ('Tunisia', 2017, 42, 12, 15),
#  ('Tunisia', 2018, 43, 12, 15),
#  ('Tunisia', 2019, 42, 12, 15),
#  ('Tunisia', 2020, 43, 12, None),
#  ('Türkiye', 2015, None, None, None),
#  ('Türkiye', 2016, None, None, None),
#  ('Türkiye', 2017, None, None, None),
#  ('Türkiye', 2018, None, None, None),
#  ('Türkiye', 2019, None, None, None),
#  ('Türkiye', 2020, None, None, None),
#  ('Turkmenistan', 2015, 36, 6, None),
#  ('Turkmenistan', 2016, 36, 6, None),
#  ('Turkmenistan', 2017, 38, 6, None),
#  ('Turkmenistan', 2018, 41, 6, None),
#  ('Turkmenistan', 2019, 45, 6, None),
#  ('Turkmenistan', 2020, None, 6, None),
#  ('Turks and Caicos Islands', 2015, 1, 0, None),
#  ('Turks and Caicos Islands', 2016, 1, 0, None),
#  ('Turks and Caicos Islands', 2017, 1, 0, None),
#  ('Turks and Caicos Islands', 2018, 1, 0, None),
#  ('Tuvalu', 2015, 0, 0, None),
#  ('Tuvalu', 2016, 0, 0, 8),
#  ('Tuvalu', 2017, 0, 0, 27),
#  ('Tuvalu', 2018, 0, 0, None),
#  ('Tuvalu', 2019, 0, 0, None),
#  ('Tuvalu', 2020, 0, 0, None),
#  ('Uganda', 2015, 32, 37, None),
#  ('Uganda', 2016, 29, 39, None),
#  ('Uganda', 2017, 31, 40, 4),
#  ('Uganda', 2018, 33, 42, None),
#  ('Uganda', 2019, 35, 43, None),
#  ('Uganda', 2020, 38, 44, None),
#  ('United Arab Emirates', 2015, 370, 9, None),
#  ('United Arab Emirates', 2016, 369, 9, 2),
#  ('United Arab Emirates', 2017, 391, 9, 2),
#  ('United Arab Emirates', 2018, 427, 9, 2),
#  ('United Arab Emirates', 2019, 418, 9, 2),
#  ('United Arab Emirates', 2020, 349, 9, 4),
#  ('United Republic of Tanzania', 2015, None, None, None),
#  ('United Republic of Tanzania', 2016, None, None, None),
#  ('United Republic of Tanzania', 2017, None, None, None),
#  ('United Republic of Tanzania', 2018, None, None, None),
#  ('United Republic of Tanzania', 2019, None, None, None),
#  ('United Republic of Tanzania', 2020, None, None, None),
#  ('United States of America', 2015, None, None, None),
#  ('United States of America', 2016, None, None, None),
#  ('United States of America', 2017, None, None, None),
#  ('United States of America', 2018, None, None, None),
#  ('United States of America', 2019, None, None, None),
#  ('United States of America', 2020, None, None, None),
#  ('United States Virgin Islands', 2015, None, None, None),
#  ('United States Virgin Islands', 2016, None, None, None),
#  ('United States Virgin Islands', 2017, None, None, None),
#  ('United States Virgin Islands', 2018, None, None, None),
#  ('United States Virgin Islands', 2019, None, None, None),
#  ('United States Virgin Islands', 2020, None, None, None),
#  ('Uruguay', 2015, 53, 3, 7),
#  ('Uruguay', 2016, 57, 3, 8),
#  ('Uruguay', 2017, 64, 3, 8),
#  ('Uruguay', 2018, 65, 3, 8),
#  ('Uruguay', 2019, 61, 3, 9),
#  ('Uruguay', 2020, 54, 3, 10),
#  ...]

# %% [markdown]
# ## Exercise

# %% [markdown]
# In this exercise. We will use a subquery to answer the following question: What is the average GDP and population for countries with unemployment rates above 5%?

# %% [markdown]
# ### Creating the subquery
# Construct the subquery that displays the average GDP and average population of countries for 2020. The query should have the following columns: `Country_name`, `Avg_GDP`, `Avg_Population`.

# %%
# %%sql
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP,
#     AVG(Est_population_in_millions) AS Avg_Population
# FROM
#     Economic_indicators
# WHERE
#     Time_period = 2020
# GROUP BY
#     Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 165 rows affected.
# [('Afghanistan', Decimal('20.0000'), Decimal('39.0000')),
#  ('Algeria', Decimal('145.0000'), Decimal('43.0000')),
#  ('American Samoa', Decimal('1.0000'), Decimal('0.0000')),
#  ('Angola', Decimal('54.0000'), Decimal('33.0000')),
#  ('Argentina', Decimal('386.0000'), Decimal('45.0000')),
#  ('Armenia', Decimal('13.0000'), Decimal('3.0000')),
#  ('Australia', Decimal('1327.0000'), Decimal('26.0000')),
#  ('Azerbaijan', Decimal('43.0000'), Decimal('10.0000')),
#  ('Bahrain', Decimal('35.0000'), Decimal('1.0000')),
#  ('Bangladesh', Decimal('374.0000'), Decimal('167.0000')),
#  ('Barbados', Decimal('5.0000'), Decimal('0.0000')),
#  ('Belize', Decimal('2.0000'), Decimal('0.0000')),
#  ('Benin', Decimal('16.0000'), Decimal('13.0000')),
#  ('Bermuda', Decimal('7.0000'), Decimal('0.0000')),
#  ('Bhutan', Decimal('2.0000'), Decimal('1.0000')),
#  ('Bolivia (Plurinational State of)', None, None),
#  ('Botswana', Decimal('15.0000'), Decimal('3.0000')),
#  ('Brazil', Decimal('1449.0000'), Decimal('213.0000')),
#  ('British Virgin Islands', None, Decimal('0.0000')),
#  ('Brunei Darussalam', Decimal('12.0000'), Decimal('0.0000')),
#  ('Burkina Faso', Decimal('18.0000'), Decimal('22.0000')),
#  ('Burundi', Decimal('3.0000'), Decimal('12.0000')),
#  ('Cabo Verde', Decimal('2.0000'), Decimal('1.0000')),
#  ('Cambodia', Decimal('26.0000'), Decimal('16.0000')),
#  ('Cameroon', Decimal('41.0000'), Decimal('26.0000')),
#  ('Canada', Decimal('1645.0000'), Decimal('38.0000')),
#  ('Central African Republic', Decimal('2.0000'), Decimal('5.0000')),
#  ('Chad', Decimal('11.0000'), Decimal('17.0000')),
#  ('Chile', Decimal('253.0000'), Decimal('19.0000')),
#  ('China', Decimal('14688.0000'), Decimal('1411.0000')),
#  ('Colombia', Decimal('270.0000'), Decimal('51.0000')),
#  ('Congo', None, None),
#  ('Cook Islands', None, None),
#  ('Costa Rica', Decimal('62.0000'), Decimal('5.0000')),
#  ("Côte d'Ivoire", None, None),
#  ('Cuba', Decimal('107.0000'), Decimal('11.0000')),
#  ('Cyprus', Decimal('25.0000'), Decimal('1.0000')),
#  ("Democratic People's Republic of Korea", None, None),
#  ('Democratic Republic of the Congo', None, None),
#  ('Djibouti', Decimal('3.0000'), Decimal('1.0000')),
#  ('Dominican Republic', Decimal('79.0000'), Decimal('11.0000')),
#  ('Ecuador', Decimal('99.0000'), Decimal('18.0000')),
#  ('Egypt', None, None),
#  ('El Salvador', Decimal('25.0000'), Decimal('6.0000')),
#  ('Eswatini', Decimal('4.0000'), Decimal('1.0000')),
#  ('Ethiopia', Decimal('108.0000'), Decimal('117.0000')),
#  ('Falkland Islands (Malvinas)', None, None),
#  ('Fiji', Decimal('4.0000'), Decimal('1.0000')),
#  ('French Guiana', None, None),
#  ('French Polynesia', Decimal('6.0000'), Decimal('0.0000')),
#  ('Gabon', Decimal('15.0000'), Decimal('2.0000')),
#  ('Gambia', None, None),
#  ('Georgia', Decimal('16.0000'), Decimal('4.0000')),
#  ('Ghana', Decimal('70.0000'), Decimal('32.0000')),
#  ('Greenland', Decimal('3.0000'), Decimal('0.0000')),
#  ('Guadeloupe', None, None),
#  ('Guam', Decimal('6.0000'), Decimal('0.0000')),
#  ('Guatemala', Decimal('78.0000'), Decimal('17.0000')),
#  ('Guinea', Decimal('14.0000'), Decimal('13.0000')),
#  ('Guinea-Bissau', Decimal('1.0000'), Decimal('2.0000')),
#  ('Guyana', Decimal('5.0000'), Decimal('1.0000')),
#  ('Haiti', Decimal('15.0000'), Decimal('11.0000')),
#  ('Honduras', Decimal('24.0000'), Decimal('10.0000')),
#  ('India', Decimal('2668.0000'), Decimal('1396.0000')),
#  ('Indonesia', Decimal('1059.0000'), Decimal('272.0000')),
#  ('Iran (Islamic Republic of)', None, None),
#  ('Iraq', Decimal('184.0000'), Decimal('43.0000')),
#  ('Israel', Decimal('413.0000'), Decimal('9.0000')),
#  ('Jamaica', Decimal('14.0000'), Decimal('3.0000')),
#  ('Japan', Decimal('5040.0000'), Decimal('126.0000')),
#  ('Jordan', Decimal('44.0000'), Decimal('11.0000')),
#  ('Kazakhstan', Decimal('171.0000'), Decimal('19.0000')),
#  ('Kenya', Decimal('101.0000'), Decimal('52.0000')),
#  ('Kiribati', Decimal('0.0000'), Decimal('0.0000')),
#  ('Kuwait', Decimal('106.0000'), Decimal('4.0000')),
#  ('Kyrgyzstan', None, None),
#  ("Lao People's Democratic Republic", None, None),
#  ('Lebanon', Decimal('32.0000'), Decimal('6.0000')),
#  ('Lesotho', Decimal('2.0000'), Decimal('2.0000')),
#  ('Liberia', Decimal('3.0000'), Decimal('5.0000')),
#  ('Libya', Decimal('50.0000'), Decimal('7.0000')),
#  ('Madagascar', Decimal('13.0000'), Decimal('28.0000')),
#  ('Malawi', Decimal('12.0000'), Decimal('19.0000')),
#  ('Malaysia', Decimal('337.0000'), Decimal('33.0000')),
#  ('Maldives', Decimal('4.0000'), Decimal('1.0000')),
#  ('Mali', Decimal('17.0000'), Decimal('21.0000')),
#  ('Marshall Islands', Decimal('0.0000'), Decimal('0.0000')),
#  ('Martinique', None, None),
#  ('Mauritania', Decimal('8.0000'), Decimal('4.0000')),
#  ('Mauritius', Decimal('11.0000'), Decimal('1.0000')),
#  ('Mayotte', None, None),
#  ('Mexico', Decimal('1091.0000'), Decimal('126.0000')),
#  ('Mongolia', Decimal('13.0000'), Decimal('3.0000')),
#  ('Montserrat', None, None),
#  ('Morocco', Decimal('121.0000'), Decimal('37.0000')),
#  ('Mozambique', Decimal('14.0000'), Decimal('31.0000')),
#  ('Myanmar', Decimal('79.0000'), Decimal('53.0000')),
#  ('Namibia', Decimal('11.0000'), Decimal('2.0000')),
#  ('Nauru', Decimal('0.0000'), Decimal('0.0000')),
#  ('Nepal', Decimal('33.0000'), Decimal('29.0000')),
#  ('New Caledonia', Decimal('9.0000'), Decimal('0.0000')),
#  ('New Zealand', Decimal('212.0000'), Decimal('5.0000')),
#  ('Nicaragua', Decimal('13.0000'), Decimal('7.0000')),
#  ('Niger', Decimal('14.0000'), Decimal('24.0000')),
#  ('Nigeria', Decimal('432.0000'), Decimal('208.0000')),
#  ('Niue', None, None),
#  ('Northern Mariana Islands', None, Decimal('0.0000')),
#  ('Oman', Decimal('76.0000'), Decimal('5.0000')),
#  ('Pakistan', Decimal('300.0000'), Decimal('227.0000')),
#  ('Palau', Decimal('0.0000'), Decimal('0.0000')),
#  ('Panama', Decimal('54.0000'), Decimal('4.0000')),
#  ('Papua New Guinea', Decimal('24.0000'), Decimal('10.0000')),
#  ('Paraguay', Decimal('35.0000'), Decimal('7.0000')),
#  ('Peru', Decimal('202.0000'), Decimal('33.0000')),
#  ('Philippines', Decimal('362.0000'), Decimal('112.0000')),
#  ('Puerto Rico', Decimal('103.0000'), Decimal('3.0000')),
#  ('Qatar', Decimal('144.0000'), Decimal('3.0000')),
#  ('Republic of Korea', None, None),
#  ('Réunion', None, None),
#  ('Rwanda', Decimal('10.0000'), Decimal('13.0000')),
#  ('Saint Barthélemy', None, None),
#  ('Saint Helena', None, None),
#  ('Saint Lucia', None, None),
#  ('Saint Martin (French Part)', None, None),
#  ('Saint Pierre and Miquelon', None, None),
#  ('Samoa', Decimal('1.0000'), Decimal('0.0000')),
#  ('Sao Tome and Principe', Decimal('0.0000'), Decimal('0.0000')),
#  ('Saudi Arabia', Decimal('703.0000'), Decimal('36.0000')),
#  ('Senegal', Decimal('24.0000'), Decimal('16.0000')),
#  ('Sierra Leone', Decimal('4.0000'), Decimal('8.0000')),
#  ('Singapore', Decimal('345.0000'), Decimal('6.0000')),
#  ('Solomon Islands', Decimal('2.0000'), Decimal('1.0000')),
#  ('Somalia', Decimal('7.0000'), Decimal('17.0000')),
#  ('South Africa', Decimal('338.0000'), Decimal('59.0000')),
#  ('South Sudan', None, Decimal('11.0000')),
#  ('Sri Lanka', Decimal('85.0000'), Decimal('22.0000')),
#  ('State of Palestine', None, None),
#  ('Sudan', Decimal('27.0000'), Decimal('44.0000')),
#  ('Suriname', Decimal('3.0000'), Decimal('1.0000')),
#  ('Syrian Arab Republic', Decimal('11.0000'), Decimal('21.0000')),
#  ('Tajikistan', Decimal('8.0000'), Decimal('10.0000')),
#  ('Thailand', Decimal('500.0000'), Decimal('71.0000')),
#  ('Timor-Leste', Decimal('2.0000'), Decimal('1.0000')),
#  ('Togo', Decimal('8.0000'), Decimal('8.0000')),
#  ('Tokelau', None, None),
#  ('Tonga', Decimal('0.0000'), Decimal('0.0000')),
#  ('Trinidad and Tobago', Decimal('21.0000'), Decimal('2.0000')),
#  ('Tunisia', Decimal('43.0000'), Decimal('12.0000')),
#  ('Türkiye', None, None),
#  ('Turkmenistan', None, Decimal('6.0000')),
#  ('Tuvalu', Decimal('0.0000'), Decimal('0.0000')),
#  ('Uganda', Decimal('38.0000'), Decimal('44.0000')),
#  ('United Arab Emirates', Decimal('349.0000'), Decimal('9.0000')),
#  ('United Republic of Tanzania', None, None),
#  ('United States of America', None, None),
#  ('United States Virgin Islands', None, None),
#  ('Uruguay', Decimal('54.0000'), Decimal('3.0000')),
#  ('Uzbekistan', Decimal('60.0000'), Decimal('34.0000')),
#  ('Vanuatu', Decimal('1.0000'), Decimal('0.0000')),
#  ('Venezuela (Bolivarian Republic of)', None, None),
#  ('Viet Nam', None, None),
#  ('Wallis and Futuna Islands', None, None),
#  ('Yemen', None, None),
#  ('Zambia', Decimal('18.0000'), Decimal('19.0000')),
#  ('Zimbabwe', Decimal('22.0000'), Decimal('16.0000'))]

# %% [markdown]
# ### Creating the main query
# Construct a query that filters out countries with unemployment rates above 5%. The query should include the following columns: `Country_name`, `Est_gdp_in_billions`,  `Est_population_in_millions`.

# %%
# %%sql
# SELECT
#     Country_name,
#     Est_gdp_in_billions,
#     Est_population_in_millions
# FROM
#     Economic_indicators
# WHERE
#     Pct_unemployment > 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 207 rows affected.
# [('Afghanistan', 19, 36),
#  ('Afghanistan', 20, 39),
#  ('Algeria', 166, 40),
#  ('Algeria', 160, 40),
#  ('Algeria', 170, 41),
#  ('Angola', 69, 32),
#  ('Argentina', 644, 44),
#  ('Argentina', 525, 44),
#  ('Argentina', 448, 45),
#  ('Argentina', 386, 45),
#  ('Armenia', 11, 3),
#  ('Armenia', 11, 3),
#  ('Armenia', 12, 3),
#  ('Armenia', 12, 3),
#  ('Armenia', 14, 3),
#  ('Armenia', 13, 3),
#  ('Australia', 1351, 24),
#  ('Australia', 1207, 24),
#  ('Australia', 1327, 25),
#  ('Australia', 1327, 26),
#  ('Azerbaijan', 43, 10),
#  ('Barbados', 5, 0),
#  ('Barbados', 5, 0),
#  ('Barbados', 5, 0),
#  ('Barbados', 5, 0),
#  ('Barbados', 5, 0),
#  ('Belize', 2, 0),
#  ('Belize', 2, 0),
#  ('Belize', 2, 0),
#  ('Belize', 2, 0),
#  ('Botswana', 17, 2),
#  ('Botswana', 15, 3),
#  ('Brazil', 1802, 205),
#  ('Brazil', 1796, 207),
#  ('Brazil', 2064, 209),
#  ('Brazil', 1917, 210),
#  ('Brazil', 1873, 212),
#  ('Brazil', 1449, 213),
#  ('Brunei Darussalam', 12, 0),
#  ('Brunei Darussalam', 14, 0),
#  ('Brunei Darussalam', 13, 0),
#  ('Brunei Darussalam', 12, 0),
#  ('Cabo Verde', 2, 1),
#  ('Cabo Verde', 2, 1),
#  ('Cabo Verde', 2, 1),
#  ('Cabo Verde', 2, 1),
#  ('Canada', 1557, 36),
#  ('Canada', 1528, 36),
#  ('Canada', 1649, 37),
#  ('Canada', 1725, 37),
#  ('Canada', 1742, 38),
#  ('Canada', 1645, 38),
#  ('Chile', 243, 18),
#  ('Chile', 249, 18),
#  ('Chile', 276, 18),
#  ('Chile', 295, 19),
#  ('Chile', 279, 19),
#  ('Chile', 253, 19),
#  ('China', 14688, 1411),
#  ('Colombia', 293, 47),
#  ('Colombia', 283, 48),
#  ('Colombia', 312, 48),
#  ('Colombia', 334, 49),
#  ('Colombia', 323, 50),
#  ('Colombia', 270, 51),
#  ('Costa Rica', 56, 5),
#  ('Costa Rica', 59, 5),
#  ('Costa Rica', 61, 5),
#  ('Costa Rica', 62, 5),
#  ('Costa Rica', 64, 5),
#  ('Costa Rica', 62, 5),
#  ('Cyprus', 20, 1),
#  ('Cyprus', 21, 1),
#  ('Cyprus', 23, 1),
#  ('Cyprus', 26, 1),
#  ('Cyprus', 26, 1),
#  ('Cyprus', 25, 1),
#  ('Djibouti', 3, 1),
#  ('Dominican Republic', 71, 10),
#  ('Dominican Republic', 76, 11),
#  ('Dominican Republic', 80, 11),
#  ('Dominican Republic', 86, 11),
#  ('Dominican Republic', 89, 11),
#  ('Dominican Republic', 79, 11),
#  ('Ecuador', 99, 18),
#  ('Eswatini', 4, 1),
#  ('Georgia', 15, 4),
#  ('Georgia', 15, 4),
#  ('Georgia', 16, 4),
#  ('Georgia', 18, 4),
#  ('Georgia', 17, 4),
#  ('Georgia', 16, 4),
#  ('Ghana', 49, 29),
#  ('Greenland', 3, 0),
#  ('Grenada', 1, 0),
#  ('Guam', 6, 0),
#  ('Guyana', 5, 1),
#  ('Guyana', 5, 1),
#  ('Honduras', 21, 9),
#  ('Honduras', 22, 9),
#  ('Honduras', 23, 10),
#  ('Honduras', 24, 10),
#  ('Honduras', 25, 10),
#  ('Honduras', 24, 10),
#  ('India', 2703, 1369),
#  ('India', 2832, 1383),
#  ('India', 2668, 1396),
#  ('Iraq', 167, 39),
#  ('Iraq', 187, 40),
#  ('Jamaica', 14, 3),
#  ('Jamaica', 14, 3),
#  ('Jamaica', 15, 3),
#  ('Jamaica', 14, 3),
#  ('Jordan', 39, 9),
#  ('Jordan', 40, 10),
#  ('Jordan', 42, 10),
#  ('Jordan', 43, 10),
#  ('Jordan', 45, 11),
#  ('Jordan', 44, 11),
#  ('Kiribati', 0, 0),
#  ('Kiribati', 0, 0),
#  ('Kiribati', 0, 0),
#  ('Lebanon', 52, 6),
#  ('Lesotho', 2, 2),
#  ('Liberia', 3, 5),
#  ('Maldives', 4, 0),
#  ('Mali', 13, 18),
#  ('Mali', 15, 19),
#  ('Marshall Islands', 0, 0),
#  ('Mauritania', 7, 4),
#  ('Mauritania', 8, 4),
#  ('Mauritius', 12, 1),
#  ('Mauritius', 13, 1),
#  ('Mauritius', 14, 1),
#  ('Mauritius', 15, 1),
#  ('Mauritius', 14, 1),
#  ('Mauritius', 11, 1),
#  ('Mongolia', 11, 3),
#  ('Mongolia', 11, 3),
#  ('Mongolia', 14, 3),
#  ('Mongolia', 13, 3),
#  ('Morocco', 110, 35),
#  ('Morocco', 112, 35),
#  ('Namibia', 11, 2),
#  ('Namibia', 14, 2),
#  ('Nepal', 29, 28),
#  ('New Caledonia', 9, 0),
#  ('New Caledonia', 10, 0),
#  ('New Caledonia', 9, 0),
#  ('New Caledonia', 9, 0),
#  ('Niger', 11, 22),
#  ('Nigeria', 405, 189),
#  ('Nigeria', 376, 193),
#  ('Nigeria', 448, 203),
#  ('Panama', 67, 4),
#  ('Panama', 54, 4),
#  ('Paraguay', 40, 6),
#  ('Paraguay', 38, 7),
#  ('Paraguay', 35, 7),
#  ('Peru', 202, 33),
#  ('Puerto Rico', 103, 3),
#  ('Puerto Rico', 104, 3),
#  ('Puerto Rico', 103, 3),
#  ('Puerto Rico', 101, 3),
#  ('Puerto Rico', 105, 3),
#  ('Rwanda', 9, 12),
#  ('Rwanda', 10, 13),
#  ('Rwanda', 10, 13),
#  ('Rwanda', 10, 13),
#  ('Samoa', 1, 0),
#  ('Saudi Arabia', 654, 33),
#  ('Saudi Arabia', 645, 33),
#  ('Saudi Arabia', 689, 34),
#  ('Saudi Arabia', 817, 35),
#  ('Saudi Arabia', 804, 36),
#  ('Saudi Arabia', 703, 36),
#  ('Senegal', 18, 14),
#  ('Somalia', 6, 16),
#  ('South Africa', 347, 56),
#  ('South Africa', 324, 56),
#  ('South Africa', 381, 57),
#  ('South Africa', 404, 57),
#  ('South Africa', 389, 58),
#  ('South Africa', 338, 59),
#  ('Suriname', 5, 1),
#  ('Suriname', 3, 1),
#  ('Tajikistan', 7, 9),
#  ('Tunisia', 46, 12),
#  ('Tunisia', 44, 12),
#  ('Tunisia', 42, 12),
#  ('Tunisia', 43, 12),
#  ('Tunisia', 42, 12),
#  ('Tuvalu', 0, 0),
#  ('Tuvalu', 0, 0),
#  ('Uruguay', 53, 3),
#  ('Uruguay', 57, 3),
#  ('Uruguay', 64, 3),
#  ('Uruguay', 65, 3),
#  ('Uruguay', 61, 3),
#  ('Uruguay', 54, 3),
#  ('Uzbekistan', 62, 32),
#  ('Uzbekistan', 53, 33),
#  ('Uzbekistan', 60, 34),
#  ('Zambia', 26, 17),
#  ('Zambia', 23, 18),
#  ('Zambia', 18, 19),
#  ('Zimbabwe', 22, 15)]

# %% [markdown]
# ### Combining the queries
#
# Using the query and the subquery, determine the average GDP and population for countries with unemployment rates above 5%. Group the results by `Country_name`.

# %%
# %%sql
# SELECT
#     sub.Country_name,
#     AVG(sub.Est_gdp_in_billions) AS Avg_GDP,
#     AVG(sub.Est_population_in_millions) AS Avg_Population
# FROM (
#     SELECT
#         Country_name,
#         Est_gdp_in_billions,
#         Est_population_in_millions
#     FROM
#         Economic_indicators
#     WHERE
#         Time_period = 2020
#         AND Pct_unemployment > 5
# ) AS sub
# GROUP BY
#     sub.Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 33 rows affected.
# [('Afghanistan', Decimal('20.0000'), Decimal('39.0000')),
#  ('Argentina', Decimal('386.0000'), Decimal('45.0000')),
#  ('Armenia', Decimal('13.0000'), Decimal('3.0000')),
#  ('Australia', Decimal('1327.0000'), Decimal('26.0000')),
#  ('Azerbaijan', Decimal('43.0000'), Decimal('10.0000')),
#  ('Botswana', Decimal('15.0000'), Decimal('3.0000')),
#  ('Brazil', Decimal('1449.0000'), Decimal('213.0000')),
#  ('Brunei Darussalam', Decimal('12.0000'), Decimal('0.0000')),
#  ('Canada', Decimal('1645.0000'), Decimal('38.0000')),
#  ('Chile', Decimal('253.0000'), Decimal('19.0000')),
#  ('China', Decimal('14688.0000'), Decimal('1411.0000')),
#  ('Colombia', Decimal('270.0000'), Decimal('51.0000')),
#  ('Costa Rica', Decimal('62.0000'), Decimal('5.0000')),
#  ('Cyprus', Decimal('25.0000'), Decimal('1.0000')),
#  ('Dominican Republic', Decimal('79.0000'), Decimal('11.0000')),
#  ('Ecuador', Decimal('99.0000'), Decimal('18.0000')),
#  ('Georgia', Decimal('16.0000'), Decimal('4.0000')),
#  ('Honduras', Decimal('24.0000'), Decimal('10.0000')),
#  ('India', Decimal('2668.0000'), Decimal('1396.0000')),
#  ('Jamaica', Decimal('14.0000'), Decimal('3.0000')),
#  ('Jordan', Decimal('44.0000'), Decimal('11.0000')),
#  ('Kiribati', Decimal('0.0000'), Decimal('0.0000')),
#  ('Mauritius', Decimal('11.0000'), Decimal('1.0000')),
#  ('Mongolia', Decimal('13.0000'), Decimal('3.0000')),
#  ('New Caledonia', Decimal('9.0000'), Decimal('0.0000')),
#  ('Panama', Decimal('54.0000'), Decimal('4.0000')),
#  ('Paraguay', Decimal('35.0000'), Decimal('7.0000')),
#  ('Peru', Decimal('202.0000'), Decimal('33.0000')),
#  ('Rwanda', Decimal('10.0000'), Decimal('13.0000')),
#  ('Saudi Arabia', Decimal('703.0000'), Decimal('36.0000')),
#  ('South Africa', Decimal('338.0000'), Decimal('59.0000')),
#  ('Uruguay', Decimal('54.0000'), Decimal('3.0000')),
#  ('Zambia', Decimal('18.0000'), Decimal('19.0000'))]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Creating the subquery

# %%
# %%sql
#
# SELECT
#     Country_name,
#     Est_gdp_in_billions,
#     Est_population_in_millions
# FROM
#     Economic_Indicators
# WHERE
#     Pct_unemployment > 5
#     AND Time_period = 2020;

# %% [markdown]
# This table simply filters the `Economic_Indicators` table to only display countries with unemployment > 5. This is the input table the main query will use.

# %% [markdown]
# ### Creating the main query

# %%
# %%sql
#
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP,
#     AVG(Est_population_in_millions) AS Avg_Population
# FROM
#     Economic_Indicators
# GROUP BY
#     Country_name;

# %% [markdown]
# Note that this query calculates the averages for **all** years, and for **all** countries.

# %% [markdown]
# ### Combining the queries

# %%
# %%sql
#
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP,
#     AVG(Est_population_in_millions) AS Avg_Population
# FROM
#     (SELECT
#         Country_name,
#         Est_gdp_in_billions,
#         Est_population_in_millions
#     FROM
#         Economic_Indicators
#     WHERE
#         Pct_unemployment > 5
#         AND Time_period = 2020) AS FilteredCountries
# GROUP BY
#     Country_name;

# %% [markdown]
# Using the subquery filters the data first into a derived table, which the main query uses to aggregate with.

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lesson, we used a subquery to determine the average GDP and populations of countries where the unemployment rate is above 5%. We made use of the `FROM` clause. In essence, the subquery in the `FROM` clause can be thought of as creating an intermediate or derived table for the main query to operate upon, even if this table exists only for the duration of the query execution.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
