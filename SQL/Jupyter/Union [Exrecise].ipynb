# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Union

# %% [markdown]
# In this exercise, we will explore different SQL union statements in order to cross-examine data contained in multiple tables in a dataset.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn to:
# - Use unions to stack the rows of similar tables.

# %% [markdown]
# First, let's load our database:

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.
# %load_ext sql

# Establish a connection to a SQLite database file.
# %sql sqlite:///chinook.db
# Out:
# 'Connected: @chinook.db'

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/The%20chinook%20database%20ERD.jpeg"  style="width:70%";/>
# <br>
# <br>
#     <em>Figure 1: The Chinook database ERD</em>
# </div>
#
#  <em> <a href="https://www.sqlitetutorial.net/sqlite-sample-database/">Image source</a></em>

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Exercise 1
#
# Use the `UNION` operator to combine information from the tracks and albums tables into a single list.

# %%
# %%sql
# SELECT
#     AlbumId, Name,
# FROM tracks
# UNION
# SELECT
#     AlbumId, Title
# FROM albums;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'Breaking The Rules'),
#  (1, 'C.O.D.'),
#  (1, 'Evil Walks'),
#  (1, 'For Those About To Rock (We Salute You)'),
#  (1, 'For Those About To Rock We Salute You'),
#  (1, 'Inject The Venom'),
#  (1, "Let's Get It Up"),
#  (1, 'Night Of The Long Knives'),
#  (1, 'Put The Finger On You'),
#  (1, 'Snowballed'),
#  (1, 'Spellbound'),
#  (2, 'Balls to the Wall'),
#  (3, 'Fast As a Shark'),
#  (3, 'Princess of the Dawn'),
#  (3, 'Restless and Wild'),
#  (4, 'Bad Boy Boogie'),
#  (4, 'Dog Eat Dog'),
#  (4, 'Go Down'),
#  (4, "Hell Ain't A Bad Place To Be"),
#  (4, 'Let There Be Rock'),
#  (4, 'Overdose'),
#  (4, 'Problem Child'),
#  (4, 'Whole Lotta Rosie'),
#  (5, 'Amazing'),
#  (5, 'Angel'),
#  (5, 'Big Ones'),
#  (5, 'Blind Man'),
#  (5, 'Crazy'),
#  (5, "Cryin'"),
#  (5, 'Deuces Are Wild'),
#  (5, 'Dude (Looks Like A Lady)'),
#  (5, 'Eat The Rich'),
#  (5, "Janie's Got A Gun"),
#  (5, "Livin' On The Edge"),
#  (5, 'Love In An Elevator'),
#  (5, 'Rag Doll'),
#  (5, 'The Other Side'),
#  (5, 'Walk On Water'),
#  (5, 'What It Takes'),
#  (6, 'All I Really Want'),
#  (6, 'Forgiven'),
#  (6, 'Hand In My Pocket'),
#  (6, 'Head Over Feet'),
#  (6, 'Ironic'),
#  (6, 'Jagged Little Pill'),
#  (6, 'Mary Jane'),
#  (6, 'Not The Doctor'),
#  (6, 'Perfect'),
#  (6, 'Right Through You'),
#  (6, 'Wake Up'),
#  (6, 'You Learn'),
#  (6, 'You Oughta Know'),
#  (6, 'You Oughta Know (Alternate)'),
#  (7, 'Bleed The Freak'),
#  (7, 'Confusion'),
#  (7, 'Facelift'),
#  (7, "I Can't Remember"),
#  (7, 'I Know Somethin (Bout You)'),
#  (7, "It Ain't Like That"),
#  (7, 'Love, Hate, Love'),
#  (7, 'Man In The Box'),
#  (7, 'Put You Down'),
#  (7, 'Real Thing'),
#  (7, 'Sea Of Sorrow'),
#  (7, 'Sunshine'),
#  (7, 'We Die Young'),
#  (8, 'Angela'),
#  (8, 'Canta, Canta Mais'),
#  (8, 'Corcovado (Quiet Nights Of Quiet Stars)'),
#  (8, 'Desafinado'),
#  (8, 'Dindi (Dindi)'),
#  (8, 'Falando De Amor'),
#  (8, 'Fotografia'),
#  (8, 'Garota De Ipanema'),
#  (8, 'Ligia'),
#  (8, 'O Boto (Bôto)'),
#  (8, 'Outra Vez'),
#  (8, 'Por Causa De Você'),
#  (8, 'Samba De Uma Nota Só (One Note Samba)'),
#  (8, 'Se Todos Fossem Iguais A Você (Instrumental)'),
#  (8, 'Warner 25 Anos'),
#  (9, 'Creeping Death'),
#  (9, 'Enter Sandman'),
#  (9, 'Harvester Of Sorrow'),
#  (9, 'Master Of Puppets'),
#  (9, 'Plays Metallica By Four Cellos'),
#  (9, 'Sad But True'),
#  (9, 'The Unforgiven'),
#  (9, 'Welcome Home (Sanitarium)'),
#  (9, 'Wherever I May Roam'),
#  (10, 'Audioslave'),
#  (10, "Bring'em Back Alive"),
#  (10, 'Cochise'),
#  (10, 'Exploder'),
#  (10, 'Gasoline'),
#  (10, 'Getaway Car'),
#  (10, 'Hypnotize'),
#  (10, 'I am the Highway'),
#  (10, 'Light My Way'),
#  (10, 'Like a Stone'),
#  (10, 'Set It Off'),
#  (10, 'Shadow on the Sun'),
#  (10, 'Show Me How to Live'),
#  (10, 'The Last Remaining Light'),
#  (10, 'What You Are'),
#  (11, '#1 Zero'),
#  (11, 'Be Yourself'),
#  (11, 'Dandelion'),
#  (11, "Doesn't Remind Me"),
#  (11, 'Drown Me Slowly'),
#  (11, "Heaven's Dead"),
#  (11, 'Man Or Animal'),
#  (11, 'Out Of Exile'),
#  (11, 'The Curse'),
#  (11, 'The Worm'),
#  (11, 'Yesterday To Tomorrow'),
#  (11, 'Your Time Has Come'),
#  (12, '20 Flight Rock'),
#  (12, 'BackBeat Soundtrack'),
#  (12, 'Bad Boy'),
#  (12, "C'Mon Everybody"),
#  (12, 'Carol'),
#  (12, 'Good Golly Miss Molly'),
#  (12, 'Long Tall Sally'),
#  (12, 'Money'),
#  (12, 'Please Mr. Postman'),
#  (12, 'Roadrunner'),
#  (12, "Rock 'N' Roll Music"),
#  (12, 'Slow Down'),
#  (12, 'Twist And Shout'),
#  (13, 'Do what cha wanna'),
#  (13, 'Moon germs'),
#  (13, 'Quadrant'),
#  (13, "Snoopy's search-Red baron"),
#  (13, 'Solo-Panhandler'),
#  (13, 'Spanish moss-"A sound portrait"-Spanish moss'),
#  (13, 'Stratus'),
#  (13, 'The Best Of Billy Cobham'),
#  (13, 'The pleasant pheasant'),
#  (14, '13 Years Of Grief'),
#  (14, 'A.N.D.R.O.T.A.Z.'),
#  (14, 'Alcohol Fueled Brewtality Live! [Disc 1]'),
#  (14, 'All For You'),
#  (14, 'Bored To Tears'),
#  (14, 'Born To Booze'),
#  (14, 'Intro/ Low Down'),
#  (14, 'Lost My Better Half'),
#  (14, 'No More Tears'),
#  (14, 'Phoney Smile Fake Hellos'),
#  (14, 'Stronger Than Death'),
#  (14, 'Super Terrorizer'),
#  (14, 'The Begining... At Last'),
#  (14, 'World Of Trouble'),
#  (15, 'Alcohol Fueled Brewtality Live! [Disc 2]'),
#  (15, 'Blood In The Wall'),
#  (15, 'Heart Of Gold'),
#  (15, 'Like A Bird'),
#  (15, 'Snowblind'),
#  (15, 'The Beginning...At Last'),
#  (16, 'Behind The Wall Of Sleep'),
#  (16, 'Black Sabbath'),
#  (16, 'Evil Woman'),
#  (16, 'N.I.B.'),
#  (16, 'Sleeping Village'),
#  (16, 'The Wizard'),
#  (16, 'Warning'),
#  (17, 'Black Sabbath Vol. 4 (Remaster)'),
#  (17, 'Changes'),
#  (17, 'Cornucopia'),
#  (17, 'FX'),
#  (17, 'Laguna Sunrise'),
#  (17, 'Snowblind'),
#  (17, 'St. Vitus Dance'),
#  (17, 'Supernaut'),
#  (17, "Tomorrow's Dream"),
#  (17, 'Under The Sun/Every Day Comes and Goes'),
#  (17, 'Wheels Of Confusion / The Straightener'),
#  (18, 'A Statistic'),
#  (18, 'Body Count'),
#  (18, 'Body Count Anthem'),
#  (18, "Body Count's In The House"),
#  (18, 'Bowels Of The Devil'),
#  (18, 'D Note'),
#  (18, 'Evil Dick'),
#  (18, 'Freedom Of Speech'),
#  (18, 'KKK Bitch'),
#  (18, "Momma's Gotta Die Tonight"),
#  (18, 'Now Sports'),
#  (18, 'Oprah'),
#  (18, 'Smoked Pork'),
#  (18, 'The Real Problem'),
#  (18, 'The Winner Loses'),
#  (18, 'There Goes The Neighborhood'),
#  (18, 'Voodoo'),
#  (19, 'Book Of Thel'),
#  (19, 'Chemical Wedding'),
#  (19, 'Gates Of Urizen'),
#  (19, 'Jerusalem'),
#  (19, 'Killing Floor'),
#  (19, 'King In Crimson'),
#  (19, 'Machine Men'),
#  (19, 'Realword'),
#  (19, 'The Alchemist'),
#  (19, 'The Tower'),
#  (19, 'Trupets Of Jericho'),
#  (20, 'First Time I Met The Blues'),
#  (20, 'Keep It To Myself (Aka Keep It To Yourself)'),
#  (20, 'Leave My Girl Alone'),
#  (20, 'Let Me Love You Baby'),
#  (20, 'My Time After Awhile'),
#  (20, 'Pretty Baby'),
#  (20, 'She Suits Me To A Tee'),
#  (20, 'Stone Crazy'),
#  (20, "Talkin' 'Bout Women Obviously"),
#  (20, 'The Best Of Buddy Guy - The Millenium Collection'),
#  (20, 'Too Many Ways (Alternate)'),
#  (20, 'When My Left Eye Jumps'),
#  (21, 'A Luz De Tieta'),
#  (21, 'Atrás Da Verd-E-Rosa Só Não Vai Quem Já Morreu'),
#  (21, 'Bem Devagar'),
#  (21, 'Carolina'),
#  (21, 'Drão'),
#  (21, 'Eclipse Oculto'),
#  (21, 'Esse Cara'),
#  (21, 'Jorge Da Capadócia'),
#  (21, 'Linha Do Equador'),
#  (21, 'Meditação'),
#  (21, 'Mel'),
#  (21, 'Odara'),
#  (21, 'Prenda Minha'),
#  (21, 'Saudosismo'),
#  (21, 'Sozinho'),
#  (21, 'Terra'),
#  (21, 'Texto "Verdade Tropical"'),
#  (21, 'Vida Boa'),
#  (22, "Sozinho (Caêdrum 'n' Bass)"),
#  (22, 'Sozinho (Hitmakers Classic Mix)'),
#  (22, 'Sozinho (Hitmakers Classic Radio Edit)'),
#  (22, 'Sozinho Remix Ao Vivo'),
#  (23, 'A Banda'),
#  (23, 'Alegria, Alegria'),
#  (23, 'Apesar De Você'),
#  (23, 'Atras Da Porta'),
#  (23, 'Brejo Da Cruz'),
#  (23, 'Bye, Bye Brasil'),
#  (23, 'Carolina'),
#  (23, 'Com Açúcar E Com Afeto'),
#  (23, 'Construção / Deus Lhe Pague'),
#  (23, 'Essa Moça Ta Diferente'),
#  (23, 'Fora Da Ordem'),
#  (23, 'Geni E O Zepelim'),
#  (23, "Gota D'água"),
#  (23, 'Meia-Lua Inteira'),
#  (23, 'Menino Do Rio'),
#  (23, 'Meu Caro Amigo'),
#  (23, 'Minha Historia'),
#  (23, 'Morena De Angola'),
#  (23, 'O Estrangeiro'),
#  (23, 'O Leaozinho'),
#  (23, 'O Que Será (À Flor Da Terra)'),
#  (23, 'Podres Poderes'),
#  (23, 'Qualquer Coisa'),
#  (23, 'Queixa'),
#  (23, 'Samba De Orly'),
#  (23, 'Sampa'),
#  (23, 'Tatuagem'),
#  (23, 'Terra'),
#  (23, 'Trocando Em Miúdos'),
#  (23, 'Um Indio'),
#  (23, 'Vai Passar'),
#  (23, 'Vai Trabalhar Vagabundo'),
#  (23, 'Voce Nao Entende Nada - Cotidiano'),
#  (23, 'Voce e Linda'),
#  (24, 'Afrociberdelia'),
#  (24, 'Amor De Muito'),
#  (24, 'Baião Ambiental [Instrumental]'),
#  (24, 'Corpo De Lama'),
#  (24, 'Criança De Domingo'),
#  (24, 'Enquanto O Mundo Explode'),
#  (24, 'Etnia'),
#  (24, 'Interlude Zumbi'),
#  (24, 'Macô'),
#  (24, 'Manguetown'),
#  (24, 'Maracatu Atômico'),
#  (24, 'Maracatu Atômico [Atomic Version]'),
#  (24, 'Maracatu Atômico [Ragga Mix]'),
#  (24, 'Maracatu Atômico [Trip Hop]'),
#  (24, 'Mateus Enter'),
#  (24, 'O Cidadão Do Mundo'),
#  (24, 'O Encontro De Isaac Asimov Com Santos Dumont No Céu'),
#  (24, 'Quilombo Groove [Instrumental]'),
#  (24, 'Samba Do Lado'),
#  (24, 'Samidarish [Instrumental]'),
#  (24, 'Sangue De Bairro'),
#  (24, 'Sobremesa'),
#  (24, 'Um Passeio No Mundo Livre'),
#  (24, 'Um Satélite Na Cabeça'),
#  (25, 'Antene Se'),
#  (25, 'Banditismo Por Uma Questa'),
#  (25, 'Cidade'),
#  (25, 'Computadores Fazem Arte'),
#  (25, 'Da Lama Ao Caos'),
#  (25, 'Lixo Do Mangue'),
#  (25, 'Maracatu De Tiro Certeiro'),
#  (25, 'Praiera'),
#  (25, 'Rios Pontes & Overdrives'),
#  (25, 'Risoflora'),
#  (25, 'Salustiano Song'),
#  (25, 'Samba Makossa'),
#  (26, 'A Cor Do Sol'),
#  (26, 'A Estrada'),
#  (26, 'A Sombra Da Maldade'),
#  (26, 'Acústico MTV [Live]'),
#  (26, 'Berlim'),
#  (26, 'Conciliação'),
#  (26, 'Extra'),
#  (26, 'Firmamento'),
#  (26, 'Girassol'),
#  (26, 'Johnny B. Goode'),
#  (26, 'Já Foi'),
#  (26, 'Mensagem'),
#  (26, 'O Erê'),
#  (26, 'Onde Você Mora?'),
#  (26, 'Pensamento'),
#  (26, 'Podes Crer'),
#  (26, 'Realidade Virtual'),
#  (26, 'Soldado Da Paz'),
#  (27, 'A Cor Do Sol'),
#  (27, 'A Estrada'),
#  (27, 'A Sombra Da Maldade'),
#  (27, 'Cidade Negra - Hits'),
#  (27, 'Doutor'),
#  (27, 'Downtown'),
#  (27, 'Eu Também Quero Beijar'),
#  (27, 'Falar A Verdade'),
#  (27, 'Firmamento'),
#  (27, 'Na Frente Da TV'),
#  (27, 'O Erê'),
#  (27, 'Onde Você Mora?'),
#  (27, 'Pensamento'),
#  (27, 'Realidade Virtual'),
#  (27, 'Sábado A Noite'),
#  (28, 'Amor Demais'),
#  (28, 'Cada Um Cada Um (A Namoradeira)'),
#  (28, 'Felicidade Urgente'),
#  (28, 'Flor Do Futuro'),
#  (28, 'Férias'),
#  (28, 'Gostava Tanto De Você'),
#  (28, 'Linha Do Equador'),
#  (28, 'Livre Pra Viver'),
#  (28, 'Na Pista'),
#  (28, 'Noite Do Prazer'),
#  (28, 'À Francesa'),
#  (29, 'Axé Bahia 2001'),
#  (29, 'Bate Lata'),
#  (29, 'Daniela'),
#  (29, 'Dig-Dig, Lambe-Lambe (Ao Vivo)'),
#  (29, 'Garotas do Brasil'),
#  (29, 'Latinha de Cerveja'),
#  (29, 'Lavadeira'),
#  (29, 'Levada do Amor (Ailoviu)'),
#  (29, 'My Love'),
#  (29, 'Pererê'),
#  (29, 'Reboladeira'),
#  (29, 'Reggae Tchan'),
#  (29, 'Tapa Aqui, Descobre Ali'),
#  (29, 'TriboTchan'),
#  (29, 'É que Nessa Encarnação Eu Nasci Manga'),
#  (30, 'BBC Sessions [Disc 1] [Live]'),
#  (30, 'Communication Breakdown'),
#  (30, 'Communication Breakdown(2)'),
#  (30, 'Communication Breakdown(3)'),
#  (30, 'Dazed and Confused'),
#  (30, 'How Many More Times'),
#  (30, "I Can't Quit You Baby"),
#  (30, "I Can't Quit You Baby(2)"),
#  (30, "Somethin' Else"),
#  (30, 'The Girl I Love She Got Long Black Wavy Hair'),
#  (30, 'Travelling Riverside Blues'),
#  (30, 'What is and Should Never Be'),
#  (30, 'Whole Lotta Love'),
#  (30, 'You Shook Me'),
#  (30, 'You Shook Me(2)'),
#  (31, '200 Years Old'),
#  (31, 'Advance Romance'),
#  (31, 'Bongo Fury'),
#  (31, 'Carolina Hard-Core Ecstasy'),
#  (31, 'Cucamonga'),
#  (31, 'Debra Kadabra'),
#  (31, 'Man With The Woman Head'),
#  (31, 'Muffin Man'),
#  (31, "Poofter's Froth Wyoming Plans Ahead"),
#  (31, 'Sam With The Showing Scalp Flat Top'),
#  (32, 'Aguia De Ouro 2001'),
#  (32, 'Camisa Verde 2001'),
#  (32, 'Carnaval 2001'),
#  (32, 'Gavioes 2001'),
#  (32, 'Ipiranga 2001'),
#  (32, 'Leandro De Itaquera 2001'),
#  (32, 'Mocidade Alegre 2001'),
#  (32, 'Morro Da Casa Verde 2001'),
#  (32, 'Nene 2001'),
#  (32, 'Perola Negra 2001'),
#  (32, 'Rosas De Ouro 2001'),
#  (32, 'Sao Lucas 2001'),
#  (32, 'Tucuruvi 2001'),
#  (32, 'Vai-Vai 2001'),
#  (32, 'X-9 2001'),
#  (33, 'A Paz'),
#  (33, 'All Star'),
#  (33, 'Ando Meio Desligado'),
#  (33, 'Chill: Brazil (Disc 1)'),
#  (33, 'Guanabara'),
#  (33, 'Maria Fumaça'),
#  (33, 'Mas Que Nada'),
#  (33, 'Menina Bonita'),
#  (33, 'Menino do Rio'),
#  (33, 'Mistério da Raça'),
#  (33, 'Pescador de Ilusões'),
#  (33, 'Pode Parar'),
#  (33, 'Samba da Bençaco'),
#  (33, 'Sambassim (dj patife remix)'),
#  (33, 'Vôo Sobre o Horizonte'),
#  (33, 'Wave (Vou te Contar)'),
#  (33, 'À Vontade (Live Mix)'),
#  (33, 'Água de Beber'),
#  (34, 'Abrir A Porta'),
#  (34, 'Alice'),
#  (34, 'Alô Alô Marciano'),
#  (34, 'Bumbo Da Mangueira'),
#  (34, 'Chill: Brazil (Disc 2)'),
#  (34, 'Eu Vim Da Bahia - Live'),
#  (34, 'Garota De Ipanema'),
#  (34, 'Linha Do Horizonte'),
#  (34, 'Momentos Que Marcam'),
#  (34, 'Mr Funk Samba'),
#  (34, 'Only A Dream In Rio'),
#  (34, 'Por Você'),
#  (34, 'Santo Antonio'),
#  (34, 'Só Tinha De Ser Com Você'),
#  (34, 'Tanto Tempo'),
#  (34, 'Tarde Em Itapoã'),
#  (34, 'Tim Tim Por Tim Tim'),
#  (34, 'Um Jantar Pra Dois'),
#  (35, 'Astronomy'),
#  (35, 'Die Die My Darling'),
#  (35, 'Free Speech For The Dumb'),
#  (35, 'Garage Inc. (Disc 1)'),
#  (35, "It's Electric"),
#  (35, 'Loverman'),
#  (35, 'Mercyful Fate'),
#  (35, 'Sabbra Cadabra'),
#  (35, 'The More I See'),
#  (35, "Tuesday's Gone"),
#  (35, 'Turn The Page'),
#  (35, 'Whiskey In The Jar'),
#  (36, 'A Kind Of Magic'),
#  (36, 'Breakthru'),
#  (36, 'Friends Will Be Friends'),
#  (36, 'Greatest Hits II'),
#  (36, 'Hammer To Fall'),
#  (36, 'Headlong'),
#  (36, 'I Want It All'),
#  (36, 'I Want To Break Free'),
#  (36, "I'm Going Slightly Mad"),
#  (36, 'Innuendo'),
#  (36, "It's A Hard Life"),
#  (36, 'One Vision'),
#  (36, 'Radio GA GA'),
#  (36, 'The Invisible Man'),
#  (36, 'The Miracle'),
#  (36, 'The Show Must Go On'),
#  (36, 'Under Pressure'),
#  (36, 'Who Wants To Live Forever'),
#  (37, 'Beth'),
#  (37, 'Black Diamond'),
#  (37, 'Calling Dr. Love'),
#  (37, 'Cold Gin'),
#  (37, 'Detroit Rock City'),
#  (37, 'Deuce'),
#  (37, 'Do You Love Me'),
#  (37, "God Gave Rock 'n' Roll To You"),
#  (37, 'God Of Thunder'),
#  (37, "Goin' Blind"),
#  (37, 'Greatest Kiss'),
#  (37, 'Hard Luck Woman'),
#  (37, 'I Was Made For Loving You'),
#  (37, 'Love Gun'),
#  (37, 'Plaster Caster'),
#  (37, 'Rock And Roll All Nite'),
#  (37, 'She'),
#  (37, 'Shock Me'),
#  (37, 'Shout It Out Loud'),
#  (37, 'Strutter'),
#  (37, 'Sure Know Something'),
#  (38, 'As We Sleep'),
#  (38, 'Believe'),
#  (38, 'Best Thing'),
#  (38, 'De La Luz'),
#  (38, 'Heart of the Night'),
#  (38, 'J Squared'),
#  (38, 'Midnight'),
#  (38, 'Playtime'),
#  (38, 'Surrender'),
#  (38, "Valentino's"),
#  (38, 'Westwood Moon'),
#  (38, 'When Evening Falls'),
#  (39, 'Basket Case'),
#  (39, 'Brain Stew'),
#  (39, 'Geek Stink Breath'),
#  (39, 'Good Riddance (Time Of Your Life)'),
#  (39, "Hitchin' A Ride"),
#  (39, 'International Superhits'),
#  (39, 'J.A.R. (Jason Andrew Relva)'),
#  (39, 'Jaded'),
#  (39, 'Longview'),
#  (39, "Macy's Day Parade"),
#  (39, 'Maria'),
#  (39, 'Minority'),
#  (39, 'Nice Guys Finish Last'),
#  (39, 'Poprocks And Coke'),
#  (39, 'Redundant'),
#  (39, 'She'),
#  (39, 'Stuck With Me'),
#  (39, 'Waiting'),
#  (39, 'Walking Contradiction'),
#  (39, 'Warning'),
#  (39, 'Welcome To Paradise'),
#  (39, 'When I Come Around'),
#  (40, 'Cry For Love'),
#  (40, "Don't Lie To Me"),
#  (40, "Don't You Cry"),
#  (40, 'Into The Light'),
#  (40, 'Living On Love'),
#  (40, 'Love Is Blind'),
#  (40, 'Midnight Blue'),
#  (40, 'River Song'),
#  (40, 'She Give Me ...'),
#  (40, 'Slave'),
#  (40, 'Too Many Tears'),
#  (40, 'Wherever You May Go'),
#  (41, 'Com A Perna No Mundo'),
#  (41, 'Começaria Tudo Outra Vez'),
#  (41, 'Comportamento Geral'),
#  (41, 'Diga Lá, Coração'),
#  (41, 'E Vamos À Luta'),
#  (41, 'Espere Por Mim, Morena'),
#  (41, 'Eu Apenas Queria Que Voçê Soubesse'),
#  (41, 'Grito De Alerta'),
#  (41, 'Lindo Lago Do Amor'),
#  (41, 'Meus Momentos'),
#  (41, 'Não Dá Mais Pra Segurar (Explode Coração)'),
#  (41, 'O Que É O Que É ?'),
#  (41, 'Ponto De Interrogação'),
#  (41, 'Sangrando'),
#  (41, 'Um Homem Também Chora (Guerreiro Menino)'),
#  (42, 'A E O Z'),
#  (42, 'Ando Meio Desligado'),
#  (42, 'Baby'),
#  (42, 'Balada Do Louco'),
#  (42, 'Banho De Lua'),
#  (42, 'Bat Macumba'),
#  (42, 'Chão De Estrelas'),
#  (42, 'Desculpe Babe'),
#  (42, 'Meu Refrigerador Não Funciona'),
#  (42, 'Minha História'),
#  (42, 'Panis Et Circenses'),
#  (42, 'Posso Perder Minha Mulher, Minha Mãe, Desde Que Eu Tenha O Rock And Roll'),
#  (42, 'Rita Lee'),
#  (42, 'Top Top'),
#  (42, 'Vida De Cachorro'),
#  (43, 'Burn'),
#  (43, 'Gypsy'),
#  (43, 'Lady Double Dealer'),
#  (43, 'MK III The Final Concerts [Disc 1]'),
#  (43, 'Mistreated'),
#  (43, 'Smoke On The Water'),
#  (43, 'Stormbringer'),
#  (43, 'You Fool No One'),
#  (44, 'Custard Pie'),
#  (44, 'Houses Of The Holy'),
#  (44, 'In My Time Of Dying'),
#  (44, 'Kashmir'),
#  (44, 'Physical Graffiti [Disc 1]'),
#  (44, 'The Rover'),
#  (44, 'Trampled Under Foot'),
#  (45, 'Beija-Flor'),
#  (45, 'Caprichosos'),
#  (45, 'Grande Rio'),
#  (45, 'Imperatriz'),
#  (45, 'Império Serrano'),
#  (45, 'Mangueira'),
#  (45, 'Mocidade'),
#  (45, 'Portela'),
#  (45, 'Salgueiro'),
#  (45, 'Sambas De Enredo 2001'),
#  (45, 'Tradição'),
#  (45, 'Tuiuti'),
#  (45, 'Unidos Da Tijuca'),
#  (45, 'União Da Ilha'),
#  (45, 'Viradouro'),
#  (46, '(Da Le) Yaleo'),
#  (46, 'Africa Bamba'),
#  (46, 'Corazon Espinado'),
#  (46, 'Do You Like The Way'),
#  (46, 'El Farol'),
#  (46, 'Love Of My Life'),
#  (46, 'Maria Maria'),
#  (46, 'Migra'),
#  (46, 'Primavera'),
#  (46, 'Put Your Lights On'),
#  (46, 'Smooth'),
#  (46, 'Supernatural'),
#  (46, 'The Calling'),
#  (46, 'Wishing It Was'),
#  (47, 'A Rua'),
#  (47, 'Agora Que O Dia Acordou'),
#  (47, 'Baixo Rio'),
#  (47, 'Do You Have Other Loves?'),
#  (47, 'Entre E Ouça'),
#  (47, 'Já!!!'),
#  (47, 'Manuel'),
#  (47, 'Seis Da Tarde'),
#  (47, 'Solução'),
#  (47, 'Sombras Do Meu Destino'),
#  (47, 'The Best of Ed Motta'),
#  (47, 'Um Contrato Com Deus'),
#  (47, 'Um Jantar Pra Dois'),
#  (47, 'Um Love'),
#  (47, 'Vamos Dançar'),
#  (48, "'Round Midnight"),
#  (48, 'Bye Bye Blackbird'),
#  (48, 'Compulsion'),
#  (48, 'Generique'),
#  (48, 'Jeru'),
#  (48, 'New Rhumba'),
#  (48, "Now's The Time"),
#  (48, 'So What'),
#  (48, 'Someday My Prince Will Come'),
#  (48, 'Summertime'),
#  (48, 'Tempus Fugit'),
#  (48, 'The Essential Miles Davis [Disc 1]'),
#  (48, 'The Pan Piper'),
#  (48, "Walkin'"),
#  (49, 'Black Satin'),
#  (49, 'E.S.P.'),
#  (49, 'Jean Pierre (Live)'),
#  (49, 'Little Church (Live)'),
#  (49, 'Miles Runs The Voodoo Down'),
#  (49, 'My Funny Valentine (Live)'),
#  (49, 'Nefertiti'),
#  (49, 'Petits Machins (Little Stuff)'),
#  (49, 'Portia'),
#  (49, 'The Essential Miles Davis [Disc 2]'),
#  (49, 'Time After Time'),
#  (50, 'Going Down / Highway Star'),
#  (50, 'Mistreated (Alternate Version)'),
#  (50, "Space Truckin'"),
#  (50, 'The Final Concerts (Disc 2)'),
#  (50, 'You Fool No One (Alternate Version)'),
#  (51, 'Blue Rythm Fantasy'),
#  (51, 'Boogie Blues'),
#  (51, 'Bop Boogie'),
#  (51, 'Coronation Drop'),
#  (51, 'Disc Jockey Jump'),
#  (51, "Don't Take Your Love From Me"),
#  (51, 'Drum Boogie'),
#  (51, 'How High The Moon'),
#  (51, "I'm Coming Virginia"),
#  (51, 'Imagination'),
#  (51, 'Jeepers Creepers'),
#  (51, 'Jungle Drums'),
#  (51, 'Leave Us Leap'),
#  (51, 'Lemon Drop'),
#  (51, 'Let Me Off Uptown'),
#  (51, 'Midget'),
#  (51, 'Opus No.1'),
#  (51, 'Overtime'),
#  (51, "Payin' Them Dues Blues"),
#  (51, 'Showcase'),
#  (51, 'Swedish Schnapps'),
#  (51, "Up An' Atom"),
#  (52, 'Berimbau'),
#  (52, 'Canto De Ossanha'),
#  (52, 'Carta Ao Tom 74'),
#  (52, 'Como É Duro Trabalhar'),
#  (52, 'Deixa'),
#  (52, 'Formosa'),
#  (52, 'Minha Namorada'),
#  (52, 'Onde Anda Você'),
#  (52, 'Por Que Será'),
#  (52, 'Pot-Pourri N.º 2'),
#  (52, 'Pot-Pourri N.º 4'),
#  (52, 'Pot-Pourri N.º 5'),
#  (52, 'Samba Da Bênção'),
#  (52, 'Samba Da Volta'),
#  (52, 'Samba Em Prelúdio'),
#  (52, 'Vinícius De Moraes - Sem Limite'),
#  (53, 'Aquarela (Toquinho)'),
#  (53, 'As Rosas Não Falam (Beth Carvalho)'),
#  (53, 'Caçador de Mim (Sá & Guarabyra)'),
#  (53, 'Chão de Giz (Elba Ramalho)'),
#  (53, 'Começaria Tudo Outra Vez (Maria Creuza)'),
#  (53, 'Coração do Agreste (Fafá de Belém)'),
#  (53, 'Dona (Roupa Nova)'),
#  (53, 'Garota de Ipanema (Dick Farney)'),
#  (53, 'Linha de Passe (João Bosco)'),
#  (53, 'Marina (Dorival Caymmi)'),
#  (53, 'Pela Luz dos Olhos Teus (Miúcha e Tom Jobim)'),
#  (53, 'Preciso Apender a Viver Só (Maysa)'),
#  (53, 'Romaria (Renato Teixeira)'),
#  (53, 'Vozes do MPB'),
#  (53, 'Wave (Os Cariocas)'),
#  (54, 'Bad Moon Rising'),
#  (54, 'Chronicle, Vol. 1'),
#  (54, 'Commotion'),
#  (54, 'Down On The Corner'),
#  (54, 'Fortunate Son'),
#  (54, 'Green River'),
#  (54, 'Have You Ever Seen The Rain?'),
#  (54, 'Hey Tonight'),
#  (54, 'I Heard It Through The Grapevine'),
#  (54, 'I Put A Spell On You'),
#  (54, 'Lodi'),
#  (54, 'Long As I Can See The Light'),
#  (54, "Lookin' Out My Back Door"),
#  (54, 'Proud Mary'),
#  (54, 'Run Through The Jungle'),
#  (54, 'Someday Never Comes'),
#  (54, 'Susie Q'),
#  (54, 'Sweet Hitch-Hiker'),
#  (54, "Travelin' Band"),
#  (54, 'Up Around The Bend'),
#  (54, "Who'll Stop The Rain"),
#  (55, '(Wish I Could) Hideaway'),
#  (55, 'Before You Accuse Me'),
#  (55, 'Born On The Bayou'),
#  (55, 'Born To Move'),
#  (55, 'Chronicle, Vol. 2'),
#  (55, 'Cotton Fields'),
#  (55, "Don't Look Now"),
#  (55, 'Good Golly Miss Molly'),
#  (55, 'Hello Mary Lou'),
#  (55, 'It Came Out Of The Sky'),
#  (55, "It's Just A Thought"),
#  (55, "Lookin' For A Reason"),
#  (55, 'Molina'),
#  (55, 'My Baby Left Me'),
#  (55, 'Night Time Is The Right Time'),
#  (55, 'Pagan Baby'),
#  (55, 'Suzie-Q, Pt. 2'),
#  (55, 'The Midnight Special'),
#  (55, 'Tombstone Shadow'),
#  (55, 'Walking On The Water'),
#  (55, 'Wrote A Song For Everyone'),
#  (56, '1° De Julho'),
#  (56, 'Brasil'),
#  (56, 'Coroné Antonio Bento'),
#  (56, 'Cássia Eller - Coleção Sem Limite [Disc 2]'),
#  (56, 'Eu Sou Neguinha (Ao Vivo)'),
#  (56, 'Gatas Extraordinárias'),
#  (56, 'Geração Coca-Cola (Ao Vivo)'),
#  (56, 'Juventude Transviada (Ao Vivo)'),
#  (56, 'Lanterna Dos Afogados'),
#  (56, 'Meu Mundo Fica Completo (Com Você)'),
#  (56, 'Música Urbana 2'),
#  (56, 'Não Sei O Que Eu Quero Da Vida'),
#  (56, 'Palavras Ao Vento'),
#  (56, 'Vida Bandida (Ao Vivo)'),
#  (56, 'Você Passa, Eu Acho Graça (Ao Vivo)'),
#  (56, 'Woman Is The Nigger Of The World (Ao Vivo)'),
#  (57, 'Admirável Gado Novo'),
#  (57, 'Blues Da Piedade'),
#  (57, 'Cássia Eller - Sem Limite [Disc 1]'),
#  (57, 'E.C.T.'),
#  (57, 'Eleanor Rigby'),
#  (57, 'Malandragem'),
#  (57, 'Metrô. Linha 743'),
#  (57, 'Mis Penas Lloraba Yo (Ao Vivo) Soy Gitano (Tangos)'),
#  (57, 'Na Cadência Do Samba'),
#  (57, 'Não Deixe O Samba Morrer - Cassia Eller e Alcione'),
#  (57, 'Nós (Ao Vivo)'),
#  (57, 'O Segundo Sol'),
#  (57, 'Rubens'),
#  (57, 'Smells Like Teen Spirit (Ao Vivo)'),
#  (57, 'Socorro'),
#  (57, 'Todo Amor Que Houver Nesta Vida'),
#  (58, 'Come Taste The Band'),
#  (58, "Comin' Home"),
#  (58, 'Dealer'),
#  (58, 'Drifter'),
#  (58, "Gettin' Tighter"),
#  (58, 'I Need Love'),
#  (58, 'Lady Luck'),
#  (58, 'Love Child'),
#  (58, "This Time Around / Owed to 'G' [Instrumental]"),
#  (58, 'You Keep On Moving'),
#  (59, 'Bloodsucker'),
#  (59, 'Child In Time'),
#  (59, 'Deep Purple In Rock'),
#  (59, 'Flight Of The Rat'),
#  (59, "Hard Lovin' Man"),
#  (59, 'Into The Fire'),
#  (59, 'Living Wreck'),
#  (59, 'Speed King'),
#  (60, "Anyone's Daughter"),
#  (60, 'Fireball'),
#  (60, 'Fools'),
#  (60, 'No No No'),
#  (60, 'No One Came'),
#  (60, 'Strange Kind Of Woman'),
#  (60, 'The Mule'),
#  (61, 'Bad Attitude'),
#  (61, 'Black Night'),
#  (61, 'Call Of The Wild'),
#  (61, 'Child In Time (Son Of Aleric - Instrumental)'),
#  (61, 'Hush'),
#  (61, 'Knocking At Your Back Door'),
#  (61, "Knocking at Your Back Door: The Best Of Deep Purple in the 80's"),
#  (61, "Nobody's Home"),
#  (61, 'Perfect Strangers'),
#  (61, 'Smoke On The Water'),
#  (61, 'Space Trucking'),
#  (61, 'The Unwritten Law'),
#  (62, 'Highway Star'),
#  (62, 'Lazy'),
#  (62, 'Machine Head'),
#  (62, "Maybe I'm A Leo"),
#  (62, 'Never Before'),
#  (62, 'Pictures Of Home'),
#  (62, 'Smoke On The Water'),
#  (62, "Space Truckin'"),
#  (63, 'A Castle Full Of Rascals'),
#  (63, 'A Touch Away'),
#  (63, "Cascades : I'm Not Your Lover"),
#  (63, 'Hey Cisco'),
#  (63, 'Loosen My Strings'),
#  (63, 'Purpendicular'),
#  (63, "Rosa's Cantina"),
#  (63, 'Somebody Stole My Guitar'),
#  (63, 'Sometimes I Feel Like Screaming'),
#  (63, 'Soon Forgotten'),
#  (63, 'The Aviator'),
#  (63, 'The Purpendicular Waltz'),
#  (63, 'Vavoom : Ted The Mechanic'),
#  (64, 'Breakfast In Bed'),
#  (64, 'Fire In The Basement'),
#  (64, 'Fortuneteller'),
#  (64, 'King Of Dreams'),
#  (64, 'Love Conquers All'),
#  (64, 'Slaves And Masters'),
#  (64, 'The Cut Runs Deep'),
#  (64, 'Too Much Is Not Enough'),
#  (64, 'Truth Hurts'),
#  (64, 'Wicked Ways'),
#  (65, 'High Ball Shooter'),
#  (65, 'Hold On'),
#  (65, 'Holy Man'),
#  (65, 'Lady Double Dealer'),
#  (65, "Love Don't Mean a Thing"),
#  (65, 'Soldier Of Fortune'),
#  (65, 'Stormbringer'),
#  (65, 'The Gypsy'),
#  (65, "You Can't Do it Right (With the One You Love)"),
#  (66, 'A Twist In The Tail'),
#  (66, 'Anya'),
#  (66, 'Lick It Up'),
#  (66, 'Nasty Piece Of Work'),
#  (66, "One Man's Meat"),
#  (66, 'Ramshackle Man'),
#  (66, 'Solitaire'),
#  (66, 'Talk About Love'),
#  (66, 'The Battle Rages On'),
#  (66, 'Time To Kill'),
#  (67, 'Action'),
#  (67, 'Animal'),
#  (67, 'Armageddon It'),
#  (67, "Bringin' On The Heartbreak"),
#  (67, 'Have You Ever Needed Someone So Bad'),
#  (67, 'Heaven Is'),
#  (67, 'Hysteria'),
#  (67, "Let's Get Rocked"),
#  (67, 'Love Bites'),
#  (67, 'Make Love Like A Man'),
#  (67, 'Photograph'),
#  (67, 'Pour Some Sugar On Me'),
#  (67, 'Rock Of Ages'),
#  (67, 'Rocket'),
#  (67, 'Two Steps Behind [Acoustic Version]'),
#  (67, "Vault: Def Leppard's Greatest Hits"),
#  (67, 'When Love & Hate Collide'),
#  (68, 'Baltimore, DC'),
#  (68, 'Groovus Interruptus'),
#  (68, 'In Time'),
#  (68, 'Otay'),
#  (68, 'Outbreak'),
#  (68, 'Paris On Mine'),
#  (68, 'Plan B'),
#  (68, 'Roll Call'),
#  (68, 'Talkin Loud and Saying Nothin'),
#  (69, 'Acelerou'),
#  (69, 'Boa Noite'),
#  (69, 'Cigano'),
#  (69, 'Djavan Ao Vivo - Vol. 02'),
#  (69, 'Esquinas'),
#  (69, 'Eu Te Devoro'),
#  (69, 'Faltando Um Pedaço'),
#  (69, 'Fato Consumado'),
#  (69, 'Lilás'),
#  (69, 'Meu Bem-Querer'),
#  (69, 'Pétala'),
#  (69, 'Se...'),
#  (69, 'Um Amor Puro'),
#  (69, 'Álibi'),
#  (70, 'A Carta'),
#  (70, 'Acelerou'),
#  (70, 'Amar É Tudo'),
#  (70, 'Azul'),
#  (70, 'Açai'),
#  (70, 'Djavan Ao Vivo - Vol. 1'),
#  (70, 'Flor De Lis'),
#  (70, 'Nem Um Dia'),
#  (70, 'Oceano'),
#  (70, 'Samurai'),
#  (70, 'Seduzir'),
#  (70, 'Serrado'),
#  (70, 'Sina'),
#  (70, 'Um Amor Puro'),
#  (71, 'Alô, Alô, Marciano'),
#  (71, 'Aprendendo A Jogar'),
#  (71, 'As Aparências Enganam'),
#  (71, 'Atrás da Porta'),
#  (71, 'Casa no Campo'),
#  (71, 'Dois Pra Lá, Dois Pra Cá'),
#  (71, 'Elis Regina-Minha História'),
#  (71, 'Fascinação'),
#  (71, 'Madalena'),
#  (71, 'Maria Rosa'),
#  (71, 'Me Deixas Louca'),
#  (71, 'O Bêbado e a Equilibrista'),
#  (71, 'O Mestre-Sala dos Mares'),
#  (71, 'Romaria'),
#  (71, 'Saudosa Maloca'),
#  (72, 'After Midnight'),
#  (72, 'Badge'),
#  (72, 'Bell Bottom Blues'),
#  (72, 'Cocaine'),
#  (72, 'Crossroads'),
#  (72, "I Can't Stand It"),
#  (72, 'I Feel Free'),
#  (72, 'I Shot The Sheriff'),
#  (72, 'Knockin On Heavens Door'),
#  (72, 'Lay Down Sally'),
#  (72, 'Layla'),
#  (72, 'Let It Grow'),
#  (72, 'Promises'),
#  (72, 'Strange Brew'),
#  (72, 'Sunshine Of Your Love'),
#  (72, 'Swing Low Sweet Chariot'),
#  (72, 'The Cream Of Clapton'),
#  (72, 'White Room'),
#  (72, 'Wonderful Tonight'),
#  (73, 'A Novidade'),
#  (73, 'A Paz'),
#  (73, 'Alberta'),
#  (73, 'Aquele Abraço'),
#  (73, 'Before You Accuse Me'),
#  (73, 'Beira Mar'),
#  (73, 'Drão'),
#  (73, 'Esotérico'),
#  (73, 'Expresso 2222'),
#  (73, 'Hey Hey'),
#  (73, 'Layla'),
#  (73, 'Lonely Stranger'),
#  (73, 'Malted Milk'),
#  (73, "Nobody Knows You When You're Down & Out"),
#  (73, 'Old Love'),
#  (73, 'Palco'),
#  (73, 'Parabolicamará'),
#  (73, 'Realce'),
#  (73, 'Refazenda'),
#  (73, "Rollin' And Tumblin'"),
#  (73, 'Running On Faith'),
#  (73, 'Sampa'),
#  (73, 'San Francisco Bay Blues'),
#  (73, 'Signe'),
#  (73, 'Sítio Do Pica-Pau Amarelo'),
#  (73, 'Tears In Heaven'),
#  (73, 'Tempo Rei'),
#  (73, 'Tenho Sede'),
#  (73, 'Toda Menina Baiana'),
#  (73, 'Unplugged'),
#  (73, "Walkin' Blues"),
#  (74, 'Album Of The Year'),
#  (74, 'Ashes To Ashes'),
#  (74, 'Collision'),
#  (74, 'Got That Feeling'),
#  (74, 'Helpless'),
#  (74, 'Home Sick Home'),
#  (74, 'Last Cup Of Sorrow'),
#  ...]

# %% [markdown]
# ### Exercise 2
#
# In some cases, artists will create eponymous albums, i.e. albums with the same name as the artist. Write a query that will highlight all eponymous albums as well as non-eponymous albums.
#
#
# **NOTE**: At the moment, SQLite does not support the `FULL OUTER JOIN` statement. Emulate it using a `LEFT JOIN` and a `UNION` operator.

# %%
# %%sql
# SELECT
#     ar.Name,
#     a.Title
# FROM
#     artists ar
# LEFT JOIN
#     albums AS a
#     ON ar.Name = a.Title
#
# UNION
#
# SELECT
#     ar.Name,
#     a.Title
# FROM
#     artists ar
# LEFT JOIN
#     albums AS a
#     ON ar.Name = a.Title;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('AC/DC', None),
#  ('Accept', None),
#  ('Aerosmith', None),
#  ('Alanis Morissette', None),
#  ('Alice In Chains', None),
#  ('Antônio Carlos Jobim', None),
#  ('Apocalyptica', None),
#  ('Audioslave', 'Audioslave'),
#  ('BackBeat', None),
#  ('Billy Cobham', None),
#  ('Black Label Society', None),
#  ('Black Sabbath', 'Black Sabbath'),
#  ('Body Count', 'Body Count'),
#  ('Bruce Dickinson', None),
#  ('Buddy Guy', None),
#  ('Caetano Veloso', None),
#  ('Chico Buarque', None),
#  ('Chico Science & Nação Zumbi', None),
#  ('Cidade Negra', None),
#  ('Cláudio Zoli', None),
#  ('Various Artists', None),
#  ('Led Zeppelin', None),
#  ('Frank Zappa & Captain Beefheart', None),
#  ('Marcos Valle', None),
#  ('Milton Nascimento & Bebeto', None),
#  ('Azymuth', None),
#  ('Gilberto Gil', None),
#  ('João Gilberto', None),
#  ('Bebel Gilberto', None),
#  ('Jorge Vercilo', None),
#  ('Baby Consuelo', None),
#  ('Ney Matogrosso', None),
#  ('Luiz Melodia', None),
#  ('Nando Reis', None),
#  ('Pedro Luís & A Parede', None),
#  ('O Rappa', None),
#  ('Ed Motta', None),
#  ('Banda Black Rio', None),
#  ('Fernanda Porto', None),
#  ('Os Cariocas', None),
#  ('Elis Regina', None),
#  ('Milton Nascimento', None),
#  ('A Cor Do Som', None),
#  ('Kid Abelha', None),
#  ('Sandra De Sá', None),
#  ('Jorge Ben', None),
#  ('Hermeto Pascoal', None),
#  ('Barão Vermelho', None),
#  ('Edson, DJ Marky & DJ Patife Featuring Fernanda Porto', None),
#  ('Metallica', None),
#  ('Queen', None),
#  ('Kiss', None),
#  ('Spyro Gyra', None),
#  ('Green Day', None),
#  ('David Coverdale', None),
#  ('Gonzaguinha', None),
#  ('Os Mutantes', None),
#  ('Deep Purple', None),
#  ('Santana', None),
#  ('Santana Feat. Dave Matthews', None),
#  ('Santana Feat. Everlast', None),
#  ('Santana Feat. Rob Thomas', None),
#  ('Santana Feat. Lauryn Hill & Cee-Lo', None),
#  ('Santana Feat. The Project G&B', None),
#  ('Santana Feat. Maná', None),
#  ('Santana Feat. Eagle-Eye Cherry', None),
#  ('Santana Feat. Eric Clapton', None),
#  ('Miles Davis', None),
#  ('Gene Krupa', None),
#  ('Toquinho & Vinícius', None),
#  ('Vinícius De Moraes & Baden Powell', None),
#  ('Vinícius De Moraes', None),
#  ('Vinícius E Qurteto Em Cy', None),
#  ('Vinícius E Odette Lara', None),
#  ('Vinicius, Toquinho & Quarteto Em Cy', None),
#  ('Creedence Clearwater Revival', None),
#  ('Cássia Eller', None),
#  ('Def Leppard', None),
#  ('Dennis Chambers', None),
#  ('Djavan', None),
#  ('Eric Clapton', None),
#  ('Faith No More', None),
#  ('Falamansa', None),
#  ('Foo Fighters', None),
#  ('Frank Sinatra', None),
#  ('Funk Como Le Gusta', None),
#  ('Godsmack', None),
#  ("Guns N' Roses", None),
#  ('Incognito', None),
#  ('Iron Maiden', 'Iron Maiden'),
#  ('James Brown', None),
#  ('Jamiroquai', None),
#  ('JET', None),
#  ('Jimi Hendrix', None),
#  ('Joe Satriani', None),
#  ('Jota Quest', None),
#  ('João Suplicy', None),
#  ('Judas Priest', None),
#  ('Legião Urbana', None),
#  ('Lenny Kravitz', None),
#  ('Lulu Santos', None),
#  ('Marillion', None),
#  ('Marisa Monte', None),
#  ('Marvin Gaye', None),
#  ('Men At Work', None),
#  ('Motörhead', None),
#  ('Motörhead & Girlschool', None),
#  ('Mônica Marianno', None),
#  ('Mötley Crüe', None),
#  ('Nirvana', None),
#  ('O Terço', None),
#  ('Olodum', 'Olodum'),
#  ('Os Paralamas Do Sucesso', None),
#  ('Ozzy Osbourne', None),
#  ('Page & Plant', None),
#  ('Passengers', None),
#  ("Paul D'Ianno", None),
#  ('Pearl Jam', 'Pearl Jam'),
#  ('Peter Tosh', None),
#  ('Pink Floyd', None),
#  ('Planet Hemp', None),
#  ('R.E.M. Feat. Kate Pearson', None),
#  ('R.E.M. Feat. KRS-One', None),
#  ('R.E.M.', None),
#  ('Raimundos', None),
#  ('Raul Seixas', 'Raul Seixas'),
#  ('Red Hot Chili Peppers', None),
#  ('Rush', None),
#  ('Simply Red', None),
#  ('Skank', None),
#  ('Smashing Pumpkins', None),
#  ('Soundgarden', None),
#  ('Stevie Ray Vaughan & Double Trouble', None),
#  ('Stone Temple Pilots', None),
#  ('System Of A Down', None),
#  ('Terry Bozzio, Tony Levin & Steve Stevens', None),
#  ('The Black Crowes', None),
#  ('The Clash', None),
#  ('The Cult', None),
#  ('The Doors', 'The Doors'),
#  ('The Police', None),
#  ('The Rolling Stones', None),
#  ('The Tea Party', None),
#  ('The Who', None),
#  ('Tim Maia', None),
#  ('Titãs', None),
#  ('Battlestar Galactica', None),
#  ('Heroes', None),
#  ('Lost', None),
#  ('U2', None),
#  ('UB40', None),
#  ('Van Halen', 'Van Halen'),
#  ('Velvet Revolver', None),
#  ('Whitesnake', None),
#  ('Zeca Pagodinho', None),
#  ('The Office', None),
#  ('Dread Zeppelin', None),
#  ('Battlestar Galactica (Classic)', None),
#  ('Aquaman', 'Aquaman'),
#  ('Christina Aguilera featuring BigElf', None),
#  ("Aerosmith & Sierra Leone's Refugee Allstars", None),
#  ('Los Lonely Boys', None),
#  ('Corinne Bailey Rae', None),
#  ('Dhani Harrison & Jakob Dylan', None),
#  ('Jackson Browne', None),
#  ('Avril Lavigne', None),
#  ('Big & Rich', None),
#  ("Youssou N'Dour", None),
#  ('Black Eyed Peas', None),
#  ('Jack Johnson', None),
#  ('Ben Harper', None),
#  ('Snow Patrol', None),
#  ('Matisyahu', None),
#  ('The Postal Service', None),
#  ('Jaguares', None),
#  ('The Flaming Lips', None),
#  ("Jack's Mannequin & Mick Fleetwood", None),
#  ('Regina Spektor', None),
#  ('Scorpions', None),
#  ('House Of Pain', None),
#  ('Xis', None),
#  ('Nega Gizza', None),
#  ('Gustavo & Andres Veiga & Salazar', None),
#  ('Rodox', None),
#  ('Charlie Brown Jr.', None),
#  ('Pedro Luís E A Parede', None),
#  ('Los Hermanos', None),
#  ('Mundo Livre S/A', None),
#  ('Otto', None),
#  ('Instituto', None),
#  ('Nação Zumbi', None),
#  ('DJ Dolores & Orchestra Santa Massa', None),
#  ('Seu Jorge', None),
#  ('Sabotage E Instituto', None),
#  ('Stereo Maracana', None),
#  ('Cake', None),
#  ('Aisha Duo', None),
#  ('Habib Koité and Bamada', None),
#  ('Karsh Kale', None),
#  ('The Posies', None),
#  ('Luciana Souza/Romero Lubambo', None),
#  ('Aaron Goldberg', None),
#  ('Nicolaus Esterhazy Sinfonia', None),
#  ('Temple of the Dog', 'Temple of the Dog'),
#  ('Chris Cornell', None),
#  ('Alberto Turco & Nova Schola Gregoriana', None),
#  ('Richard Marlow & The Choir of Trinity College, Cambridge', None),
#  ('English Concert & Trevor Pinnock', None),
#  ('Anne-Sophie Mutter, Herbert Von Karajan & Wiener Philharmoniker', None),
#  ('Hilary Hahn, Jeffrey Kahane, Los Angeles Chamber Orchestra & Margaret Batjer', None),
#  ('Wilhelm Kempff', None),
#  ('Yo-Yo Ma', None),
#  ('Scholars Baroque Ensemble', None),
#  ('Academy of St. Martin in the Fields & Sir Neville Marriner', None),
#  ('Academy of St. Martin in the Fields Chamber Ensemble & Sir Neville Marriner', None),
#  ('Berliner Philharmoniker, Claudio Abbado & Sabine Meyer', None),
#  ('Royal Philharmonic Orchestra & Sir Thomas Beecham', None),
#  ('Orchestre Révolutionnaire et Romantique & John Eliot Gardiner', None),
#  ('Britten Sinfonia, Ivor Bolton & Lesley Garrett', None),
#  ('Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti', None),
#  ('Sir Georg Solti & Wiener Philharmoniker', None),
#  ('Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', None),
#  ('London Symphony Orchestra & Sir Charles Mackerras', None),
#  ('Barry Wordsworth & BBC Concert Orchestra', None),
#  ('Herbert Von Karajan, Mirella Freni & Wiener Philharmoniker', None),
#  ('Eugene Ormandy', None),
#  ('Luciano Pavarotti', None),
#  ('Leonard Bernstein & New York Philharmonic', None),
#  ('Boston Symphony Orchestra & Seiji Ozawa', None),
#  ('Aaron Copland & London Symphony Orchestra', None),
#  ('Ton Koopman', None),
#  ('Sergei Prokofiev & Yuri Temirkanov', None),
#  ('Chicago Symphony Orchestra & Fritz Reiner', None),
#  ('Orchestra of The Age of Enlightenment', None),
#  ('Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', None),
#  ('James Levine', None),
#  ('Berliner Philharmoniker & Hans Rosbaud', None),
#  ('Maurizio Pollini', None),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & William Bennett', None),
#  ('Gustav Mahler', None),
#  ('Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', None),
#  ('Edo de Waart & San Francisco Symphony', None),
#  ('Antal Doráti & London Symphony Orchestra', None),
#  ('Choir Of Westminster Abbey & Simon Preston', None),
#  ('Michael Tilson Thomas & San Francisco Symphony', None),
#  ('Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker', None),
#  ("The King's Singers", None),
#  ('Berliner Philharmoniker & Herbert Von Karajan', None),
#  ('Sir Georg Solti, Sumi Jo & Wiener Philharmoniker', None),
#  ("Christopher O'Riley", None),
#  ('Fretwork', None),
#  ('Amy Winehouse', None),
#  ('Calexico', None),
#  ('Otto Klemperer & Philharmonia Orchestra', None),
#  ('Yehudi Menuhin', None),
#  ('Philharmonia Orchestra & Sir Neville Marriner', None),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', None),
#  ('Les Arts Florissants & William Christie', None),
#  ('The 12 Cellists of The Berlin Philharmonic', None),
#  ('Adrian Leaper & Doreen de Feis', None),
#  ('Roger Norrington, London Classical Players', None),
#  ("Charles Dutoit & L'Orchestre Symphonique de Montréal", None),
#  ('Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', None),
#  ("Kent Nagano and Orchestre de l'Opéra de Lyon", None),
#  ('Julian Bream', None),
#  ('Martin Roscoe', None),
#  ('Göteborgs Symfoniker & Neeme Järvi', None),
#  ('Itzhak Perlman', None),
#  ('Michele Campanella', None),
#  ('Gerald Moore', None),
#  ('Mela Tenenbaum, Pro Musica Prague & Richard Kapp', None),
#  ('Emerson String Quartet', None),
#  ('C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu', None),
#  ('Nash Ensemble', None),
#  ('Philip Glass Ensemble', None)]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Exercise 1
#
# The SQL query uses the `UNION` operator to merge data from two tables, `tracks` and `albums`, into a single list. It selects the `AlbumId` and `Name` columns from the `tracks` table with a "Category" label of "Artist" and combines it with the `AlbumId` and `Title` columns from the `albums` table with a "Category" label of "Album". The `LIMIT 10` clause is used to restrict the output to the first 10 results.

# %%
# %%sql
#
# SELECT t.AlbumId, t.Name, "Artist" AS "Category"
# FROM tracks AS t
#
# UNION
#
# SELECT a.AlbumId, a.Title, "Album" AS "Category"
# FROM albums AS a
#
# LIMIT 10;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'Breaking The Rules', 'Artist'),
#  (1, 'C.O.D.', 'Artist'),
#  (1, 'Evil Walks', 'Artist'),
#  (1, 'For Those About To Rock (We Salute You)', 'Artist'),
#  (1, 'For Those About To Rock We Salute You', 'Album'),
#  (1, 'Inject The Venom', 'Artist'),
#  (1, "Let's Get It Up", 'Artist'),
#  (1, 'Night Of The Long Knives', 'Artist'),
#  (1, 'Put The Finger On You', 'Artist'),
#  (1, 'Snowballed', 'Artist')]

# %% [markdown]
# ### Exercise 2
#
# The SQL query retrieves a list of artist names and album titles, highlighting both eponymous albums (albums with the same name as the artist) and non-eponymous albums. It achieves this by using a combination of `LEFT JOIN` and `UNION ALL` to combine the results of two separate queries. The first query joins the `artists` and `albums` tables by matching the artist's name with the album title, while the second query joins the `albums` and `artists` tables with the same condition. This approach effectively emulates a `FULL OUTER JOIN`, ensuring that all eponymous and non-eponymous albums are included in the final result.

# %%
# %%sql
#
# SELECT
#     ar.Name,
#     a.Title
# FROM
#     artists ar
# LEFT JOIN
#     albums AS a
#     ON ar.Name = a.Title
#
# UNION ALL
#
# SELECT
#     ar.Name,
#     a.Title
# FROM
#     albums AS a
# LEFT JOIN
#     artists AS ar
#     ON ar.Name = a.Title
#
# LIMIT 10;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('AC/DC', None),
#  ('Accept', None),
#  ('Aerosmith', None),
#  ('Alanis Morissette', None),
#  ('Alice In Chains', None),
#  ('Antônio Carlos Jobim', None),
#  ('Apocalyptica', None),
#  ('Audioslave', 'Audioslave'),
#  ('BackBeat', None),
#  ('Billy Cobham', None)]

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
