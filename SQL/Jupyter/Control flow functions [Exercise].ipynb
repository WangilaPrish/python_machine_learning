# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Control flow functions

# %% [markdown]
# In this exercise, we'll use control flow functions to break down a complex problem into its fundamental components.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn to:
# - Use the `IIF` control function to check for a certain condition and return a value for each scenario.
# - Use the `CASE` statement to categorise data in an existing column.

# %% [markdown]
# First, let's load our sample database:

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.
# %load_ext sql

# %%
# Load the Northwind database stored in your local machine. 
# Make sure the file is saved in the same folder as this notebook.
# %sql sqlite:///Northwind.db
# Out:
# 'Connected: @Northwind.db'

# %% [markdown]
# Here is a view of all of our tables in the database:
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Northwind_ERD.png"  style="width:70%";/>
# <br>
# <br>
#     <em>Figure 1: Northwind database ERD</em>
# </div>

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### 1. Categorise employees based on salaries
#
# Using the `Employees` table in the Northwind database, write a SQL query that returns a list of all employees along with a column `HighSalary` that shows 'Yes' if the employee's salary is above \$50,000 and 'No' otherwise.

# %%
# %%sql
# SELECT
#     *,
#     CASE
#         WHEN Salary > 50000 THEN 'Yes'
#         ELSE 'No'
#     END AS HighSalary
# FROM Employees;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(1, 'Davolio', 'Nancy', 'Sales Representative', 'Ms.', '1948-12-08 00:00:00', '1992-05-01 00:00:00', '507 - 20th Ave. E.Apt. 2A', 'Seattle', 'WA', '98122', 'USA', '(206) 555-9857', '5467', 'Education includes a BA in psychology from Colorado State University in 1970.  She also completed "The Art of the Cold Call."  Nancy is a member of Toastmasters International.', 2, 'http://accweb/emmployees/davolio.bmp', 2954.55, 'No'),
#  (2, 'Fuller', 'Andrew', 'Vice President, Sales', 'Dr.', '1952-02-19 00:00:00', '1992-08-14 00:00:00', '908 W. Capital Way', 'Tacoma', 'WA', '98401', 'USA', '(206) 555-9482', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and  ... (150 characters truncated) ... es in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', None, 'http://accweb/emmployees/fuller.bmp', 2254.49, 'No'),
#  (3, 'Leverling', 'Janet', 'Sales Representative', 'Ms.', '1963-08-30 00:00:00', '1992-04-01 00:00:00', '722 Moss Bay Blvd.', 'Kirkland', 'WA', '98033', 'USA', '(206) 555-3412', '3355', 'Janet has a BS degree in chemistry from Boston College (1984).  She has also completed a certificate program in food retailing management.  Janet was hired as a sales associate in 1991 and promoted to sales representative in February 1992.', 2, 'http://accweb/emmployees/leverling.bmp', 3119.15, 'No'),
#  (4, 'Peacock', 'Margaret', 'Sales Representative', 'Mrs.', '1937-09-19 00:00:00', '1993-05-03 00:00:00', '4110 Old Redmond Rd.', 'Redmond', 'WA', '98052', 'USA', '(206) 555-8122', '5176', 'Margaret holds a BA in English literature from Concordia College (1958) and an MA from the American Institute of Culinary Arts (1966).  She was assigned to the London office temporarily from July through November 1992.', 2, 'http://accweb/emmployees/peacock.bmp', 1861.08, 'No'),
#  (5, 'Buchanan', 'Steven', 'Sales Manager', 'Mr.', '1955-03-04 00:00:00', '1993-10-17 00:00:00', '14 Garrett Hill', 'London', None, 'SW1 8JR', 'UK', '(71) 555-4848', '3453', 'Steven Buchanan graduated from St. Andrews University, Scotland, with a BSC degree in 1976.  Upon joining the company as a sales representative in 19 ... (150 characters truncated) ... ager in March 1993.  Mr. Buchanan has completed the courses "Successful Telemarketing" and "International Sales Management."  He is fluent in French.', 2, 'http://accweb/emmployees/buchanan.bmp', 1744.21, 'No'),
#  (6, 'Suyama', 'Michael', 'Sales Representative', 'Mr.', '1963-07-02 00:00:00', '1993-10-17 00:00:00', 'Coventry House\\r\\nMiner Rd.', 'London', None, 'EC2 7JR', 'UK', '(71) 555-7773', '428', 'Michael is a graduate of Sussex University (MA, economics, 1983) and the University of California at Los Angeles (MBA, marketing, 1986).  He has also ... (26 characters truncated) ... Cultural Selling" and "Time Management for the Sales Professional."  He is fluent in Japanese and can read and write French, Portuguese, and Spanish.', 5, 'http://accweb/emmployees/davolio.bmp', 2004.07, 'No'),
#  (7, 'King', 'Robert', 'Sales Representative', 'Mr.', '1960-05-29 00:00:00', '1994-01-02 00:00:00', 'Edgeham Hollow\\r\\nWinchester Way', 'London', None, 'RG1 9SP', 'UK', '(71) 555-5598', '465', 'Robert King served in the Peace Corps and traveled extensively before completing his degree in English at the University of Michigan in 1992, the year he joined the company.  After completing a course entitled "Selling in Europe," he was transferred to the London office in March 1993.', 5, 'http://accweb/emmployees/davolio.bmp', 1991.55, 'No'),
#  (8, 'Callahan', 'Laura', 'Inside Sales Coordinator', 'Ms.', '1958-01-09 00:00:00', '1994-03-05 00:00:00', '4726 - 11th Ave. N.E.', 'Seattle', 'WA', '98105', 'USA', '(206) 555-1189', '2344', 'Laura received a BA in psychology from the University of Washington.  She has also completed a course in business French.  She reads and writes French.', 2, 'http://accweb/emmployees/davolio.bmp', 2100.5, 'No'),
#  (9, 'Dodsworth', 'Anne', 'Sales Representative', 'Ms.', '1966-01-27 00:00:00', '1994-11-15 00:00:00', '7 Houndstooth Rd.', 'London', None, 'WG2 7LT', 'UK', '(71) 555-4444', '452', 'Anne has a BA degree in English from St. Lawrence College.  She is fluent in French and German.', 5, 'http://accweb/emmployees/davolio.bmp', 2333.33, 'No')]

# %% [markdown]
# ### 2. Categorise orders based on quantity
#
# Based on the `OrderDetails` table, write a SQL query that categorises orders into 'Small', 'Medium', or 'Large' based on the order quantity: Small (less than 20), Medium (between 20 and 100), and Large (more than 100).

# %%
# %%sql
# SELECT
#     *,
#     CASE
#         WHEN Quantity < 20 THEN 'Small'
#         WHEN Quantity BETWEEN 20 AND 100 THEN 'Medium'
#         ELSE 'Large'
#     END AS HighSalary
# FROM OrderDetails;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(10248, 11, 14, 12, 0.0, 'Small'),
#  (10248, 42, 9.8, 10, 0.0, 'Small'),
#  (10248, 72, 34.8, 5, 0.0, 'Small'),
#  (10249, 14, 18.6, 9, 0.0, 'Small'),
#  (10249, 51, 42.4, 40, 0.0, 'Medium'),
#  (10250, 41, 7.7, 10, 0.0, 'Small'),
#  (10250, 51, 42.4, 35, 0.0, 'Medium'),
#  (10250, 65, 16.8, 15, 0.0, 'Small'),
#  (10251, 22, 16.8, 6, 0.0, 'Small'),
#  (10251, 57, 15.6, 15, 0.0, 'Small'),
#  (10251, 65, 16.8, 20, 0.0, 'Medium'),
#  (10252, 20, 64.8, 40, 0.0, 'Medium'),
#  (10252, 33, 2, 25, 0.0, 'Medium'),
#  (10252, 60, 27.2, 40, 0.0, 'Medium'),
#  (10253, 31, 10, 20, 0.0, 'Medium'),
#  (10253, 39, 14.4, 42, 0.0, 'Medium'),
#  (10253, 49, 16, 40, 0.0, 'Medium'),
#  (10254, 24, 3.6, 15, 0.0, 'Small'),
#  (10254, 55, 19.2, 21, 0.0, 'Medium'),
#  (10254, 74, 8, 21, 0.0, 'Medium'),
#  (10255, 2, 15.2, 20, 0.0, 'Medium'),
#  (10255, 16, 13.9, 35, 0.0, 'Medium'),
#  (10255, 36, 15.2, 25, 0.0, 'Medium'),
#  (10255, 59, 44, 30, 0.0, 'Medium'),
#  (10256, 53, 26.2, 15, 0.0, 'Small'),
#  (10256, 77, 10.4, 12, 0.0, 'Small'),
#  (10257, 27, 35.1, 25, 0.0, 'Medium'),
#  (10257, 39, 14.4, 6, 0.0, 'Small'),
#  (10257, 77, 10.4, 15, 0.0, 'Small'),
#  (10258, 2, 15.2, 50, 0.0, 'Medium'),
#  (10258, 5, 17, 65, 0.0, 'Medium'),
#  (10258, 32, 25.6, 6, 0.0, 'Small'),
#  (10259, 21, 8, 10, 0.0, 'Small'),
#  (10259, 37, 20.8, 1, 0.0, 'Small'),
#  (10260, 41, 7.7, 16, 0.0, 'Small'),
#  (10260, 57, 15.6, 50, 0.0, 'Medium'),
#  (10260, 62, 39.4, 15, 0.0, 'Small'),
#  (10260, 70, 12, 21, 0.0, 'Medium'),
#  (10261, 21, 8, 20, 0.0, 'Medium'),
#  (10261, 35, 14.4, 20, 0.0, 'Medium'),
#  (10262, 5, 17, 12, 0.0, 'Small'),
#  (10262, 7, 24, 15, 0.0, 'Small'),
#  (10262, 56, 30.4, 2, 0.0, 'Small'),
#  (10263, 16, 13.9, 60, 0.0, 'Medium'),
#  (10263, 24, 3.6, 28, 0.0, 'Medium'),
#  (10263, 30, 20.7, 60, 0.0, 'Medium'),
#  (10263, 74, 8, 36, 0.0, 'Medium'),
#  (10264, 2, 15.2, 35, 0.0, 'Medium'),
#  (10264, 41, 7.7, 25, 0.0, 'Medium'),
#  (10265, 17, 31.2, 30, 0.0, 'Medium'),
#  (10265, 70, 12, 20, 0.0, 'Medium'),
#  (10266, 12, 30.4, 12, 0.0, 'Small'),
#  (10267, 40, 14.7, 50, 0.0, 'Medium'),
#  (10267, 59, 44, 70, 0.0, 'Medium'),
#  (10267, 76, 14.4, 15, 0.0, 'Small'),
#  (10268, 29, 99, 10, 0.0, 'Small'),
#  (10268, 72, 27.8, 4, 0.0, 'Small'),
#  (10269, 33, 2, 60, 0.0, 'Medium'),
#  (10269, 72, 27.8, 20, 0.0, 'Medium'),
#  (10270, 36, 15.2, 30, 0.0, 'Medium'),
#  (10270, 43, 36.8, 25, 0.0, 'Medium'),
#  (10271, 33, 2, 24, 0.0, 'Medium'),
#  (10272, 20, 64.8, 6, 0.0, 'Small'),
#  (10272, 31, 10, 40, 0.0, 'Medium'),
#  (10272, 72, 27.8, 24, 0.0, 'Medium'),
#  (10273, 10, 24.8, 24, 0.0, 'Medium'),
#  (10273, 31, 10, 15, 0.0, 'Small'),
#  (10273, 33, 2, 20, 0.0, 'Medium'),
#  (10273, 40, 14.7, 60, 0.0, 'Medium'),
#  (10273, 76, 14.4, 33, 0.0, 'Medium'),
#  (10274, 71, 17.2, 20, 0.0, 'Medium'),
#  (10274, 72, 27.8, 7, 0.0, 'Small'),
#  (10275, 24, 3.6, 12, 0.0, 'Small'),
#  (10275, 59, 44, 6, 0.0, 'Small'),
#  (10276, 10, 24.8, 15, 0.0, 'Small'),
#  (10276, 13, 4.8, 10, 0.0, 'Small'),
#  (10277, 28, 36.4, 20, 0.0, 'Medium'),
#  (10277, 62, 39.4, 12, 0.0, 'Small'),
#  (10278, 44, 15.5, 16, 0.0, 'Small'),
#  (10278, 59, 44, 15, 0.0, 'Small'),
#  (10278, 63, 35.1, 8, 0.0, 'Small'),
#  (10278, 73, 12, 25, 0.0, 'Medium'),
#  (10279, 17, 31.2, 15, 0.0, 'Small'),
#  (10280, 24, 3.6, 12, 0.0, 'Small'),
#  (10280, 55, 19.2, 20, 0.0, 'Medium'),
#  (10280, 75, 6.2, 30, 0.0, 'Medium'),
#  (10281, 19, 7.3, 1, 0.0, 'Small'),
#  (10281, 24, 3.6, 6, 0.0, 'Small'),
#  (10281, 35, 14.4, 4, 0.0, 'Small'),
#  (10282, 30, 20.7, 6, 0.0, 'Small'),
#  (10282, 57, 15.6, 2, 0.0, 'Small'),
#  (10283, 15, 12.4, 20, 0.0, 'Medium'),
#  (10283, 19, 7.3, 18, 0.0, 'Small'),
#  (10283, 60, 27.2, 35, 0.0, 'Medium'),
#  (10283, 72, 27.8, 3, 0.0, 'Small'),
#  (10284, 27, 35.1, 15, 0.0, 'Small'),
#  (10284, 44, 15.5, 21, 0.0, 'Medium'),
#  (10284, 60, 27.2, 20, 0.0, 'Medium'),
#  (10284, 67, 11.2, 5, 0.0, 'Small'),
#  (10285, 1, 14.4, 45, 0.0, 'Medium'),
#  (10285, 40, 14.7, 40, 0.0, 'Medium'),
#  (10285, 53, 26.2, 36, 0.0, 'Medium'),
#  (10286, 35, 14.4, 100, 0.0, 'Medium'),
#  (10286, 62, 39.4, 40, 0.0, 'Medium'),
#  (10287, 16, 13.9, 40, 0.0, 'Medium'),
#  (10287, 34, 11.2, 20, 0.0, 'Medium'),
#  (10287, 46, 9.6, 15, 0.0, 'Small'),
#  (10288, 54, 5.9, 10, 0.0, 'Small'),
#  (10288, 68, 10, 3, 0.0, 'Small'),
#  (10289, 3, 8, 30, 0.0, 'Medium'),
#  (10289, 64, 26.6, 9, 0.0, 'Small'),
#  (10290, 5, 17, 20, 0.0, 'Medium'),
#  (10290, 29, 99, 15, 0.0, 'Small'),
#  (10290, 49, 16, 15, 0.0, 'Small'),
#  (10290, 77, 10.4, 10, 0.0, 'Small'),
#  (10291, 13, 4.8, 20, 0.0, 'Medium'),
#  (10291, 44, 15.5, 24, 0.0, 'Medium'),
#  (10291, 51, 42.4, 2, 0.0, 'Small'),
#  (10292, 20, 64.8, 20, 0.0, 'Medium'),
#  (10293, 18, 50, 12, 0.0, 'Small'),
#  (10293, 24, 3.6, 10, 0.0, 'Small'),
#  (10293, 63, 35.1, 5, 0.0, 'Small'),
#  (10293, 75, 6.2, 6, 0.0, 'Small'),
#  (10294, 1, 14.4, 18, 0.0, 'Small'),
#  (10294, 17, 31.2, 15, 0.0, 'Small'),
#  (10294, 43, 36.8, 15, 0.0, 'Small'),
#  (10294, 60, 27.2, 21, 0.0, 'Medium'),
#  (10294, 75, 6.2, 6, 0.0, 'Small'),
#  (10295, 56, 30.4, 4, 0.0, 'Small'),
#  (10296, 11, 16.8, 12, 0.0, 'Small'),
#  (10296, 16, 13.9, 30, 0.0, 'Medium'),
#  (10296, 69, 28.8, 15, 0.0, 'Small'),
#  (10297, 39, 14.4, 60, 0.0, 'Medium'),
#  (10297, 72, 27.8, 20, 0.0, 'Medium'),
#  (10298, 2, 15.2, 40, 0.0, 'Medium'),
#  (10298, 36, 15.2, 40, 0.0, 'Medium'),
#  (10298, 59, 44, 30, 0.0, 'Medium'),
#  (10298, 62, 39.4, 15, 0.0, 'Small'),
#  (10299, 19, 7.3, 15, 0.0, 'Small'),
#  (10299, 70, 12, 20, 0.0, 'Medium'),
#  (10300, 66, 13.6, 30, 0.0, 'Medium'),
#  (10300, 68, 10, 20, 0.0, 'Medium'),
#  (10301, 40, 14.7, 10, 0.0, 'Small'),
#  (10301, 56, 30.4, 20, 0.0, 'Medium'),
#  (10302, 17, 31.2, 40, 0.0, 'Medium'),
#  (10302, 28, 36.4, 28, 0.0, 'Medium'),
#  (10302, 43, 36.8, 12, 0.0, 'Small'),
#  (10303, 40, 14.7, 40, 0.0, 'Medium'),
#  (10303, 65, 16.8, 30, 0.0, 'Medium'),
#  (10303, 68, 10, 15, 0.0, 'Small'),
#  (10304, 49, 16, 30, 0.0, 'Medium'),
#  (10304, 59, 44, 10, 0.0, 'Small'),
#  (10304, 71, 17.2, 2, 0.0, 'Small'),
#  (10305, 18, 50, 25, 0.0, 'Medium'),
#  (10305, 29, 99, 25, 0.0, 'Medium'),
#  (10305, 39, 14.4, 30, 0.0, 'Medium'),
#  (10306, 30, 20.7, 10, 0.0, 'Small'),
#  (10306, 53, 26.2, 10, 0.0, 'Small'),
#  (10306, 54, 5.9, 5, 0.0, 'Small'),
#  (10307, 62, 39.4, 10, 0.0, 'Small'),
#  (10307, 68, 10, 3, 0.0, 'Small'),
#  (10308, 69, 28.8, 1, 0.0, 'Small'),
#  (10308, 70, 12, 5, 0.0, 'Small'),
#  (10309, 4, 17.6, 20, 0.0, 'Medium'),
#  (10309, 6, 20, 30, 0.0, 'Medium'),
#  (10309, 42, 11.2, 2, 0.0, 'Small'),
#  (10309, 43, 36.8, 20, 0.0, 'Medium'),
#  (10309, 71, 17.2, 3, 0.0, 'Small'),
#  (10310, 16, 13.9, 10, 0.0, 'Small'),
#  (10310, 62, 39.4, 5, 0.0, 'Small'),
#  (10311, 42, 11.2, 6, 0.0, 'Small'),
#  (10311, 69, 28.8, 7, 0.0, 'Small'),
#  (10312, 28, 36.4, 4, 0.0, 'Small'),
#  (10312, 43, 36.8, 24, 0.0, 'Medium'),
#  (10312, 53, 26.2, 20, 0.0, 'Medium'),
#  (10312, 75, 6.2, 10, 0.0, 'Small'),
#  (10313, 36, 15.2, 12, 0.0, 'Small'),
#  (10314, 32, 25.6, 40, 0.0, 'Medium'),
#  (10314, 58, 10.6, 30, 0.0, 'Medium'),
#  (10314, 62, 39.4, 25, 0.0, 'Medium'),
#  (10315, 34, 11.2, 14, 0.0, 'Small'),
#  (10315, 70, 12, 30, 0.0, 'Medium'),
#  (10316, 41, 7.7, 10, 0.0, 'Small'),
#  (10316, 62, 39.4, 70, 0.0, 'Medium'),
#  (10317, 1, 14.4, 20, 0.0, 'Medium'),
#  (10318, 41, 7.7, 20, 0.0, 'Medium'),
#  (10318, 76, 14.4, 6, 0.0, 'Small'),
#  (10319, 17, 31.2, 8, 0.0, 'Small'),
#  (10319, 28, 36.4, 14, 0.0, 'Small'),
#  (10319, 76, 14.4, 30, 0.0, 'Medium'),
#  (10320, 71, 17.2, 30, 0.0, 'Medium'),
#  (10321, 35, 14.4, 10, 0.0, 'Small'),
#  (10322, 52, 5.6, 20, 0.0, 'Medium'),
#  (10323, 15, 12.4, 5, 0.0, 'Small'),
#  (10323, 25, 11.2, 4, 0.0, 'Small'),
#  (10323, 39, 14.4, 4, 0.0, 'Small'),
#  (10324, 16, 13.9, 21, 0.0, 'Medium'),
#  (10324, 35, 14.4, 70, 0.0, 'Medium'),
#  (10324, 46, 9.6, 30, 0.0, 'Medium'),
#  (10324, 59, 44, 40, 0.0, 'Medium'),
#  (10324, 63, 35.1, 80, 0.0, 'Medium'),
#  (10325, 6, 20, 6, 0.0, 'Small'),
#  (10325, 13, 4.8, 12, 0.0, 'Small'),
#  (10325, 14, 18.6, 9, 0.0, 'Small'),
#  (10325, 31, 10, 4, 0.0, 'Small'),
#  (10325, 72, 27.8, 40, 0.0, 'Medium'),
#  (10326, 4, 17.6, 24, 0.0, 'Medium'),
#  (10326, 57, 15.6, 16, 0.0, 'Small'),
#  (10326, 75, 6.2, 50, 0.0, 'Medium'),
#  (10327, 2, 15.2, 25, 0.0, 'Medium'),
#  (10327, 11, 16.8, 50, 0.0, 'Medium'),
#  (10327, 30, 20.7, 35, 0.0, 'Medium'),
#  (10327, 58, 10.6, 30, 0.0, 'Medium'),
#  (10328, 59, 44, 9, 0.0, 'Small'),
#  (10328, 65, 16.8, 40, 0.0, 'Medium'),
#  (10328, 68, 10, 10, 0.0, 'Small'),
#  (10329, 19, 7.3, 10, 0.0, 'Small'),
#  (10329, 30, 20.7, 8, 0.0, 'Small'),
#  (10329, 38, 210.8, 20, 0.0, 'Medium'),
#  (10329, 56, 30.4, 12, 0.0, 'Small'),
#  (10330, 26, 24.9, 50, 0.0, 'Medium'),
#  (10330, 72, 27.8, 25, 0.0, 'Medium'),
#  (10331, 54, 5.9, 15, 0.0, 'Small'),
#  (10332, 18, 50, 40, 0.0, 'Medium'),
#  (10332, 42, 11.2, 10, 0.0, 'Small'),
#  (10332, 47, 7.6, 16, 0.0, 'Small'),
#  (10333, 14, 18.6, 10, 0.0, 'Small'),
#  (10333, 21, 8, 10, 0.0, 'Small'),
#  (10333, 71, 17.2, 40, 0.0, 'Medium'),
#  (10334, 52, 5.6, 8, 0.0, 'Small'),
#  (10334, 68, 10, 10, 0.0, 'Small'),
#  (10335, 2, 15.2, 7, 0.0, 'Small'),
#  (10335, 31, 10, 25, 0.0, 'Medium'),
#  (10335, 32, 25.6, 6, 0.0, 'Small'),
#  (10335, 51, 42.4, 48, 0.0, 'Medium'),
#  (10336, 4, 17.6, 18, 0.0, 'Small'),
#  (10337, 23, 7.2, 40, 0.0, 'Medium'),
#  (10337, 26, 24.9, 24, 0.0, 'Medium'),
#  (10337, 36, 15.2, 20, 0.0, 'Medium'),
#  (10337, 37, 20.8, 28, 0.0, 'Medium'),
#  (10337, 72, 27.8, 25, 0.0, 'Medium'),
#  (10338, 17, 31.2, 20, 0.0, 'Medium'),
#  (10338, 30, 20.7, 15, 0.0, 'Small'),
#  (10339, 4, 17.6, 10, 0.0, 'Small'),
#  (10339, 17, 31.2, 70, 0.0, 'Medium'),
#  (10339, 62, 39.4, 28, 0.0, 'Medium'),
#  (10340, 18, 50, 20, 0.0, 'Medium'),
#  (10340, 41, 7.7, 12, 0.0, 'Small'),
#  (10340, 43, 36.8, 40, 0.0, 'Medium'),
#  (10341, 33, 2, 8, 0.0, 'Small'),
#  (10341, 59, 44, 9, 0.0, 'Small'),
#  (10342, 2, 15.2, 24, 0.0, 'Medium'),
#  (10342, 31, 10, 56, 0.0, 'Medium'),
#  (10342, 36, 15.2, 40, 0.0, 'Medium'),
#  (10342, 55, 19.2, 40, 0.0, 'Medium'),
#  (10343, 64, 26.6, 50, 0.0, 'Medium'),
#  (10343, 68, 10, 4, 0.0, 'Small'),
#  (10343, 76, 14.4, 15, 0.0, 'Small'),
#  (10344, 4, 17.6, 35, 0.0, 'Medium'),
#  (10344, 8, 32, 70, 0.0, 'Medium'),
#  (10345, 8, 32, 70, 0.0, 'Medium'),
#  (10345, 19, 7.3, 80, 0.0, 'Medium'),
#  (10345, 42, 11.2, 9, 0.0, 'Small'),
#  (10346, 17, 31.2, 36, 0.0, 'Medium'),
#  (10346, 56, 30.4, 20, 0.0, 'Medium'),
#  (10347, 25, 11.2, 10, 0.0, 'Small'),
#  (10347, 39, 14.4, 50, 0.0, 'Medium'),
#  (10347, 40, 14.7, 4, 0.0, 'Small'),
#  (10347, 75, 6.2, 6, 0.0, 'Small'),
#  (10348, 1, 14.4, 15, 0.0, 'Small'),
#  (10348, 23, 7.2, 25, 0.0, 'Medium'),
#  (10349, 54, 5.9, 24, 0.0, 'Medium'),
#  (10350, 50, 13, 15, 0.0, 'Small'),
#  (10350, 69, 28.8, 18, 0.0, 'Small'),
#  (10351, 38, 210.8, 20, 0.0, 'Medium'),
#  (10351, 41, 7.7, 13, 0.0, 'Small'),
#  (10351, 44, 15.5, 77, 0.0, 'Medium'),
#  (10351, 65, 16.8, 10, 0.0, 'Small'),
#  (10352, 24, 3.6, 10, 0.0, 'Small'),
#  (10352, 54, 5.9, 20, 0.0, 'Medium'),
#  (10353, 11, 16.8, 12, 0.0, 'Small'),
#  (10353, 38, 210.8, 50, 0.0, 'Medium'),
#  (10354, 1, 14.4, 12, 0.0, 'Small'),
#  (10354, 29, 99, 4, 0.0, 'Small'),
#  (10355, 24, 3.6, 25, 0.0, 'Medium'),
#  (10355, 57, 15.6, 25, 0.0, 'Medium'),
#  (10356, 31, 10, 30, 0.0, 'Medium'),
#  (10356, 55, 19.2, 12, 0.0, 'Small'),
#  (10356, 69, 28.8, 20, 0.0, 'Medium'),
#  (10357, 10, 24.8, 30, 0.0, 'Medium'),
#  (10357, 26, 24.9, 16, 0.0, 'Small'),
#  (10357, 60, 27.2, 8, 0.0, 'Small'),
#  (10358, 24, 3.6, 10, 0.0, 'Small'),
#  (10358, 34, 11.2, 10, 0.0, 'Small'),
#  (10358, 36, 15.2, 20, 0.0, 'Medium'),
#  (10359, 16, 13.9, 56, 0.0, 'Medium'),
#  (10359, 31, 10, 70, 0.0, 'Medium'),
#  (10359, 60, 27.2, 80, 0.0, 'Medium'),
#  (10360, 28, 36.4, 30, 0.0, 'Medium'),
#  (10360, 29, 99, 35, 0.0, 'Medium'),
#  (10360, 38, 210.8, 10, 0.0, 'Small'),
#  (10360, 49, 16, 35, 0.0, 'Medium'),
#  (10360, 54, 5.9, 28, 0.0, 'Medium'),
#  (10361, 39, 14.4, 54, 0.0, 'Medium'),
#  (10361, 60, 27.2, 55, 0.0, 'Medium'),
#  (10362, 25, 11.2, 50, 0.0, 'Medium'),
#  (10362, 51, 42.4, 20, 0.0, 'Medium'),
#  (10362, 54, 5.9, 24, 0.0, 'Medium'),
#  (10363, 31, 10, 20, 0.0, 'Medium'),
#  (10363, 75, 6.2, 12, 0.0, 'Small'),
#  (10363, 76, 14.4, 12, 0.0, 'Small'),
#  (10364, 69, 28.8, 30, 0.0, 'Medium'),
#  (10364, 71, 17.2, 5, 0.0, 'Small'),
#  (10365, 11, 16.8, 24, 0.0, 'Medium'),
#  (10366, 65, 16.8, 5, 0.0, 'Small'),
#  (10366, 77, 10.4, 5, 0.0, 'Small'),
#  (10367, 34, 11.2, 36, 0.0, 'Medium'),
#  (10367, 54, 5.9, 18, 0.0, 'Small'),
#  (10367, 65, 16.8, 15, 0.0, 'Small'),
#  (10367, 77, 10.4, 7, 0.0, 'Small'),
#  (10368, 21, 8, 5, 0.0, 'Small'),
#  (10368, 28, 36.4, 13, 0.0, 'Small'),
#  (10368, 57, 15.6, 25, 0.0, 'Medium'),
#  (10368, 64, 26.6, 35, 0.0, 'Medium'),
#  (10369, 29, 99, 20, 0.0, 'Medium'),
#  (10369, 56, 30.4, 18, 0.0, 'Small'),
#  (10370, 1, 14.4, 15, 0.0, 'Small'),
#  (10370, 64, 26.6, 30, 0.0, 'Medium'),
#  (10370, 74, 8, 20, 0.0, 'Medium'),
#  (10371, 36, 15.2, 6, 0.0, 'Small'),
#  (10372, 20, 64.8, 12, 0.0, 'Small'),
#  (10372, 38, 210.8, 40, 0.0, 'Medium'),
#  (10372, 60, 27.2, 70, 0.0, 'Medium'),
#  (10372, 72, 27.8, 42, 0.0, 'Medium'),
#  (10373, 58, 10.6, 80, 0.0, 'Medium'),
#  (10373, 71, 17.2, 50, 0.0, 'Medium'),
#  (10374, 31, 10, 30, 0.0, 'Medium'),
#  (10374, 58, 10.6, 15, 0.0, 'Small'),
#  (10375, 14, 18.6, 15, 0.0, 'Small'),
#  (10375, 54, 5.9, 10, 0.0, 'Small'),
#  (10376, 31, 10, 42, 0.0, 'Medium'),
#  (10377, 28, 36.4, 20, 0.0, 'Medium'),
#  (10377, 39, 14.4, 20, 0.0, 'Medium'),
#  (10378, 71, 17.2, 6, 0.0, 'Small'),
#  (10379, 41, 7.7, 8, 0.0, 'Small'),
#  (10379, 63, 35.1, 16, 0.0, 'Small'),
#  (10379, 65, 16.8, 20, 0.0, 'Medium'),
#  (10380, 30, 20.7, 18, 0.0, 'Small'),
#  (10380, 53, 26.2, 20, 0.0, 'Medium'),
#  (10380, 60, 27.2, 6, 0.0, 'Small'),
#  (10380, 70, 12, 30, 0.0, 'Medium'),
#  (10381, 74, 8, 14, 0.0, 'Small'),
#  (10382, 5, 17, 32, 0.0, 'Medium'),
#  (10382, 18, 50, 9, 0.0, 'Small'),
#  (10382, 29, 99, 14, 0.0, 'Small'),
#  (10382, 33, 2, 60, 0.0, 'Medium'),
#  (10382, 74, 8, 50, 0.0, 'Medium'),
#  (10383, 13, 4.8, 20, 0.0, 'Medium'),
#  (10383, 50, 13, 15, 0.0, 'Small'),
#  (10383, 56, 30.4, 20, 0.0, 'Medium'),
#  (10384, 20, 64.8, 28, 0.0, 'Medium'),
#  (10384, 60, 27.2, 15, 0.0, 'Small'),
#  (10385, 7, 24, 10, 0.0, 'Small'),
#  (10385, 60, 27.2, 20, 0.0, 'Medium'),
#  (10385, 68, 10, 8, 0.0, 'Small'),
#  (10386, 24, 3.6, 15, 0.0, 'Small'),
#  (10386, 34, 11.2, 10, 0.0, 'Small'),
#  (10387, 24, 3.6, 15, 0.0, 'Small'),
#  (10387, 28, 36.4, 6, 0.0, 'Small'),
#  (10387, 59, 44, 12, 0.0, 'Small'),
#  (10387, 71, 17.2, 15, 0.0, 'Small'),
#  (10388, 45, 7.6, 15, 0.0, 'Small'),
#  (10388, 52, 5.6, 20, 0.0, 'Medium'),
#  (10388, 53, 26.2, 40, 0.0, 'Medium'),
#  (10389, 10, 24.8, 16, 0.0, 'Small'),
#  (10389, 55, 19.2, 15, 0.0, 'Small'),
#  (10389, 62, 39.4, 20, 0.0, 'Medium'),
#  (10389, 70, 12, 30, 0.0, 'Medium'),
#  (10390, 31, 10, 60, 0.0, 'Medium'),
#  (10390, 35, 14.4, 40, 0.0, 'Medium'),
#  (10390, 46, 9.6, 45, 0.0, 'Medium'),
#  (10390, 72, 27.8, 24, 0.0, 'Medium'),
#  (10391, 13, 4.8, 18, 0.0, 'Small'),
#  (10392, 69, 28.8, 50, 0.0, 'Medium'),
#  (10393, 2, 15.2, 25, 0.0, 'Medium'),
#  (10393, 14, 18.6, 42, 0.0, 'Medium'),
#  (10393, 25, 11.2, 7, 0.0, 'Small'),
#  (10393, 26, 24.9, 70, 0.0, 'Medium'),
#  (10393, 31, 10, 32, 0.0, 'Medium'),
#  (10394, 13, 4.8, 10, 0.0, 'Small'),
#  (10394, 62, 39.4, 10, 0.0, 'Small'),
#  (10395, 46, 9.6, 28, 0.0, 'Medium'),
#  (10395, 53, 26.2, 70, 0.0, 'Medium'),
#  (10395, 69, 28.8, 8, 0.0, 'Small'),
#  (10396, 23, 7.2, 40, 0.0, 'Medium'),
#  (10396, 71, 17.2, 60, 0.0, 'Medium'),
#  (10396, 72, 27.8, 21, 0.0, 'Medium'),
#  (10397, 21, 8, 10, 0.0, 'Small'),
#  (10397, 51, 42.4, 18, 0.0, 'Small'),
#  (10398, 35, 14.4, 30, 0.0, 'Medium'),
#  (10398, 55, 19.2, 120, 0.0, 'Large'),
#  (10399, 68, 10, 60, 0.0, 'Medium'),
#  (10399, 71, 17.2, 30, 0.0, 'Medium'),
#  (10399, 76, 14.4, 35, 0.0, 'Medium'),
#  (10399, 77, 10.4, 14, 0.0, 'Small'),
#  (10400, 29, 99, 21, 0.0, 'Medium'),
#  (10400, 35, 14.4, 35, 0.0, 'Medium'),
#  (10400, 49, 16, 30, 0.0, 'Medium'),
#  (10401, 30, 20.7, 18, 0.0, 'Small'),
#  (10401, 56, 30.4, 70, 0.0, 'Medium'),
#  (10401, 65, 16.8, 20, 0.0, 'Medium'),
#  (10401, 71, 17.2, 60, 0.0, 'Medium'),
#  (10402, 23, 7.2, 60, 0.0, 'Medium'),
#  (10402, 63, 35.1, 65, 0.0, 'Medium'),
#  (10403, 16, 13.9, 21, 0.0, 'Medium'),
#  (10403, 48, 10.2, 70, 0.0, 'Medium'),
#  (10404, 26, 24.9, 30, 0.0, 'Medium'),
#  (10404, 42, 11.2, 40, 0.0, 'Medium'),
#  (10404, 49, 16, 30, 0.0, 'Medium'),
#  (10405, 3, 8, 50, 0.0, 'Medium'),
#  (10406, 1, 14.4, 10, 0.0, 'Small'),
#  (10406, 21, 8, 30, 0.0, 'Medium'),
#  (10406, 28, 36.4, 42, 0.0, 'Medium'),
#  (10406, 36, 15.2, 5, 0.0, 'Small'),
#  (10406, 40, 14.7, 2, 0.0, 'Small'),
#  (10407, 11, 16.8, 30, 0.0, 'Medium'),
#  (10407, 69, 28.8, 15, 0.0, 'Small'),
#  (10407, 71, 17.2, 15, 0.0, 'Small'),
#  (10408, 37, 20.8, 10, 0.0, 'Small'),
#  (10408, 54, 5.9, 6, 0.0, 'Small'),
#  (10408, 62, 39.4, 35, 0.0, 'Medium'),
#  (10409, 14, 18.6, 12, 0.0, 'Small'),
#  (10409, 21, 8, 12, 0.0, 'Small'),
#  (10410, 33, 2, 49, 0.0, 'Medium'),
#  (10410, 59, 44, 16, 0.0, 'Small'),
#  (10411, 41, 7.7, 25, 0.0, 'Medium'),
#  (10411, 44, 15.5, 40, 0.0, 'Medium'),
#  (10411, 59, 44, 9, 0.0, 'Small'),
#  (10412, 14, 18.6, 20, 0.0, 'Medium'),
#  (10413, 1, 14.4, 24, 0.0, 'Medium'),
#  (10413, 62, 39.4, 40, 0.0, 'Medium'),
#  (10413, 76, 14.4, 14, 0.0, 'Small'),
#  (10414, 19, 7.3, 18, 0.0, 'Small'),
#  (10414, 33, 2, 50, 0.0, 'Medium'),
#  (10415, 17, 31.2, 2, 0.0, 'Small'),
#  (10415, 33, 2, 20, 0.0, 'Medium'),
#  (10416, 19, 7.3, 20, 0.0, 'Medium'),
#  (10416, 53, 26.2, 10, 0.0, 'Small'),
#  (10416, 57, 15.6, 20, 0.0, 'Medium'),
#  (10417, 38, 210.8, 50, 0.0, 'Medium'),
#  (10417, 46, 9.6, 2, 0.0, 'Small'),
#  (10417, 68, 10, 36, 0.0, 'Medium'),
#  (10417, 77, 10.4, 35, 0.0, 'Medium'),
#  (10418, 2, 15.2, 60, 0.0, 'Medium'),
#  (10418, 47, 7.6, 55, 0.0, 'Medium'),
#  (10418, 61, 22.8, 16, 0.0, 'Small'),
#  (10418, 74, 8, 15, 0.0, 'Small'),
#  (10419, 60, 27.2, 60, 0.0, 'Medium'),
#  (10419, 69, 28.8, 20, 0.0, 'Medium'),
#  (10420, 9, 77.6, 20, 0.0, 'Medium'),
#  (10420, 13, 4.8, 2, 0.0, 'Small'),
#  (10420, 70, 12, 8, 0.0, 'Small'),
#  (10420, 73, 12, 20, 0.0, 'Medium'),
#  (10421, 19, 7.3, 4, 0.0, 'Small'),
#  (10421, 26, 24.9, 30, 0.0, 'Medium'),
#  (10421, 53, 26.2, 15, 0.0, 'Small'),
#  (10421, 77, 10.4, 10, 0.0, 'Small'),
#  (10422, 26, 24.9, 2, 0.0, 'Small'),
#  (10423, 31, 10, 14, 0.0, 'Small'),
#  (10423, 59, 44, 20, 0.0, 'Medium'),
#  (10424, 35, 14.4, 60, 0.0, 'Medium'),
#  (10424, 38, 210.8, 49, 0.0, 'Medium'),
#  (10424, 68, 10, 30, 0.0, 'Medium'),
#  (10425, 55, 19.2, 10, 0.0, 'Small'),
#  (10425, 76, 14.4, 20, 0.0, 'Medium'),
#  (10426, 56, 30.4, 5, 0.0, 'Small'),
#  (10426, 64, 26.6, 7, 0.0, 'Small'),
#  (10427, 14, 18.6, 35, 0.0, 'Medium'),
#  (10428, 46, 9.6, 20, 0.0, 'Medium'),
#  (10429, 50, 13, 40, 0.0, 'Medium'),
#  (10429, 63, 35.1, 35, 0.0, 'Medium'),
#  (10430, 17, 31.2, 45, 0.0, 'Medium'),
#  (10430, 21, 8, 50, 0.0, 'Medium'),
#  (10430, 56, 30.4, 30, 0.0, 'Medium'),
#  (10430, 59, 44, 70, 0.0, 'Medium'),
#  (10431, 17, 31.2, 50, 0.0, 'Medium'),
#  (10431, 40, 14.7, 50, 0.0, 'Medium'),
#  (10431, 47, 7.6, 30, 0.0, 'Medium'),
#  (10432, 26, 24.9, 10, 0.0, 'Small'),
#  (10432, 54, 5.9, 40, 0.0, 'Medium'),
#  (10433, 56, 30.4, 28, 0.0, 'Medium'),
#  (10434, 11, 16.8, 6, 0.0, 'Small'),
#  (10434, 76, 14.4, 18, 0.0, 'Small'),
#  (10435, 2, 15.2, 10, 0.0, 'Small'),
#  (10435, 22, 16.8, 12, 0.0, 'Small'),
#  (10435, 72, 27.8, 10, 0.0, 'Small'),
#  (10436, 46, 9.6, 5, 0.0, 'Small'),
#  (10436, 56, 30.4, 40, 0.0, 'Medium'),
#  (10436, 64, 26.6, 30, 0.0, 'Medium'),
#  (10436, 75, 6.2, 24, 0.0, 'Medium'),
#  (10437, 53, 26.2, 15, 0.0, 'Small'),
#  (10438, 19, 7.3, 15, 0.0, 'Small'),
#  (10438, 34, 11.2, 20, 0.0, 'Medium'),
#  (10438, 57, 15.6, 15, 0.0, 'Small'),
#  (10439, 12, 30.4, 15, 0.0, 'Small'),
#  (10439, 16, 13.9, 16, 0.0, 'Small'),
#  (10439, 64, 26.6, 6, 0.0, 'Small'),
#  (10439, 74, 8, 30, 0.0, 'Medium'),
#  (10440, 2, 15.2, 45, 0.0, 'Medium'),
#  (10440, 16, 13.9, 49, 0.0, 'Medium'),
#  (10440, 29, 99, 24, 0.0, 'Medium'),
#  (10440, 61, 22.8, 90, 0.0, 'Medium'),
#  (10441, 27, 35.1, 50, 0.0, 'Medium'),
#  (10442, 11, 16.8, 30, 0.0, 'Medium'),
#  (10442, 54, 5.9, 80, 0.0, 'Medium'),
#  (10442, 66, 13.6, 60, 0.0, 'Medium'),
#  (10443, 11, 16.8, 6, 0.0, 'Small'),
#  (10443, 28, 36.4, 12, 0.0, 'Small'),
#  (10444, 17, 31.2, 10, 0.0, 'Small'),
#  (10444, 26, 24.9, 15, 0.0, 'Small'),
#  (10444, 35, 14.4, 8, 0.0, 'Small'),
#  (10444, 41, 7.7, 30, 0.0, 'Medium'),
#  (10445, 39, 14.4, 6, 0.0, 'Small'),
#  (10445, 54, 5.9, 15, 0.0, 'Small'),
#  (10446, 19, 7.3, 12, 0.0, 'Small'),
#  (10446, 24, 3.6, 20, 0.0, 'Medium'),
#  (10446, 31, 10, 3, 0.0, 'Small'),
#  (10446, 52, 5.6, 15, 0.0, 'Small'),
#  (10447, 19, 7.3, 40, 0.0, 'Medium'),
#  (10447, 65, 16.8, 35, 0.0, 'Medium'),
#  (10447, 71, 17.2, 2, 0.0, 'Small'),
#  (10448, 26, 24.9, 6, 0.0, 'Small'),
#  (10448, 40, 14.7, 20, 0.0, 'Medium'),
#  (10449, 10, 24.8, 14, 0.0, 'Small'),
#  (10449, 52, 5.6, 20, 0.0, 'Medium'),
#  (10449, 62, 39.4, 35, 0.0, 'Medium'),
#  (10450, 10, 24.8, 20, 0.0, 'Medium'),
#  (10450, 54, 5.9, 6, 0.0, 'Small'),
#  (10451, 55, 19.2, 120, 0.0, 'Large'),
#  (10451, 64, 26.6, 35, 0.0, 'Medium'),
#  (10451, 65, 16.8, 28, 0.0, 'Medium'),
#  (10451, 77, 10.4, 55, 0.0, 'Medium'),
#  (10452, 28, 36.4, 15, 0.0, 'Small'),
#  (10452, 44, 15.5, 100, 0.0, 'Medium'),
#  (10453, 48, 10.2, 15, 0.0, 'Small'),
#  (10453, 70, 12, 25, 0.0, 'Medium'),
#  (10454, 16, 13.9, 20, 0.0, 'Medium'),
#  (10454, 33, 2, 20, 0.0, 'Medium'),
#  (10454, 46, 9.6, 10, 0.0, 'Small'),
#  (10455, 39, 14.4, 20, 0.0, 'Medium'),
#  (10455, 53, 26.2, 50, 0.0, 'Medium'),
#  (10455, 61, 22.8, 25, 0.0, 'Medium'),
#  (10455, 71, 17.2, 30, 0.0, 'Medium'),
#  (10456, 21, 8, 40, 0.0, 'Medium'),
#  (10456, 49, 16, 21, 0.0, 'Medium'),
#  (10457, 59, 44, 36, 0.0, 'Medium'),
#  (10458, 26, 24.9, 30, 0.0, 'Medium'),
#  (10458, 28, 36.4, 30, 0.0, 'Medium'),
#  (10458, 43, 36.8, 20, 0.0, 'Medium'),
#  (10458, 56, 30.4, 15, 0.0, 'Small'),
#  (10458, 71, 17.2, 50, 0.0, 'Medium'),
#  (10459, 7, 24, 16, 0.0, 'Small'),
#  (10459, 46, 9.6, 20, 0.0, 'Medium'),
#  (10459, 72, 27.8, 40, 0.0, 'Medium'),
#  (10460, 68, 10, 21, 0.0, 'Medium'),
#  (10460, 75, 6.2, 4, 0.0, 'Small'),
#  (10461, 21, 8, 40, 0.0, 'Medium'),
#  (10461, 30, 20.7, 28, 0.0, 'Medium'),
#  (10461, 55, 19.2, 60, 0.0, 'Medium'),
#  (10462, 13, 4.8, 1, 0.0, 'Small'),
#  (10462, 23, 7.2, 21, 0.0, 'Medium'),
#  (10463, 19, 7.3, 21, 0.0, 'Medium'),
#  (10463, 42, 11.2, 50, 0.0, 'Medium'),
#  (10464, 4, 17.6, 16, 0.0, 'Small'),
#  (10464, 43, 36.8, 3, 0.0, 'Small'),
#  (10464, 56, 30.4, 30, 0.0, 'Medium'),
#  (10464, 60, 27.2, 20, 0.0, 'Medium'),
#  (10465, 24, 3.6, 25, 0.0, 'Medium'),
#  (10465, 29, 99, 18, 0.0, 'Small'),
#  (10465, 40, 14.7, 20, 0.0, 'Medium'),
#  (10465, 45, 7.6, 30, 0.0, 'Medium'),
#  (10465, 50, 13, 25, 0.0, 'Medium'),
#  (10466, 11, 16.8, 10, 0.0, 'Small'),
#  (10466, 46, 9.6, 5, 0.0, 'Small'),
#  (10467, 24, 3.6, 28, 0.0, 'Medium'),
#  (10467, 25, 11.2, 12, 0.0, 'Small'),
#  (10468, 30, 20.7, 8, 0.0, 'Small'),
#  (10468, 43, 36.8, 15, 0.0, 'Small'),
#  (10469, 2, 15.2, 40, 0.0, 'Medium'),
#  (10469, 16, 13.9, 35, 0.0, 'Medium'),
#  (10469, 44, 15.5, 2, 0.0, 'Small'),
#  (10470, 18, 50, 30, 0.0, 'Medium'),
#  (10470, 23, 7.2, 15, 0.0, 'Small'),
#  (10470, 64, 26.6, 8, 0.0, 'Small'),
#  (10471, 7, 24, 30, 0.0, 'Medium'),
#  (10471, 56, 30.4, 20, 0.0, 'Medium'),
#  (10472, 24, 3.6, 80, 0.0, 'Medium'),
#  (10472, 51, 42.4, 18, 0.0, 'Small'),
#  (10473, 33, 2, 12, 0.0, 'Small'),
#  (10473, 71, 17.2, 12, 0.0, 'Small'),
#  (10474, 14, 18.6, 12, 0.0, 'Small'),
#  (10474, 28, 36.4, 18, 0.0, 'Small'),
#  (10474, 40, 14.7, 21, 0.0, 'Medium'),
#  (10474, 75, 6.2, 10, 0.0, 'Small'),
#  (10475, 31, 10, 35, 0.0, 'Medium'),
#  (10475, 66, 13.6, 60, 0.0, 'Medium'),
#  (10475, 76, 14.4, 42, 0.0, 'Medium'),
#  (10476, 55, 19.2, 2, 0.0, 'Small'),
#  (10476, 70, 12, 12, 0.0, 'Small'),
#  (10477, 1, 14.4, 15, 0.0, 'Small'),
#  (10477, 21, 8, 21, 0.0, 'Medium'),
#  (10477, 39, 14.4, 20, 0.0, 'Medium'),
#  (10478, 10, 24.8, 20, 0.0, 'Medium'),
#  (10479, 38, 210.8, 30, 0.0, 'Medium'),
#  (10479, 53, 26.2, 28, 0.0, 'Medium'),
#  (10479, 59, 44, 60, 0.0, 'Medium'),
#  (10479, 64, 26.6, 30, 0.0, 'Medium'),
#  (10480, 47, 7.6, 30, 0.0, 'Medium'),
#  (10480, 59, 44, 12, 0.0, 'Small'),
#  (10481, 49, 16, 24, 0.0, 'Medium'),
#  (10481, 60, 27.2, 40, 0.0, 'Medium'),
#  (10482, 40, 14.7, 10, 0.0, 'Small'),
#  (10483, 34, 11.2, 35, 0.0, 'Medium'),
#  (10483, 77, 10.4, 30, 0.0, 'Medium'),
#  (10484, 21, 8, 14, 0.0, 'Small'),
#  (10484, 40, 14.7, 10, 0.0, 'Small'),
#  (10484, 51, 42.4, 3, 0.0, 'Small'),
#  (10485, 2, 15.2, 20, 0.0, 'Medium'),
#  (10485, 3, 8, 20, 0.0, 'Medium'),
#  (10485, 55, 19.2, 30, 0.0, 'Medium'),
#  (10485, 70, 12, 60, 0.0, 'Medium'),
#  (10486, 11, 16.8, 5, 0.0, 'Small'),
#  (10486, 51, 42.4, 25, 0.0, 'Medium'),
#  (10486, 74, 8, 16, 0.0, 'Small'),
#  (10487, 19, 7.3, 5, 0.0, 'Small'),
#  (10487, 26, 24.9, 30, 0.0, 'Medium'),
#  (10487, 54, 5.9, 24, 0.0, 'Medium'),
#  (10488, 59, 44, 30, 0.0, 'Medium'),
#  (10488, 73, 12, 20, 0.0, 'Medium'),
#  (10489, 11, 16.8, 15, 0.0, 'Small'),
#  (10489, 16, 13.9, 18, 0.0, 'Small'),
#  (10490, 59, 44, 60, 0.0, 'Medium'),
#  (10490, 68, 10, 30, 0.0, 'Medium'),
#  (10490, 75, 6.2, 36, 0.0, 'Medium'),
#  (10491, 44, 15.5, 15, 0.0, 'Small'),
#  (10491, 77, 10.4, 7, 0.0, 'Small'),
#  (10492, 25, 11.2, 60, 0.0, 'Medium'),
#  (10492, 42, 11.2, 20, 0.0, 'Medium'),
#  (10493, 65, 16.8, 15, 0.0, 'Small'),
#  (10493, 66, 13.6, 10, 0.0, 'Small'),
#  (10493, 69, 28.8, 10, 0.0, 'Small'),
#  (10494, 56, 30.4, 30, 0.0, 'Medium'),
#  (10495, 23, 7.2, 10, 0.0, 'Small'),
#  (10495, 41, 7.7, 20, 0.0, 'Medium'),
#  (10495, 77, 10.4, 5, 0.0, 'Small'),
#  (10496, 31, 10, 20, 0.0, 'Medium'),
#  (10497, 56, 30.4, 14, 0.0, 'Small'),
#  (10497, 72, 27.8, 25, 0.0, 'Medium'),
#  (10497, 77, 10.4, 25, 0.0, 'Medium'),
#  (10498, 24, 4.5, 14, 0.0, 'Small'),
#  (10498, 40, 18.4, 5, 0.0, 'Small'),
#  (10498, 42, 14, 30, 0.0, 'Medium'),
#  (10499, 28, 45.6, 20, 0.0, 'Medium'),
#  (10499, 49, 20, 25, 0.0, 'Medium'),
#  (10500, 15, 15.5, 12, 0.0, 'Small'),
#  (10500, 28, 45.6, 8, 0.0, 'Small'),
#  (10501, 54, 7.45, 20, 0.0, 'Medium'),
#  (10502, 45, 9.5, 21, 0.0, 'Medium'),
#  (10502, 53, 32.8, 6, 0.0, 'Small'),
#  (10502, 67, 14, 30, 0.0, 'Medium'),
#  (10503, 14, 23.25, 70, 0.0, 'Medium'),
#  (10503, 65, 21.05, 20, 0.0, 'Medium'),
#  (10504, 2, 19, 12, 0.0, 'Small'),
#  (10504, 21, 10, 12, 0.0, 'Small'),
#  (10504, 53, 32.8, 10, 0.0, 'Small'),
#  (10504, 61, 28.5, 25, 0.0, 'Medium'),
#  (10505, 62, 49.3, 3, 0.0, 'Small'),
#  (10506, 25, 14, 18, 0.0, 'Small'),
#  (10506, 70, 15, 14, 0.0, 'Small'),
#  (10507, 43, 46, 15, 0.0, 'Small'),
#  (10507, 48, 12.75, 15, 0.0, 'Small'),
#  (10508, 13, 6, 10, 0.0, 'Small'),
#  (10508, 39, 18, 10, 0.0, 'Small'),
#  (10509, 28, 45.6, 3, 0.0, 'Small'),
#  (10510, 29, 123.79, 36, 0.0, 'Medium'),
#  (10510, 75, 7.75, 36, 0.0, 'Medium'),
#  (10511, 4, 22, 50, 0.0, 'Medium'),
#  (10511, 7, 30, 50, 0.0, 'Medium'),
#  (10511, 8, 40, 10, 0.0, 'Small'),
#  (10512, 24, 4.5, 10, 0.0, 'Small'),
#  (10512, 46, 12, 9, 0.0, 'Small'),
#  (10512, 47, 9.5, 6, 0.0, 'Small'),
#  (10512, 60, 34, 12, 0.0, 'Small'),
#  (10513, 21, 10, 40, 0.0, 'Medium'),
#  (10513, 32, 32, 50, 0.0, 'Medium'),
#  (10513, 61, 28.5, 15, 0.0, 'Small'),
#  (10514, 20, 81, 39, 0.0, 'Medium'),
#  (10514, 28, 45.6, 35, 0.0, 'Medium'),
#  (10514, 56, 38, 70, 0.0, 'Medium'),
#  (10514, 65, 21.05, 39, 0.0, 'Medium'),
#  (10514, 75, 7.75, 50, 0.0, 'Medium'),
#  (10515, 9, 97, 16, 0.0, 'Small'),
#  (10515, 16, 17.45, 50, 0.0, 'Medium'),
#  (10515, 27, 43.9, 120, 0.0, 'Large'),
#  (10515, 33, 2.5, 16, 0.0, 'Small'),
#  (10515, 60, 34, 84, 0.0, 'Medium'),
#  (10516, 18, 62.5, 25, 0.0, 'Medium'),
#  (10516, 41, 9.65, 80, 0.0, 'Medium'),
#  (10516, 42, 14, 20, 0.0, 'Medium'),
#  (10517, 52, 7, 6, 0.0, 'Small'),
#  (10517, 59, 55, 4, 0.0, 'Small'),
#  (10517, 70, 15, 6, 0.0, 'Small'),
#  (10518, 24, 4.5, 5, 0.0, 'Small'),
#  (10518, 38, 263.5, 15, 0.0, 'Small'),
#  (10518, 44, 19.45, 9, 0.0, 'Small'),
#  (10519, 10, 31, 16, 0.0, 'Small'),
#  (10519, 56, 38, 40, 0.0, 'Medium'),
#  (10519, 60, 34, 10, 0.0, 'Small'),
#  (10520, 24, 4.5, 8, 0.0, 'Small'),
#  (10520, 53, 32.8, 5, 0.0, 'Small'),
#  (10521, 35, 18, 3, 0.0, 'Small'),
#  (10521, 41, 9.65, 10, 0.0, 'Small'),
#  (10521, 68, 12.5, 6, 0.0, 'Small'),
#  (10522, 1, 18, 40, 0.0, 'Medium'),
#  (10522, 8, 40, 24, 0.0, 'Medium'),
#  (10522, 30, 25.89, 20, 0.0, 'Medium'),
#  (10522, 40, 18.4, 25, 0.0, 'Medium'),
#  (10523, 17, 39, 25, 0.0, 'Medium'),
#  (10523, 20, 81, 15, 0.0, 'Small'),
#  (10523, 37, 26, 18, 0.0, 'Small'),
#  (10523, 41, 9.65, 6, 0.0, 'Small'),
#  (10524, 10, 31, 2, 0.0, 'Small'),
#  (10524, 30, 25.89, 10, 0.0, 'Small'),
#  (10524, 43, 46, 60, 0.0, 'Medium'),
#  (10524, 54, 7.45, 15, 0.0, 'Small'),
#  (10525, 36, 19, 30, 0.0, 'Medium'),
#  (10525, 40, 18.4, 15, 0.0, 'Small'),
#  (10526, 1, 18, 8, 0.0, 'Small'),
#  (10526, 13, 6, 10, 0.0, 'Small'),
#  (10526, 56, 38, 30, 0.0, 'Medium'),
#  (10527, 4, 22, 50, 0.0, 'Medium'),
#  (10527, 36, 19, 30, 0.0, 'Medium'),
#  (10528, 11, 21, 3, 0.0, 'Small'),
#  (10528, 33, 2.5, 8, 0.0, 'Small'),
#  (10528, 72, 34.8, 9, 0.0, 'Small'),
#  (10529, 55, 24, 14, 0.0, 'Small'),
#  (10529, 68, 12.5, 20, 0.0, 'Medium'),
#  (10529, 69, 36, 10, 0.0, 'Small'),
#  (10530, 17, 39, 40, 0.0, 'Medium'),
#  (10530, 43, 46, 25, 0.0, 'Medium'),
#  (10530, 61, 28.5, 20, 0.0, 'Medium'),
#  (10530, 76, 18, 50, 0.0, 'Medium'),
#  (10531, 59, 55, 2, 0.0, 'Small'),
#  (10532, 30, 25.89, 15, 0.0, 'Small'),
#  (10532, 66, 17, 24, 0.0, 'Medium'),
#  (10533, 4, 22, 50, 0.0, 'Medium'),
#  (10533, 72, 34.8, 24, 0.0, 'Medium'),
#  (10533, 73, 15, 24, 0.0, 'Medium'),
#  (10534, 30, 25.89, 10, 0.0, 'Small'),
#  (10534, 40, 18.4, 10, 0.0, 'Small'),
#  (10534, 54, 7.45, 10, 0.0, 'Small'),
#  (10535, 11, 21, 50, 0.0, 'Medium'),
#  (10535, 40, 18.4, 10, 0.0, 'Small'),
#  (10535, 57, 19.5, 5, 0.0, 'Small'),
#  (10535, 59, 55, 15, 0.0, 'Small'),
#  (10536, 12, 38, 15, 0.0, 'Small'),
#  (10536, 31, 12.5, 20, 0.0, 'Medium'),
#  (10536, 33, 2.5, 30, 0.0, 'Medium'),
#  (10536, 60, 34, 35, 0.0, 'Medium'),
#  (10537, 31, 12.5, 30, 0.0, 'Medium'),
#  (10537, 51, 53, 6, 0.0, 'Small'),
#  (10537, 58, 13.25, 20, 0.0, 'Medium'),
#  (10537, 72, 34.8, 21, 0.0, 'Medium'),
#  (10537, 73, 15, 9, 0.0, 'Small'),
#  (10538, 70, 15, 7, 0.0, 'Small'),
#  (10538, 72, 34.8, 1, 0.0, 'Small'),
#  (10539, 13, 6, 8, 0.0, 'Small'),
#  (10539, 21, 10, 15, 0.0, 'Small'),
#  (10539, 33, 2.5, 15, 0.0, 'Small'),
#  (10539, 49, 20, 6, 0.0, 'Small'),
#  (10540, 3, 10, 60, 0.0, 'Medium'),
#  (10540, 26, 31.23, 40, 0.0, 'Medium'),
#  (10540, 38, 263.5, 30, 0.0, 'Medium'),
#  (10540, 68, 12.5, 35, 0.0, 'Medium'),
#  (10541, 24, 4.5, 35, 0.0, 'Medium'),
#  (10541, 38, 263.5, 4, 0.0, 'Small'),
#  (10541, 65, 21.05, 36, 0.0, 'Medium'),
#  (10541, 71, 21.5, 9, 0.0, 'Small'),
#  (10542, 11, 21, 15, 0.0, 'Small'),
#  (10542, 54, 7.45, 24, 0.0, 'Medium'),
#  (10543, 12, 38, 30, 0.0, 'Medium'),
#  (10543, 23, 9, 70, 0.0, 'Medium'),
#  (10544, 28, 45.6, 7, 0.0, 'Small'),
#  (10544, 67, 14, 7, 0.0, 'Small'),
#  (10545, 11, 21, 10, 0.0, 'Small'),
#  (10546, 7, 30, 10, 0.0, 'Small'),
#  (10546, 35, 18, 30, 0.0, 'Medium'),
#  (10546, 62, 49.3, 40, 0.0, 'Medium'),
#  (10547, 32, 32, 24, 0.0, 'Medium'),
#  (10547, 36, 19, 60, 0.0, 'Medium'),
#  (10548, 34, 14, 10, 0.0, 'Small'),
#  (10548, 41, 9.65, 14, 0.0, 'Small'),
#  (10549, 31, 12.5, 55, 0.0, 'Medium'),
#  (10549, 45, 9.5, 100, 0.0, 'Medium'),
#  (10549, 51, 53, 48, 0.0, 'Medium'),
#  (10550, 17, 39, 8, 0.0, 'Small'),
#  (10550, 19, 9.2, 10, 0.0, 'Small'),
#  (10550, 21, 10, 6, 0.0, 'Small'),
#  (10550, 61, 28.5, 10, 0.0, 'Small'),
#  (10551, 16, 17.45, 40, 0.0, 'Medium'),
#  (10551, 35, 18, 20, 0.0, 'Medium'),
#  (10551, 44, 19.45, 40, 0.0, 'Medium'),
#  (10552, 69, 36, 18, 0.0, 'Small'),
#  (10552, 75, 7.75, 30, 0.0, 'Medium'),
#  (10553, 11, 21, 15, 0.0, 'Small'),
#  (10553, 16, 17.45, 14, 0.0, 'Small'),
#  (10553, 22, 21, 24, 0.0, 'Medium'),
#  (10553, 31, 12.5, 30, 0.0, 'Medium'),
#  (10553, 35, 18, 6, 0.0, 'Small'),
#  (10554, 16, 17.45, 30, 0.0, 'Medium'),
#  (10554, 23, 9, 20, 0.0, 'Medium'),
#  (10554, 62, 49.3, 20, 0.0, 'Medium'),
#  (10554, 77, 13, 10, 0.0, 'Small'),
#  (10555, 14, 23.25, 30, 0.0, 'Medium'),
#  (10555, 19, 9.2, 35, 0.0, 'Medium'),
#  (10555, 24, 4.5, 18, 0.0, 'Small'),
#  (10555, 51, 53, 20, 0.0, 'Medium'),
#  (10555, 56, 38, 40, 0.0, 'Medium'),
#  (10556, 72, 34.8, 24, 0.0, 'Medium'),
#  (10557, 64, 33.25, 30, 0.0, 'Medium'),
#  (10557, 75, 7.75, 20, 0.0, 'Medium'),
#  (10558, 47, 9.5, 25, 0.0, 'Medium'),
#  (10558, 51, 53, 20, 0.0, 'Medium'),
#  (10558, 52, 7, 30, 0.0, 'Medium'),
#  (10558, 53, 32.8, 18, 0.0, 'Small'),
#  (10558, 73, 15, 3, 0.0, 'Small'),
#  (10559, 41, 9.65, 12, 0.0, 'Small'),
#  (10559, 55, 24, 18, 0.0, 'Small'),
#  (10560, 30, 25.89, 20, 0.0, 'Medium'),
#  (10560, 62, 49.3, 15, 0.0, 'Small'),
#  (10561, 44, 19.45, 10, 0.0, 'Small'),
#  (10561, 51, 53, 50, 0.0, 'Medium'),
#  (10562, 33, 2.5, 20, 0.0, 'Medium'),
#  (10562, 62, 49.3, 10, 0.0, 'Small'),
#  (10563, 36, 19, 25, 0.0, 'Medium'),
#  (10563, 52, 7, 70, 0.0, 'Medium'),
#  (10564, 17, 39, 16, 0.0, 'Small'),
#  (10564, 31, 12.5, 6, 0.0, 'Small'),
#  (10564, 55, 24, 25, 0.0, 'Medium'),
#  (10565, 24, 4.5, 25, 0.0, 'Medium'),
#  (10565, 64, 33.25, 18, 0.0, 'Small'),
#  (10566, 11, 21, 35, 0.0, 'Medium'),
#  (10566, 18, 62.5, 18, 0.0, 'Small'),
#  (10566, 76, 18, 10, 0.0, 'Small'),
#  (10567, 31, 12.5, 60, 0.0, 'Medium'),
#  (10567, 51, 53, 3, 0.0, 'Small'),
#  (10567, 59, 55, 40, 0.0, 'Medium'),
#  (10568, 10, 31, 5, 0.0, 'Small'),
#  (10569, 31, 12.5, 35, 0.0, 'Medium'),
#  (10569, 76, 18, 30, 0.0, 'Medium'),
#  (10570, 11, 21, 15, 0.0, 'Small'),
#  (10570, 56, 38, 60, 0.0, 'Medium'),
#  (10571, 14, 23.25, 11, 0.0, 'Small'),
#  (10571, 42, 14, 28, 0.0, 'Medium'),
#  (10572, 16, 17.45, 12, 0.0, 'Small'),
#  (10572, 32, 32, 10, 0.0, 'Small'),
#  (10572, 40, 18.4, 50, 0.0, 'Medium'),
#  (10572, 75, 7.75, 15, 0.0, 'Small'),
#  (10573, 17, 39, 18, 0.0, 'Small'),
#  (10573, 34, 14, 40, 0.0, 'Medium'),
#  (10573, 53, 32.8, 25, 0.0, 'Medium'),
#  (10574, 33, 2.5, 14, 0.0, 'Small'),
#  (10574, 40, 18.4, 2, 0.0, 'Small'),
#  (10574, 62, 49.3, 10, 0.0, 'Small'),
#  (10574, 64, 33.25, 6, 0.0, 'Small'),
#  (10575, 59, 55, 12, 0.0, 'Small'),
#  (10575, 63, 43.9, 6, 0.0, 'Small'),
#  (10575, 72, 34.8, 30, 0.0, 'Medium'),
#  (10575, 76, 18, 10, 0.0, 'Small'),
#  (10576, 1, 18, 10, 0.0, 'Small'),
#  (10576, 31, 12.5, 20, 0.0, 'Medium'),
#  (10576, 44, 19.45, 21, 0.0, 'Medium'),
#  (10577, 39, 18, 10, 0.0, 'Small'),
#  (10577, 75, 7.75, 20, 0.0, 'Medium'),
#  (10577, 77, 13, 18, 0.0, 'Small'),
#  (10578, 35, 18, 20, 0.0, 'Medium'),
#  (10578, 57, 19.5, 6, 0.0, 'Small'),
#  (10579, 15, 15.5, 10, 0.0, 'Small'),
#  (10579, 75, 7.75, 21, 0.0, 'Medium'),
#  (10580, 14, 23.25, 15, 0.0, 'Small'),
#  (10580, 41, 9.65, 9, 0.0, 'Small'),
#  (10580, 65, 21.05, 30, 0.0, 'Medium'),
#  (10581, 75, 7.75, 50, 0.0, 'Medium'),
#  (10582, 57, 19.5, 4, 0.0, 'Small'),
#  (10582, 76, 18, 14, 0.0, 'Small'),
#  (10583, 29, 123.79, 10, 0.0, 'Small'),
#  (10583, 60, 34, 24, 0.0, 'Medium'),
#  (10583, 69, 36, 10, 0.0, 'Small'),
#  (10584, 31, 12.5, 50, 0.0, 'Medium'),
#  (10585, 47, 9.5, 15, 0.0, 'Small'),
#  (10586, 52, 7, 4, 0.0, 'Small'),
#  (10587, 26, 31.23, 6, 0.0, 'Small'),
#  (10587, 35, 18, 20, 0.0, 'Medium'),
#  (10587, 77, 13, 20, 0.0, 'Medium'),
#  (10588, 18, 62.5, 40, 0.0, 'Medium'),
#  (10588, 42, 14, 100, 0.0, 'Medium'),
#  (10589, 35, 18, 4, 0.0, 'Small'),
#  (10590, 1, 18, 20, 0.0, 'Medium'),
#  (10590, 77, 13, 60, 0.0, 'Medium'),
#  (10591, 3, 10, 14, 0.0, 'Small'),
#  (10591, 7, 30, 10, 0.0, 'Small'),
#  (10591, 54, 7.45, 50, 0.0, 'Medium'),
#  (10592, 15, 15.5, 25, 0.0, 'Medium'),
#  (10592, 26, 31.23, 5, 0.0, 'Small'),
#  (10593, 20, 81, 21, 0.0, 'Medium'),
#  (10593, 69, 36, 20, 0.0, 'Medium'),
#  (10593, 76, 18, 4, 0.0, 'Small'),
#  (10594, 52, 7, 24, 0.0, 'Medium'),
#  (10594, 58, 13.25, 30, 0.0, 'Medium'),
#  (10595, 35, 18, 30, 0.0, 'Medium'),
#  (10595, 61, 28.5, 120, 0.0, 'Large'),
#  (10595, 69, 36, 65, 0.0, 'Medium'),
#  (10596, 56, 38, 5, 0.0, 'Small'),
#  (10596, 63, 43.9, 24, 0.0, 'Medium'),
#  (10596, 75, 7.75, 30, 0.0, 'Medium'),
#  (10597, 24, 4.5, 35, 0.0, 'Medium'),
#  (10597, 57, 19.5, 20, 0.0, 'Medium'),
#  (10597, 65, 21.05, 12, 0.0, 'Small'),
#  (10598, 27, 43.9, 50, 0.0, 'Medium'),
#  (10598, 71, 21.5, 9, 0.0, 'Small'),
#  (10599, 62, 49.3, 10, 0.0, 'Small'),
#  (10600, 54, 7.45, 4, 0.0, 'Small'),
#  (10600, 73, 15, 30, 0.0, 'Medium'),
#  (10601, 13, 6, 60, 0.0, 'Medium'),
#  (10601, 59, 55, 35, 0.0, 'Medium'),
#  (10602, 77, 13, 5, 0.0, 'Small'),
#  (10603, 22, 21, 48, 0.0, 'Medium'),
#  (10603, 49, 20, 25, 0.0, 'Medium'),
#  (10604, 48, 12.75, 6, 0.0, 'Small'),
#  (10604, 76, 18, 10, 0.0, 'Small'),
#  (10605, 16, 17.45, 30, 0.0, 'Medium'),
#  (10605, 59, 55, 20, 0.0, 'Medium'),
#  (10605, 60, 34, 70, 0.0, 'Medium'),
#  (10605, 71, 21.5, 15, 0.0, 'Small'),
#  (10606, 4, 22, 20, 0.0, 'Medium'),
#  (10606, 55, 24, 20, 0.0, 'Medium'),
#  (10606, 62, 49.3, 10, 0.0, 'Small'),
#  (10607, 7, 30, 45, 0.0, 'Medium'),
#  (10607, 17, 39, 100, 0.0, 'Medium'),
#  (10607, 33, 2.5, 14, 0.0, 'Small'),
#  (10607, 40, 18.4, 42, 0.0, 'Medium'),
#  (10607, 72, 34.8, 12, 0.0, 'Small'),
#  (10608, 56, 38, 28, 0.0, 'Medium'),
#  (10609, 1, 18, 3, 0.0, 'Small'),
#  (10609, 10, 31, 10, 0.0, 'Small'),
#  (10609, 21, 10, 6, 0.0, 'Small'),
#  (10610, 36, 19, 21, 0.0, 'Medium'),
#  (10611, 1, 18, 6, 0.0, 'Small'),
#  (10611, 2, 19, 10, 0.0, 'Small'),
#  (10611, 60, 34, 15, 0.0, 'Small'),
#  (10612, 10, 31, 70, 0.0, 'Medium'),
#  (10612, 36, 19, 55, 0.0, 'Medium'),
#  (10612, 49, 20, 18, 0.0, 'Small'),
#  (10612, 60, 34, 40, 0.0, 'Medium'),
#  (10612, 76, 18, 80, 0.0, 'Medium'),
#  (10613, 13, 6, 8, 0.0, 'Small'),
#  (10613, 75, 7.75, 40, 0.0, 'Medium'),
#  (10614, 11, 21, 14, 0.0, 'Small'),
#  (10614, 21, 10, 8, 0.0, 'Small'),
#  (10614, 39, 18, 5, 0.0, 'Small'),
#  (10615, 55, 24, 5, 0.0, 'Small'),
#  (10616, 38, 263.5, 15, 0.0, 'Small'),
#  (10616, 56, 38, 14, 0.0, 'Small'),
#  (10616, 70, 15, 15, 0.0, 'Small'),
#  (10616, 71, 21.5, 15, 0.0, 'Small'),
#  (10617, 59, 55, 30, 0.0, 'Medium'),
#  (10618, 6, 25, 70, 0.0, 'Medium'),
#  (10618, 56, 38, 20, 0.0, 'Medium'),
#  (10618, 68, 12.5, 15, 0.0, 'Small'),
#  (10619, 21, 10, 42, 0.0, 'Medium'),
#  (10619, 22, 21, 40, 0.0, 'Medium'),
#  (10620, 24, 4.5, 5, 0.0, 'Small'),
#  (10620, 52, 7, 5, 0.0, 'Small'),
#  (10621, 19, 9.2, 5, 0.0, 'Small'),
#  (10621, 23, 9, 10, 0.0, 'Small'),
#  (10621, 70, 15, 20, 0.0, 'Medium'),
#  (10621, 71, 21.5, 15, 0.0, 'Small'),
#  (10622, 2, 19, 20, 0.0, 'Medium'),
#  (10622, 68, 12.5, 18, 0.0, 'Small'),
#  (10623, 14, 23.25, 21, 0.0, 'Medium'),
#  (10623, 19, 9.2, 15, 0.0, 'Small'),
#  (10623, 21, 10, 25, 0.0, 'Medium'),
#  (10623, 24, 4.5, 3, 0.0, 'Small'),
#  (10623, 35, 18, 30, 0.0, 'Medium'),
#  (10624, 28, 45.6, 10, 0.0, 'Small'),
#  (10624, 29, 123.79, 6, 0.0, 'Small'),
#  (10624, 44, 19.45, 10, 0.0, 'Small'),
#  (10625, 14, 23.25, 3, 0.0, 'Small'),
#  (10625, 42, 14, 5, 0.0, 'Small'),
#  (10625, 60, 34, 10, 0.0, 'Small'),
#  ...]

# %% [markdown]
# ### 3. Replace country if `NULL`
#
# Suppose some records in the `Customers` table have null values in the `Country` column. Write a SQL query that retrieves all customers, and if the country of a customer is `NULL`, replace it with the text 'Not Provided'.

# %%
# %%sql
# SELECT
#     *,
#     CASE
#         WHEN Country IS NULL THEN 'Not Provided'
#         ELSE Country
#     END AS Country_Status
# FROM Customers;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', None, '12209', 'Germany', '030-0074321', '030-0076545', 'Germany'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitucin 2222', 'Mxico D.F.', None, '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745', 'Mexico'),
#  ('ANTON', 'Antonio Moreno Taquera', 'Antonio Moreno', 'Owner', 'Mataderos  2312', 'Mxico D.F.', None, '05023', 'Mexico', '(5) 555-3932', None, 'Mexico'),
#  ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', None, 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750', 'UK'),
#  ('BERGS', 'Berglunds snabbkp', 'Christina Berglund', 'Order Administrator', 'Berguvsvgen  8', 'Lule', None, 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67', 'Sweden'),
#  ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Sales Representative', 'Forsterstr. 57', 'Mannheim', None, '68306', 'Germany', '0621-08460', '0621-08924', 'Germany'),
#  ('BLONP', 'Blondesddsl pre et fils', 'Frdrique Citeaux', 'Marketing Manager', '24, place Klber', 'Strasbourg', None, '67000', 'France', '88.60.15.31', '88.60.15.32', 'France'),
#  ('BOLID', 'Blido Comidas preparadas', 'Martn Sommer', 'Owner', 'C/ Araquil, 67', 'Madrid', None, '28023', 'Spain', '(91) 555 22 82', '(91) 555 91 99', 'Spain'),
#  ('BONAP', "Bon app'", 'Laurence Lebihan', 'Owner', '12, rue des Bouchers', 'Marseille', None, '13008', 'France', '91.24.45.40', '91.24.45.41', 'France'),
#  ('BOTTM', 'Bottom-Dollar Markets', 'Elizabeth Lincoln', 'Accounting Manager', '23 Tsawassen Blvd.', 'Tsawassen', 'BC', 'T2F 8M4', 'Canada', '(604) 555-4729', '(604) 555-3745', 'Canada'),
#  ('BSBEV', "B's Beverages", 'Victoria Ashworth', 'Sales Representative', 'Fauntleroy Circus', 'London', None, 'EC2 5NT', 'UK', '(171) 555-1212', None, 'UK'),
#  ('CACTU', 'Cactus Comidas para llevar', 'Patricio Simpson', 'Sales Agent', 'Cerrito 333', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5555', '(1) 135-4892', 'Argentina'),
#  ('CENTC', 'Centro comercial Moctezuma', 'Francisco Chang', 'Marketing Manager', 'Sierras de Granada 9993', 'Mxico D.F.', None, '05022', 'Mexico', '(5) 555-3392', '(5) 555-7293', 'Mexico'),
#  ('CHOPS', 'Chop-suey Chinese', 'Yang Wang', 'Owner', 'Hauptstr. 29', 'Bern', None, '3012', 'Switzerland', '0452-076545', None, 'Switzerland'),
#  ('COMMI', 'Comrcio Mineiro', 'Pedro Afonso', 'Sales Associate', 'Av. dos Lusadas, 23', 'Sao Paulo', 'SP', '05432-043', 'Brazil', '(11) 555-7647', None, 'Brazil'),
#  ('CONSH', 'Consolidated Holdings', 'Elizabeth Brown', 'Sales Representative', 'Berkeley Gardens 12  Brewery', 'London', None, 'WX1 6LT', 'UK', '(171) 555-2282', '(171) 555-9199', 'UK'),
#  ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Order Administrator', 'Walserweg 21', 'Aachen', None, '52066', 'Germany', '0241-039123', '0241-059428', 'Germany'),
#  ('DUMON', 'Du monde entier', 'Janine Labrune', 'Owner', '67, rue des Cinquante Otages', 'Nantes', None, '44000', 'France', '40.67.88.88', '40.67.89.89', 'France'),
#  ('EASTC', 'Eastern Connection', 'Ann Devon', 'Sales Agent', '35 King George', 'London', None, 'WX3 6FW', 'UK', '(171) 555-0297', '(171) 555-3373', 'UK'),
#  ('ERNSH', 'Ernst Handel', 'Roland Mendel', 'Sales Manager', 'Kirchgasse 6', 'Graz', None, '8010', 'Austria', '7675-3425', '7675-3426', 'Austria'),
#  ('FAMIA', 'Familia Arquibaldo', 'Aria Cruz', 'Marketing Assistant', 'Rua Ors, 92', 'Sao Paulo', 'SP', '05442-030', 'Brazil', '(11) 555-9857', None, 'Brazil'),
#  ('FISSA', 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'Accounting Manager', 'C/ Moralzarzal, 86', 'Madrid', None, '28034', 'Spain', '(91) 555 94 44', '(91) 555 55 93', 'Spain'),
#  ('FOLIG', 'Folies gourmandes', 'Martine Ranc', 'Assistant Sales Agent', '184, chausse de Tournai', 'Lille', None, '59000', 'France', '20.16.10.16', '20.16.10.17', 'France'),
#  ('FOLKO', 'Folk och f HB', 'Maria Larsson', 'Owner', 'kergatan 24', 'Brcke', None, 'S-844 67', 'Sweden', '0695-34 67 21', None, 'Sweden'),
#  ('FRANK', 'Frankenversand', 'Peter Franken', 'Marketing Manager', 'Berliner Platz 43', 'Mnchen', None, '80805', 'Germany', '089-0877310', '089-0877451', 'Germany'),
#  ('FRANR', 'France restauration', 'Carine Schmitt', 'Marketing Manager', '54, rue Royale', 'Nantes', None, '44000', 'France', '40.32.21.21', '40.32.21.20', 'France'),
#  ('FRANS', 'Franchi S.p.A.', 'Paolo Accorti', 'Sales Representative', 'Via Monte Bianco 34', 'Torino', None, '10100', 'Italy', '011-4988260', '011-4988261', 'Italy'),
#  ('FURIB', 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Sales Manager', 'Jardim das rosas n. 32', 'Lisboa', None, '1675', 'Portugal', '(1) 354-2534', '(1) 354-2535', 'Portugal'),
#  ('GALED', 'Galera del gastrnomo', 'Eduardo Saavedra', 'Marketing Manager', 'Rambla de Catalua, 23', 'Barcelona', None, '08022', 'Spain', '(93) 203 4560', '(93) 203 4561', 'Spain'),
#  ('GODOS', 'Godos Cocina Tpica', 'Jos Pedro Freyre', 'Sales Manager', 'C/ Romero, 33', 'Sevilla', None, '41101', 'Spain', '(95) 555 82 82', None, 'Spain'),
#  ('GOURL', 'Gourmet Lanchonetes', 'Andr Fonseca', 'Sales Associate', 'Av. Brasil, 442', 'Campinas', 'SP', '04876-786', 'Brazil', '(11) 555-9482', None, 'Brazil'),
#  ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', 'Marketing Manager', '2732 Baker Blvd.', 'Eugene', 'OR', '97403', 'USA', '(503) 555-7555', None, 'USA'),
#  ('GROSR', 'GROSELLA-Restaurante', 'Manuel Pereira', 'Owner', '5 Ave. Los Palos Grandes', 'Caracas', 'DF', '1081', 'Venezuela', '(2) 283-2951', '(2) 283-3397', 'Venezuela'),
#  ('HANAR', 'Hanari Carnes', 'Mario Pontes', 'Accounting Manager', 'Rua do Pao, 67', 'Rio de Janeiro', 'RJ', '05454-876', 'Brazil', '(21) 555-0091', '(21) 555-8765', 'Brazil'),
#  ('HILAA', 'HILARION-Abastos', 'Carlos Hernndez', 'Sales Representative', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristbal', 'Tchira', '5022', 'Venezuela', '(5) 555-1340', '(5) 555-1948', 'Venezuela'),
#  ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'Sales Representative', 'City Center Plaza 516 Main St.', 'Elgin', 'OR', '97827', 'USA', '(503) 555-6874', '(503) 555-2376', 'USA'),
#  ('HUNGO', 'Hungry Owl All-Night Grocers', 'Patricia McKenna', 'Sales Associate', '8 Johnstown Road', 'Cork', 'Co. Cork', None, 'Ireland', '2967 542', '2967 3333', 'Ireland'),
#  ('ISLAT', 'Island Trading', 'Helen Bennett', 'Marketing Manager', 'Garden House Crowther Way', 'Cowes', 'Isle of Wight', 'PO31 7PJ', 'UK', '(198) 555-8888', None, 'UK'),
#  ('KOENE', 'Kniglich Essen', 'Philip Cramer', 'Sales Associate', 'Maubelstr. 90', 'Brandenburg', None, '14776', 'Germany', '0555-09876', None, 'Germany'),
#  ('LACOR', "La corne d'abondance", 'Daniel Tonini', 'Sales Representative', "67, avenue de l'Europe", 'Versailles', None, '78000', 'France', '30.59.84.10', '30.59.85.11', 'France'),
#  ('LAMAI', "La maison d'Asie", 'Annette Roulet', 'Sales Manager', '1 rue Alsace-Lorraine', 'Toulouse', None, '31000', 'France', '61.77.61.10', '61.77.61.11', 'France'),
#  ('LAUGB', 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', 'Marketing Assistant', '1900 Oak St.', 'Vancouver', 'BC', 'V3F 2K1', 'Canada', '(604) 555-3392', '(604) 555-7293', 'Canada'),
#  ('LAZYK', 'Lazy K Kountry Store', 'John Steel', 'Marketing Manager', '12 Orchestra Terrace', 'Walla Walla', 'WA', '99362', 'USA', '(509) 555-7969', '(509) 555-6221', 'USA'),
#  ('LEHMS', 'Lehmanns Marktstand', 'Renate Messner', 'Sales Representative', 'Magazinweg 7', 'Frankfurt a.M.', None, '60528', 'Germany', '069-0245984', '069-0245874', 'Germany'),
#  ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', 'Owner', '87 Polk St. Suite 5', 'San Francisco', 'CA', '94117', 'USA', '(415) 555-5938', None, 'USA'),
#  ('LILAS', 'LILA-Supermercado', 'Carlos Gonzlez', 'Accounting Manager', 'Carrera 52 con Ave. Bolvar #65-98 Llano Largo', 'Barquisimeto', 'Lara', '3508', 'Venezuela', '(9) 331-6954', '(9) 331-7256', 'Venezuela'),
#  ('LINOD', 'LINO-Delicateses', 'Felipe Izquierdo', 'Owner', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', 'Nueva Esparta', '4980', 'Venezuela', '(8) 34-56-12', '(8) 34-93-93', 'Venezuela'),
#  ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', 'Sales Manager', '89 Chiaroscuro Rd.', 'Portland', 'OR', '97219', 'USA', '(503) 555-9573', '(503) 555-9646', 'USA'),
#  ('MAGAA', 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Marketing Manager', 'Via Ludovico il Moro 22', 'Bergamo', None, '24100', 'Italy', '035-640230', '035-640231', 'Italy'),
#  ('MAISD', 'Maison Dewey', 'Catherine Dewey', 'Sales Agent', 'Rue Joseph-Bens 532', 'Bruxelles', None, 'B-1180', 'Belgium', '(02) 201 24 67', '(02) 201 24 68', 'Belgium'),
#  ('MEREP', 'Mre Paillarde', 'Jean Fresnire', 'Marketing Assistant', '43 rue St. Laurent', 'Montral', 'Qubec', 'H1J 1C3', 'Canada', '(514) 555-8054', '(514) 555-8055', 'Canada'),
#  ('MORGK', 'Morgenstern Gesundkost', 'Alexander Feuer', 'Marketing Assistant', 'Heerstr. 22', 'Leipzig', None, '04179', 'Germany', '0342-023176', None, 'Germany'),
#  ('NORTS', 'North/South', 'Simon Crowther', 'Sales Associate', 'South House 300 Queensbridge', 'London', None, 'SW7 1RZ', 'UK', '(171) 555-7733', '(171) 555-2530', 'UK'),
#  ('OCEAN', 'Ocano Atlntico Ltda.', 'Yvonne Moncada', 'Sales Agent', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', None, '1010', 'Argentina', '(1) 135-5333', '(1) 135-5535', 'Argentina'),
#  ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', 'Sales Representative', '2743 Bering St.', 'Anchorage', 'AK', '99508', 'USA', '(907) 555-7584', '(907) 555-2880', 'USA'),
#  ('OTTIK', 'Ottilies Kseladen', 'Henriette Pfalzheim', 'Owner', 'Mehrheimerstr. 369', 'Kln', None, '50739', 'Germany', '0221-0644327', '0221-0765721', 'Germany'),
#  ('PARIS', 'Paris spcialits', 'Marie Bertrand', 'Owner', '265, boulevard Charonne', 'Paris', None, '75012', 'France', '(1) 42.34.22.66', '(1) 42.34.22.77', 'France'),
#  ('PERIC', 'Pericles Comidas clsicas', 'Guillermo Fernndez', 'Sales Representative', 'Calle Dr. Jorge Cash 321', 'Mxico D.F.', None, '05033', 'Mexico', '(5) 552-3745', '(5) 545-3745', 'Mexico'),
#  ('PICCO', 'Piccolo und mehr', 'Georg Pipps', 'Sales Manager', 'Geislweg 14', 'Salzburg', None, '5020', 'Austria', '6562-9722', '6562-9723', 'Austria'),
#  ('PRINI', 'Princesa Isabel Vinhos', 'Isabel de Castro', 'Sales Representative', 'Estrada da sade n. 58', 'Lisboa', None, '1756', 'Portugal', '(1) 356-5634', None, 'Portugal'),
#  ('QUEDE', 'Que Delcia', 'Bernardo Batista', 'Accounting Manager', 'Rua da Panificadora, 12', 'Rio de Janeiro', 'RJ', '02389-673', 'Brazil', '(21) 555-4252', '(21) 555-4545', 'Brazil'),
#  ('QUEEN', 'Queen Cozinha', 'Lcia Carvalho', 'Marketing Assistant', 'Alameda dos Canrios, 891', 'Sao Paulo', 'SP', '05487-020', 'Brazil', '(11) 555-1189', None, 'Brazil'),
#  ('QUICK', 'QUICK-Stop', 'Horst Kloss', 'Accounting Manager', 'Taucherstrae 10', 'Cunewalde', None, '01307', 'Germany', '0372-035188', None, 'Germany'),
#  ('RANCH', 'Rancho grande', 'Sergio Gutirrez', 'Sales Representative', 'Av. del Libertador 900', 'Buenos Aires', None, '1010', 'Argentina', '(1) 123-5555', '(1) 123-5556', 'Argentina'),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', 'Assistant Sales Representative', '2817 Milton Dr.', 'Albuquerque', 'NM', '87110', 'USA', '(505) 555-5939', '(505) 555-3620', 'USA'),
#  ('REGGC', 'Reggiani Caseifici', 'Maurizio Moroni', 'Sales Associate', 'Strada Provinciale 124', 'Reggio Emilia', None, '42100', 'Italy', '0522-556721', '0522-556722', 'Italy'),
#  ('RICAR', 'Ricardo Adocicados', 'Janete Limeira', 'Assistant Sales Agent', 'Av. Copacabana, 267', 'Rio de Janeiro', 'RJ', '02389-890', 'Brazil', '(21) 555-3412', None, 'Brazil'),
#  ('RICSU', 'Richter Supermarkt', 'Michael Holz', 'Sales Manager', 'Grenzacherweg 237', 'Genve', None, '1203', 'Switzerland', '0897-034214', None, 'Switzerland'),
#  ('ROMEY', 'Romero y tomillo', 'Alejandra Camino', 'Accounting Manager', 'Gran Va, 1', 'Madrid', None, '28001', 'Spain', '(91) 745 6200', '(91) 745 6210', 'Spain'),
#  ('SANTG', 'Sant Gourmet', 'Jonas Bergulfsen', 'Owner', 'Erling Skakkes gate 78', 'Stavern', None, '4110', 'Norway', '07-98 92 35', '07-98 92 47', 'Norway'),
#  ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', 'Sales Representative', '187 Suffolk Ln.', 'Boise', 'ID', '83720', 'USA', '(208) 555-8097', None, 'USA'),
#  ('SEVES', 'Seven Seas Imports', 'Hari Kumar', 'Sales Manager', '90 Wadhurst Rd.', 'London', None, 'OX15 4NB', 'UK', '(171) 555-1717', '(171) 555-5646', 'UK'),
#  ('SIMOB', 'Simons bistro', 'Jytte Petersen', 'Owner', 'Vinbltet 34', 'Kobenhavn', None, '1734', 'Denmark', '31 12 34 56', '31 13 35 57', 'Denmark'),
#  ('SPECD', 'Spcialits du monde', 'Dominique Perrier', 'Marketing Manager', '25, rue Lauriston', 'Paris', None, '75016', 'France', '(1) 47.55.60.10', '(1) 47.55.60.20', 'France'),
#  ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'Sales Manager', 'P.O. Box 555', 'Lander', 'WY', '82520', 'USA', '(307) 555-4680', '(307) 555-6525', 'USA'),
#  ('SUPRD', 'Suprmes dlices', 'Pascale Cartrain', 'Accounting Manager', 'Boulevard Tirou, 255', 'Charleroi', None, 'B-6000', 'Belgium', '(071) 23 67 22 20', '(071) 23 67 22 21', 'Belgium'),
#  ('THEBI', 'The Big Cheese', 'Liz Nixon', 'Marketing Manager', '89 Jefferson Way Suite 2', 'Portland', 'OR', '97201', 'USA', '(503) 555-3612', None, 'USA'),
#  ('THECR', 'The Cracker Box', 'Liu Wong', 'Marketing Assistant', '55 Grizzly Peak Rd.', 'Butte', 'MT', '59801', 'USA', '(406) 555-5834', '(406) 555-8083', 'USA'),
#  ('TOMSP', 'Toms Spezialitten', 'Karin Josephs', 'Marketing Manager', 'Luisenstr. 48', 'Mnster', None, '44087', 'Germany', '0251-031259', '0251-035695', 'Germany'),
#  ('TORTU', 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Owner', 'Avda. Azteca 123', 'Mxico D.F.', None, '05033', 'Mexico', '(5) 555-2933', None, 'Mexico'),
#  ('TRADH', 'Tradio Hipermercados', 'Anabela Domingues', 'Sales Representative', 'Av. Ins de Castro, 414', 'Sao Paulo', 'SP', '05634-030', 'Brazil', '(11) 555-2167', '(11) 555-2168', 'Brazil'),
#  ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', 'Sales Associate', '722 DaVinci Blvd.', 'Kirkland', 'WA', '98034', 'USA', '(206) 555-8257', '(206) 555-2174', 'USA'),
#  ('VAFFE', 'Vaffeljernet', 'Palle Ibsen', 'Sales Manager', 'Smagsloget 45', 'rhus', None, '8200', 'Denmark', '86 21 32 43', '86 22 33 44', 'Denmark'),
#  ('Val2 ', 'IT', 'Val2', 'IT', None, None, None, None, None, None, None, 'Not Provided'),
#  ('VALON', 'IT', 'Valon Hoti', 'IT', None, None, None, None, None, None, None, 'Not Provided'),
#  ('VICTE', 'Victuailles en stock', 'Mary Saveley', 'Sales Agent', '2, rue du Commerce', 'Lyon', None, '69004', 'France', '78.32.54.86', '78.32.54.87', 'France'),
#  ('VINET', 'Vins et alcools Chevalier', 'Paul Henriot', 'Accounting Manager', "59 rue de l'Abbaye", 'Reims', None, '51100', 'France', '26.47.15.10', '26.47.15.11', 'France'),
#  ('WANDK', 'Die Wandernde Kuh', 'Rita Mller', 'Sales Representative', 'Adenauerallee 900', 'Stuttgart', None, '70563', 'Germany', '0711-020361', '0711-035428', 'Germany'),
#  ('WARTH', 'Wartian Herkku', 'Pirkko Koskitalo', 'Accounting Manager', 'Torikatu 38', 'Oulu', None, '90110', 'Finland', '981-443655', '981-443655', 'Finland'),
#  ('WELLI', 'Wellington Importadora', 'Paula Parente', 'Sales Manager', 'Rua do Mercado, 12', 'Resende', 'SP', '08737-363', 'Brazil', '(14) 555-8122', None, 'Brazil'),
#  ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115', 'USA'),
#  ('WILMK', 'Wilman Kala', 'Matti Karttunen', 'Owner/Marketing Assistant', 'Keskuskatu 45', 'Helsinki', None, '21240', 'Finland', '90-224 8858', '90-224 8858', 'Finland'),
#  ('WOLZA', 'Wolski  Zajazd', 'Zbyszek Piestrzeniewicz', 'Owner', 'ul. Filtrowa 68', 'Warszawa', None, '01-012', 'Poland', '(26) 642-7012', '(26) 642-7012', 'Poland')]

# %% [markdown]
# ### 4. Calculate the average price of products
#
# Using the `Products` table, write a SQL query that calculates the average unit price of all products. Then, for each product, show its name, unit price, and a column `Price Comparison` that shows whether its price is 'Below Average', 'Average', or 'Above Average'.

# %%
# %%sql
# SELECT
#     *,
#     (SELECT AVG(UnitPrice) FROM Products) AS Avg_UnitPrice,
#     CASE
#         WHEN UnitPrice < (SELECT AVG(UnitPrice) FROM Products) THEN 'Below Average'
#         WHEN UnitPrice = (SELECT AVG(UnitPrice) FROM Products) THEN 'Average'
#         WHEN UnitPrice > (SELECT AVG(UnitPrice) FROM Products) THEN 'Above Average'
#         ELSE 'Unknown'
#     END AS Price_comparison
# FROM Products;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [(1, 'Chai', 1, 1, '10 boxes x 20 bags', 18, 39, 0, 10, 0, 28.866363636363637, 'Below Average'),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19, 17, 40, 25, 0, 28.866363636363637, 'Below Average'),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10, 13, 70, 25, 0, 28.866363636363637, 'Below Average'),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22, 53, 0, 0, 0, 28.866363636363637, 'Below Average'),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21.35, 0, 0, 0, 1, 28.866363636363637, 'Below Average'),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25, 120, 0, 25, 0, 28.866363636363637, 'Below Average'),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30, 15, 0, 10, 0, 28.866363636363637, 'Above Average'),
#  (8, 'Northwoods Cranberry Sauce', 3, 2, '12 - 12 oz jars', 40, 6, 0, 0, 0, 28.866363636363637, 'Above Average'),
#  (9, 'Mishi Kobe Niku', 4, 6, '18 - 500 g pkgs.', 97, 29, 0, 0, 1, 28.866363636363637, 'Above Average'),
#  (10, 'Ikura', 4, 8, '12 - 200 ml jars', 31, 31, 0, 0, 0, 28.866363636363637, 'Above Average'),
#  (11, 'Queso Cabrales', 5, 4, '1 kg pkg.', 21, 22, 30, 30, 0, 28.866363636363637, 'Below Average'),
#  (12, 'Queso Manchego La Pastora', 5, 4, '10 - 500 g pkgs.', 38, 86, 0, 0, 0, 28.866363636363637, 'Above Average'),
#  (13, 'Konbu', 6, 8, '2 kg box', 6, 24, 0, 5, 0, 28.866363636363637, 'Below Average'),
#  (14, 'Tofu', 6, 7, '40 - 100 g pkgs.', 23.25, 35, 0, 0, 0, 28.866363636363637, 'Below Average'),
#  (15, 'Genen Shouyu', 6, 2, '24 - 250 ml bottles', 15.5, 39, 0, 5, 0, 28.866363636363637, 'Below Average'),
#  (16, 'Pavlova', 7, 3, '32 - 500 g boxes', 17.45, 29, 0, 10, 0, 28.866363636363637, 'Below Average'),
#  (17, 'Alice Mutton', 7, 6, '20 - 1 kg tins', 39, 0, 0, 0, 1, 28.866363636363637, 'Above Average'),
#  (18, 'Carnarvon Tigers', 7, 8, '16 kg pkg.', 62.5, 42, 0, 0, 0, 28.866363636363637, 'Above Average'),
#  (19, 'Teatime Chocolate Biscuits', 8, 3, '10 boxes x 12 pieces', 9.2, 25, 0, 5, 0, 28.866363636363637, 'Below Average'),
#  (20, "Sir Rodney's Marmalade", 8, 3, '30 gift boxes', 81, 40, 0, 0, 0, 28.866363636363637, 'Above Average'),
#  (21, "Sir Rodney's Scones", 8, 3, '24 pkgs. x 4 pieces', 10, 3, 40, 5, 0, 28.866363636363637, 'Below Average'),
#  (22, "Gustaf's Knckebrd", 9, 5, '24 - 500 g pkgs.', 21, 104, 0, 25, 0, 28.866363636363637, 'Below Average'),
#  (23, 'Tunnbrd', 9, 5, '12 - 250 g pkgs.', 9, 61, 0, 25, 0, 28.866363636363637, 'Below Average'),
#  (24, 'Guaran Fantstica', 10, 1, '12 - 355 ml cans', 4.5, 20, 0, 0, 1, 28.866363636363637, 'Below Average'),
#  (25, 'NuNuCa Nu-Nougat-Creme', 11, 3, '20 - 450 g glasses', 14, 76, 0, 30, 0, 28.866363636363637, 'Below Average'),
#  (26, 'Gumbr Gummibrchen', 11, 3, '100 - 250 g bags', 31.23, 15, 0, 0, 0, 28.866363636363637, 'Above Average'),
#  (27, 'Schoggi Schokolade', 11, 3, '100 - 100 g pieces', 43.9, 49, 0, 30, 0, 28.866363636363637, 'Above Average'),
#  (28, 'Rssle Sauerkraut', 12, 7, '25 - 825 g cans', 45.6, 26, 0, 0, 1, 28.866363636363637, 'Above Average'),
#  (29, 'Thringer Rostbratwurst', 12, 6, '50 bags x 30 sausgs.', 123.79, 0, 0, 0, 1, 28.866363636363637, 'Above Average'),
#  (30, 'Nord-Ost Matjeshering', 13, 8, '10 - 200 g glasses', 25.89, 10, 0, 15, 0, 28.866363636363637, 'Below Average'),
#  (31, 'Gorgonzola Telino', 14, 4, '12 - 100 g pkgs', 12.5, 0, 70, 20, 0, 28.866363636363637, 'Below Average'),
#  (32, 'Mascarpone Fabioli', 14, 4, '24 - 200 g pkgs.', 32, 9, 40, 25, 0, 28.866363636363637, 'Above Average'),
#  (33, 'Geitost', 15, 4, '500 g', 2.5, 112, 0, 20, 0, 28.866363636363637, 'Below Average'),
#  (34, 'Sasquatch Ale', 16, 1, '24 - 12 oz bottles', 14, 111, 0, 15, 0, 28.866363636363637, 'Below Average'),
#  (35, 'Steeleye Stout', 16, 1, '24 - 12 oz bottles', 18, 20, 0, 15, 0, 28.866363636363637, 'Below Average'),
#  (36, 'Inlagd Sill', 17, 8, '24 - 250 g  jars', 19, 112, 0, 20, 0, 28.866363636363637, 'Below Average'),
#  (37, 'Gravad lax', 17, 8, '12 - 500 g pkgs.', 26, 11, 50, 25, 0, 28.866363636363637, 'Below Average'),
#  (38, 'Cte de Blaye', 18, 1, '12 - 75 cl bottles', 263.5, 17, 0, 15, 0, 28.866363636363637, 'Above Average'),
#  (39, 'Chartreuse verte', 18, 1, '750 cc per bottle', 18, 69, 0, 5, 0, 28.866363636363637, 'Below Average'),
#  (40, 'Boston Crab Meat', 19, 8, '24 - 4 oz tins', 18.4, 123, 0, 30, 0, 28.866363636363637, 'Below Average'),
#  (41, "Jack's New England Clam Chowder", 19, 8, '12 - 12 oz cans', 9.65, 85, 0, 10, 0, 28.866363636363637, 'Below Average'),
#  (42, 'Singaporean Hokkien Fried Mee', 20, 5, '32 - 1 kg pkgs.', 14, 26, 0, 0, 1, 28.866363636363637, 'Below Average'),
#  (43, 'Ipoh Coffee', 20, 1, '16 - 500 g tins', 46, 17, 10, 25, 0, 28.866363636363637, 'Above Average'),
#  (44, 'Gula Malacca', 20, 2, '20 - 2 kg bags', 19.45, 27, 0, 15, 0, 28.866363636363637, 'Below Average'),
#  (45, 'Rogede sild', 21, 8, '1k pkg.', 9.5, 5, 70, 15, 0, 28.866363636363637, 'Below Average'),
#  (46, 'Spegesild', 21, 8, '4 - 450 g glasses', 12, 95, 0, 0, 0, 28.866363636363637, 'Below Average'),
#  (47, 'Zaanse koeken', 22, 3, '10 - 4 oz boxes', 9.5, 36, 0, 0, 0, 28.866363636363637, 'Below Average'),
#  (48, 'Chocolade', 22, 3, '10 pkgs.', 12.75, 15, 70, 25, 0, 28.866363636363637, 'Below Average'),
#  (49, 'Maxilaku', 23, 3, '24 - 50 g pkgs.', 20, 10, 60, 15, 0, 28.866363636363637, 'Below Average'),
#  (50, 'Valkoinen suklaa', 23, 3, '12 - 100 g bars', 16.25, 65, 0, 30, 0, 28.866363636363637, 'Below Average'),
#  (51, 'Manjimup Dried Apples', 24, 7, '50 - 300 g pkgs.', 53, 20, 0, 10, 0, 28.866363636363637, 'Above Average'),
#  (52, 'Filo Mix', 24, 5, '16 - 2 kg boxes', 7, 38, 0, 25, 0, 28.866363636363637, 'Below Average'),
#  (53, 'Perth Pasties', 24, 6, '48 pieces', 32.8, 0, 0, 0, 1, 28.866363636363637, 'Above Average'),
#  (54, 'Tourtire', 25, 6, '16 pies', 7.45, 21, 0, 10, 0, 28.866363636363637, 'Below Average'),
#  (55, 'Pt chinois', 25, 6, '24 boxes x 2 pies', 24, 115, 0, 20, 0, 28.866363636363637, 'Below Average'),
#  (56, 'Gnocchi di nonna Alice', 26, 5, '24 - 250 g pkgs.', 38, 21, 10, 30, 0, 28.866363636363637, 'Above Average'),
#  (57, 'Ravioli Angelo', 26, 5, '24 - 250 g pkgs.', 19.5, 36, 0, 20, 0, 28.866363636363637, 'Below Average'),
#  (58, 'Escargots de Bourgogne', 27, 8, '24 pieces', 13.25, 62, 0, 20, 0, 28.866363636363637, 'Below Average'),
#  (59, 'Raclette Courdavault', 28, 4, '5 kg pkg.', 55, 79, 0, 0, 0, 28.866363636363637, 'Above Average'),
#  (60, 'Camembert Pierrot', 28, 4, '15 - 300 g rounds', 34, 19, 0, 0, 0, 28.866363636363637, 'Above Average'),
#  (61, "Sirop d'rable", 29, 2, '24 - 500 ml bottles', 28.5, 113, 0, 25, 0, 28.866363636363637, 'Below Average'),
#  (62, 'Tarte au sucre', 29, 3, '48 pies', 49.3, 17, 0, 0, 0, 28.866363636363637, 'Above Average'),
#  (63, 'Vegie-spread', 7, 2, '15 - 625 g jars', 43.9, 24, 0, 5, 0, 28.866363636363637, 'Above Average'),
#  (64, 'Wimmers gute Semmelkndel', 12, 5, '20 bags x 4 pieces', 33.25, 22, 80, 30, 0, 28.866363636363637, 'Above Average'),
#  (65, 'Louisiana Fiery Hot Pepper Sauce', 2, 2, '32 - 8 oz bottles', 21.05, 76, 0, 0, 0, 28.866363636363637, 'Below Average'),
#  (66, 'Louisiana Hot Spiced Okra', 2, 2, '24 - 8 oz jars', 17, 4, 100, 20, 0, 28.866363636363637, 'Below Average'),
#  (67, 'Laughing Lumberjack Lager', 16, 1, '24 - 12 oz bottles', 14, 52, 0, 10, 0, 28.866363636363637, 'Below Average'),
#  (68, 'Scottish Longbreads', 8, 3, '10 boxes x 8 pieces', 12.5, 6, 10, 15, 0, 28.866363636363637, 'Below Average'),
#  (69, 'Gudbrandsdalsost', 15, 4, '10 kg pkg.', 36, 26, 0, 15, 0, 28.866363636363637, 'Above Average'),
#  (70, 'Outback Lager', 7, 1, '24 - 355 ml bottles', 15, 15, 10, 30, 0, 28.866363636363637, 'Below Average'),
#  (71, 'Flotemysost', 15, 4, '10 - 500 g pkgs.', 21.5, 26, 0, 0, 0, 28.866363636363637, 'Below Average'),
#  (72, 'Mozzarella di Giovanni', 14, 4, '24 - 200 g pkgs.', 34.8, 14, 0, 0, 0, 28.866363636363637, 'Above Average'),
#  (73, 'Rd Kaviar', 17, 8, '24 - 150 g jars', 15, 101, 0, 5, 0, 28.866363636363637, 'Below Average'),
#  (74, 'Longlife Tofu', 4, 7, '5 kg pkg.', 10, 4, 20, 5, 0, 28.866363636363637, 'Below Average'),
#  (75, 'Rhnbru Klosterbier', 12, 1, '24 - 0.5 l bottles', 7.75, 125, 0, 25, 0, 28.866363636363637, 'Below Average'),
#  (76, 'Lakkalikri', 23, 1, '500 ml', 18, 57, 0, 20, 0, 28.866363636363637, 'Below Average'),
#  (77, 'Original Frankfurter grne Soe', 12, 2, '12 boxes', 13, 32, 0, 15, 0, 28.866363636363637, 'Below Average')]

# %% [markdown]
# ### 5. Identify top management employees
#
# In the `Employees` table, assume the `ReportsTo` column has some null values which represent the highest-level employees (such as a CEO). Write a SQL query to list all employees and display a new column `Position` that labels the employee as 'Top Management' if the `ReportsTo` column is `NULL`, and 'Staff' otherwise.

# %%
# %%sql
# SELECT
#     FirstName,
#     LastName,
#     CASE
#         WHEN ReportsTo IS NULL THEN 'Top Management'
#         ELSE 'Staff'
#     END AS Position
# FROM Employees;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Nancy', 'Davolio', 'Staff'),
#  ('Andrew', 'Fuller', 'Top Management'),
#  ('Janet', 'Leverling', 'Staff'),
#  ('Margaret', 'Peacock', 'Staff'),
#  ('Steven', 'Buchanan', 'Staff'),
#  ('Michael', 'Suyama', 'Staff'),
#  ('Robert', 'King', 'Staff'),
#  ('Laura', 'Callahan', 'Staff'),
#  ('Anne', 'Dodsworth', 'Staff')]

# %% [markdown]
# ### Challenge question
#
# You are working with a products inventory database which has a Products table with the following columns:
#
# - `ProductID`
# - `ProductName`
# - `UnitPrice`
# - `UnitsInStock`
# - `ReorderLevel`
# - `SupplierCountry`
#
# Your manager wants to assess the company's stock levels and has asked for your assistance.

# %% [markdown]
# Write a SQL query that retrieves the following information:
#
# - `ProductName`
# - `UnitPrice`
# - `UnitsInStock`
# - A column `StockStatus` that categorises the stock level of each product as 'Low', 'Medium', or 'High' based on the `UnitsInStock` (Use a `CASE` statement to create this column where 'Low' is less than 20 units, 'Medium' is between 20 and 50 units, 'High' is over 50 units).
# - A column `PriceLevel` that categorises the price of each product as 'Cheap', 'Affordable', or 'Expensive' based on the `UnitPrice` (Use a `CASE` statement to create this column where 'Cheap' is less than \$10, 'Affordable' is between \$10 and \$50, 'Expensive' is over \$50).
#
# Your SQL query should consider the use of aggregation functions, date functions, control flow functions, and string functions.

# %%
# %%sql
# SELECT
#     ProductName,
#     UnitPrice,
#     UnitsInStock,
#     CASE
#         WHEN UnitsInStock < 20 THEN 'Low'
#         WHEN UnitsInStock BETWEEN 20 AND 50 THEN 'Medium'
#         WHEN UnitsInStock > 50 THEN 'High'
#     END AS StockStatus,
#     CASE
#         WHEN UnitPrice < 10 THEN 'Cheap'
#         WHEN UnitPrice BETWEEN 10 AND 50 THEN 'Affordable'
#         WHEN UnitPrice > 50 THEN 'Expensive'
#     END AS PriceLevel
#
# FROM Products;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Chai', 18, 39, 'Medium', 'Affordable'),
#  ('Chang', 19, 17, 'Low', 'Affordable'),
#  ('Aniseed Syrup', 10, 13, 'Low', 'Affordable'),
#  ("Chef Anton's Cajun Seasoning", 22, 53, 'High', 'Affordable'),
#  ("Chef Anton's Gumbo Mix", 21.35, 0, 'Low', 'Affordable'),
#  ("Grandma's Boysenberry Spread", 25, 120, 'High', 'Affordable'),
#  ("Uncle Bob's Organic Dried Pears", 30, 15, 'Low', 'Affordable'),
#  ('Northwoods Cranberry Sauce', 40, 6, 'Low', 'Affordable'),
#  ('Mishi Kobe Niku', 97, 29, 'Medium', 'Expensive'),
#  ('Ikura', 31, 31, 'Medium', 'Affordable'),
#  ('Queso Cabrales', 21, 22, 'Medium', 'Affordable'),
#  ('Queso Manchego La Pastora', 38, 86, 'High', 'Affordable'),
#  ('Konbu', 6, 24, 'Medium', 'Cheap'),
#  ('Tofu', 23.25, 35, 'Medium', 'Affordable'),
#  ('Genen Shouyu', 15.5, 39, 'Medium', 'Affordable'),
#  ('Pavlova', 17.45, 29, 'Medium', 'Affordable'),
#  ('Alice Mutton', 39, 0, 'Low', 'Affordable'),
#  ('Carnarvon Tigers', 62.5, 42, 'Medium', 'Expensive'),
#  ('Teatime Chocolate Biscuits', 9.2, 25, 'Medium', 'Cheap'),
#  ("Sir Rodney's Marmalade", 81, 40, 'Medium', 'Expensive'),
#  ("Sir Rodney's Scones", 10, 3, 'Low', 'Affordable'),
#  ("Gustaf's Knckebrd", 21, 104, 'High', 'Affordable'),
#  ('Tunnbrd', 9, 61, 'High', 'Cheap'),
#  ('Guaran Fantstica', 4.5, 20, 'Medium', 'Cheap'),
#  ('NuNuCa Nu-Nougat-Creme', 14, 76, 'High', 'Affordable'),
#  ('Gumbr Gummibrchen', 31.23, 15, 'Low', 'Affordable'),
#  ('Schoggi Schokolade', 43.9, 49, 'Medium', 'Affordable'),
#  ('Rssle Sauerkraut', 45.6, 26, 'Medium', 'Affordable'),
#  ('Thringer Rostbratwurst', 123.79, 0, 'Low', 'Expensive'),
#  ('Nord-Ost Matjeshering', 25.89, 10, 'Low', 'Affordable'),
#  ('Gorgonzola Telino', 12.5, 0, 'Low', 'Affordable'),
#  ('Mascarpone Fabioli', 32, 9, 'Low', 'Affordable'),
#  ('Geitost', 2.5, 112, 'High', 'Cheap'),
#  ('Sasquatch Ale', 14, 111, 'High', 'Affordable'),
#  ('Steeleye Stout', 18, 20, 'Medium', 'Affordable'),
#  ('Inlagd Sill', 19, 112, 'High', 'Affordable'),
#  ('Gravad lax', 26, 11, 'Low', 'Affordable'),
#  ('Cte de Blaye', 263.5, 17, 'Low', 'Expensive'),
#  ('Chartreuse verte', 18, 69, 'High', 'Affordable'),
#  ('Boston Crab Meat', 18.4, 123, 'High', 'Affordable'),
#  ("Jack's New England Clam Chowder", 9.65, 85, 'High', 'Cheap'),
#  ('Singaporean Hokkien Fried Mee', 14, 26, 'Medium', 'Affordable'),
#  ('Ipoh Coffee', 46, 17, 'Low', 'Affordable'),
#  ('Gula Malacca', 19.45, 27, 'Medium', 'Affordable'),
#  ('Rogede sild', 9.5, 5, 'Low', 'Cheap'),
#  ('Spegesild', 12, 95, 'High', 'Affordable'),
#  ('Zaanse koeken', 9.5, 36, 'Medium', 'Cheap'),
#  ('Chocolade', 12.75, 15, 'Low', 'Affordable'),
#  ('Maxilaku', 20, 10, 'Low', 'Affordable'),
#  ('Valkoinen suklaa', 16.25, 65, 'High', 'Affordable'),
#  ('Manjimup Dried Apples', 53, 20, 'Medium', 'Expensive'),
#  ('Filo Mix', 7, 38, 'Medium', 'Cheap'),
#  ('Perth Pasties', 32.8, 0, 'Low', 'Affordable'),
#  ('Tourtire', 7.45, 21, 'Medium', 'Cheap'),
#  ('Pt chinois', 24, 115, 'High', 'Affordable'),
#  ('Gnocchi di nonna Alice', 38, 21, 'Medium', 'Affordable'),
#  ('Ravioli Angelo', 19.5, 36, 'Medium', 'Affordable'),
#  ('Escargots de Bourgogne', 13.25, 62, 'High', 'Affordable'),
#  ('Raclette Courdavault', 55, 79, 'High', 'Expensive'),
#  ('Camembert Pierrot', 34, 19, 'Low', 'Affordable'),
#  ("Sirop d'rable", 28.5, 113, 'High', 'Affordable'),
#  ('Tarte au sucre', 49.3, 17, 'Low', 'Affordable'),
#  ('Vegie-spread', 43.9, 24, 'Medium', 'Affordable'),
#  ('Wimmers gute Semmelkndel', 33.25, 22, 'Medium', 'Affordable'),
#  ('Louisiana Fiery Hot Pepper Sauce', 21.05, 76, 'High', 'Affordable'),
#  ('Louisiana Hot Spiced Okra', 17, 4, 'Low', 'Affordable'),
#  ('Laughing Lumberjack Lager', 14, 52, 'High', 'Affordable'),
#  ('Scottish Longbreads', 12.5, 6, 'Low', 'Affordable'),
#  ('Gudbrandsdalsost', 36, 26, 'Medium', 'Affordable'),
#  ('Outback Lager', 15, 15, 'Low', 'Affordable'),
#  ('Flotemysost', 21.5, 26, 'Medium', 'Affordable'),
#  ('Mozzarella di Giovanni', 34.8, 14, 'Low', 'Affordable'),
#  ('Rd Kaviar', 15, 101, 'High', 'Affordable'),
#  ('Longlife Tofu', 10, 4, 'Low', 'Affordable'),
#  ('Rhnbru Klosterbier', 7.75, 125, 'High', 'Cheap'),
#  ('Lakkalikri', 18, 57, 'High', 'Affordable'),
#  ('Original Frankfurter grne Soe', 13, 32, 'Medium', 'Affordable')]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Categorise employees based on salaries
#
# This query uses the `IIF` control function to check if each employee's salary is greater than 50,000. If it is, the function returns 'Yes', otherwise 'No'. This result is displayed in the new column `HighSalary`.
#
# Expected outcome: A table with columns `FirstName`, `LastName`, and `HighSalary`. The `HighSalary` column displays 'Yes' or 'No' depending on each employee's salary.
#
# **NOTE:** The `IF` function is not supported in SQLite, so we use the `IIF` function which is the SQLite equivalent for `IF`.

# %%
# %%sql
#
# SELECT
#        FirstName,
#        LastName,
#        IIF(Salary > 50000, 'Yes', 'No') AS HighSalary
# FROM
#        Employees;

# %% [markdown]
# ### 2. Categorise orders based on quantity
#
# This query uses the `CASE` statement to categorise the size of each order. If the quantity of an order is less than 20, it's categorised as 'Small'. If it's between 20 and 100, it's 'Medium'. Otherwise, it's 'Large'.
#
# Expected outcome: A table with columns `OrderID` and `OrderSize`. The `OrderSize` column displays 'Small', 'Medium', or 'Large' depending on each order's quantity.

# %%
# %%sql
#
# SELECT
#     OrderID,
#     CASE
#         WHEN (Quantity < 20) THEN 'Small'
#         WHEN Quantity BETWEEN 20 AND 100 THEN 'Medium'
#         ELSE 'Large'
#     END as OrderSize
# FROM
#     OrderDetails;

# %% [markdown]
# ### 3. Replace country if `NULL`
#
# This query uses the `IFNULL` function to replace null values in the `Country` column with 'Not Provided'.
#
# Expected outcome: A table with columns `CustomerID`, `CompanyName`, and `Country`. The `Country` column displays the name of the country or 'Not Provided' if the original value was `NULL`.

# %%
# %%sql
#
# SELECT
#     CustomerID,
#     CompanyName,
#     IFNULL(Country, 'Not Provided') AS Country
# FROM
#     Customers;

# %% [markdown]
# ### 4. Calculate the average price of products
#
# This query calculates the average unit price of all products. Then, it compares the unit price of each product with this average and labels it as 'Below Average', 'Average', or 'Above Average' accordingly.
#
# Expected outcome: A table with columns `ProductName`, `UnitPrice`, and `PriceComparison`. The `PriceComparison` column displays 'Below Average', 'Average', or 'Above Average' depending on each product's unit price.

# %%
# %%sql
#
# SELECT
#     ProductName,
#     UnitPrice,
#     CASE
#         WHEN UnitPrice < (SELECT AVG(UnitPrice) FROM Products) THEN 'Below Average'
#         WHEN UnitPrice = (SELECT AVG(UnitPrice) FROM Products) THEN 'Average'
#         ELSE 'Above Average'
#     END as PriceComparison
# FROM
#     Products;

# %% [markdown]
# ### 5. Identify top management employees
#
# This query uses the `IIF` function to check if the `ReportsTo` field of an employee is `NULL`. If it is, the employee is labelled as 'Top Management', otherwise 'Staff'.
#
# Expected outcome: A table with columns `FirstName`, `LastName`, and `Position`. The `Position` column displays 'Top Management' or 'Staff' depending on the `ReportsTo` field of each employee.

# %%
# %%sql
#
# SELECT
#     FirstName,
#     LastName,
#     IIF(ReportsTo IS NULL, 'Top Management', 'Staff') as Position
# FROM
#     Employees;
# Out:
#  * sqlite:///Northwind.db
# Done.
# [('Nancy', 'Davolio', 'Staff'),
#  ('Andrew', 'Fuller', 'Top Management'),
#  ('Janet', 'Leverling', 'Staff'),
#  ('Margaret', 'Peacock', 'Staff'),
#  ('Steven', 'Buchanan', 'Staff'),
#  ('Michael', 'Suyama', 'Staff'),
#  ('Robert', 'King', 'Staff'),
#  ('Laura', 'Callahan', 'Staff'),
#  ('Anne', 'Dodsworth', 'Staff')]

# %% [markdown]
# ### Challenge question
#
# This problem requires the integration of SQL querying with some basic logic and control flow.
#
# Here is a step-by-step breakdown of how to approach solving this problem:

# %% [markdown]
# 1. **Identify required fields:** The first part of the problem is straightforward. We're being asked to retrieve `ProductName`, `UnitsInStock`, and `UnitPrice` from our `Products` table. These fields can be directly selected in our SQL query.
#
# 2. **Categorise stock levels:** We need to create a new field, `StockStatus`, that categorises the stock level based on the `UnitsInStock`. This requires the use of a control flow function – specifically, a `CASE` statement. The `CASE` statement allows us to conditionally return results based on the value of another field. In this case, we will categorise `UnitsInStock` as 'Low' if less than 20, 'Medium' if between 20 and 50, and 'High' if more than 50.
#
# 3. **Categorise price levels:** Similarly, we need to create another field, `PriceLevel`, that categorises the price of a product based on the `UnitPrice`. We'll again use a `CASE` statement to accomplish this. We will categorise `UnitPrice` as *Cheap* if less than \$10, *Affordable* if between \$10 and \$50, and *Expensive* if more than \$50.

# %% [markdown]
# So, to solve the problem, we would write a SQL query that selects the required fields and uses `CASE` statements to create the new `StockStatus` and `PriceLevel` fields based on the conditions described above.
#
# In SQL, this would look something like:

# %%
# %%sql
#
# SELECT
#     ProductName,
#     UnitsInStock,
#     UnitPrice,
#     CASE
#         WHEN UnitsInStock < 20 THEN 'Low'
#         WHEN UnitsInStock BETWEEN 20 AND 50 THEN 'Medium'
#         ELSE 'High'
#     END AS StockStatus,
#     CASE
#         WHEN UnitPrice < 10 THEN 'Cheap'
#         WHEN UnitPrice BETWEEN 10 AND 50 THEN 'Affordable'
#         ELSE 'Expensive'
#     END AS PriceLevel
# FROM
#     Products;

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
