# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Database views

# %% [markdown]
# A view is a virtual table that represents data derived from one or more base tables. It does not store data. It is basically a saved query that can be used as a table. Views allow you to simplify complex queries, abstract the underlying data structure, and provide some security by allowing access to specific columns or rows of data.
#
# In this lesson, we will construct a complex query and then create a view of that query.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# By the end of this lesson, you should know:
# - What a view is and why it's needed.
# - How to create a view.
# - How to join tables using views.
# - How to impute Null values using views.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table in the `united_nations` database that we created in MySQL Workbench, we want to answer some questions about our dataset. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace `password` with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:WangilaP%400911@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line then add the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ## Exercise

# %% [markdown]
# We have decomposed the `united_nations.Access_to_Basic_Services` table into three tables. The `united_nations.Basic_Services` table, `united_nations.Economic_Indicators` table, and the `united_nations.Geographic_Locations` table. In this tutorial, we will be constructing a complex query to view the unemployment rate in Sub-Saharan Africa. We will then save that query as a VIEW.

# %% [markdown]
# ### Task 1
# To view the unemployment rate per region we will have to first join the `Economic_Indicators` table to the `Geographic_Locations` table.

# %%
# %%sql
# SELECT
#     Geo.Country_name,
#     Econ.Pct_unemployment,
#     Geo.Region
# FROM
#     Economic_indicators AS Econ
# JOIN
#     Geographic_location AS Geo
#         ON Econ.Country_name = Geo.Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Afghanistan', None, 'Central and Southern Asia'),
#  ('Afghanistan', None, 'Central and Southern Asia'),
#  ('Afghanistan', 11, 'Central and Southern Asia'),
#  ('Afghanistan', None, 'Central and Southern Asia'),
#  ('Afghanistan', None, 'Central and Southern Asia'),
#  ('Afghanistan', 12, 'Central and Southern Asia'),
#  ('Algeria', 11, 'Northern Africa and Western Asia'),
#  ('Algeria', 10, 'Northern Africa and Western Asia'),
#  ('Algeria', 12, 'Northern Africa and Western Asia'),
#  ('Algeria', None, 'Northern Africa and Western Asia'),
#  ('Algeria', None, 'Northern Africa and Western Asia'),
#  ('Algeria', None, 'Northern Africa and Western Asia'),
#  ('American Samoa', None, 'Oceania'),
#  ('American Samoa', None, 'Oceania'),
#  ('American Samoa', None, 'Oceania'),
#  ('American Samoa', None, 'Oceania'),
#  ('American Samoa', None, 'Oceania'),
#  ('American Samoa', None, 'Oceania'),
#  ('Angola', None, 'Sub-Saharan Africa'),
#  ('Angola', None, 'Sub-Saharan Africa'),
#  ('Angola', None, 'Sub-Saharan Africa'),
#  ('Angola', None, 'Sub-Saharan Africa'),
#  ('Angola', 17, 'Sub-Saharan Africa'),
#  ('Angola', None, 'Sub-Saharan Africa'),
#  ('Anguilla', None, 'Latin America and the Caribbean'),
#  ('Anguilla', None, 'Latin America and the Caribbean'),
#  ('Anguilla', None, 'Latin America and the Caribbean'),
#  ('Antigua and Barbuda', None, 'Latin America and the Caribbean'),
#  ('Antigua and Barbuda', None, 'Latin America and the Caribbean'),
#  ('Antigua and Barbuda', None, 'Latin America and the Caribbean'),
#  ('Argentina', None, 'Latin America and the Caribbean'),
#  ('Argentina', None, 'Latin America and the Caribbean'),
#  ('Argentina', 8, 'Latin America and the Caribbean'),
#  ('Argentina', 9, 'Latin America and the Caribbean'),
#  ('Argentina', 10, 'Latin America and the Caribbean'),
#  ('Argentina', 11, 'Latin America and the Caribbean'),
#  ('Armenia', 18, 'Northern Africa and Western Asia'),
#  ('Armenia', 18, 'Northern Africa and Western Asia'),
#  ('Armenia', 18, 'Northern Africa and Western Asia'),
#  ('Armenia', 13, 'Northern Africa and Western Asia'),
#  ('Armenia', 12, 'Northern Africa and Western Asia'),
#  ('Armenia', 12, 'Northern Africa and Western Asia'),
#  ('Aruba', None, 'Latin America and the Caribbean'),
#  ('Aruba', None, 'Latin America and the Caribbean'),
#  ('Australia', 6, 'Oceania'),
#  ('Australia', 6, 'Oceania'),
#  ('Australia', 6, 'Oceania'),
#  ('Australia', 5, 'Oceania'),
#  ('Australia', 5, 'Oceania'),
#  ('Australia', 6, 'Oceania'),
#  ('Azerbaijan', 5, 'Northern Africa and Western Asia'),
#  ('Azerbaijan', 5, 'Northern Africa and Western Asia'),
#  ('Azerbaijan', 5, 'Northern Africa and Western Asia'),
#  ('Azerbaijan', 5, 'Northern Africa and Western Asia'),
#  ('Azerbaijan', 5, 'Northern Africa and Western Asia'),
#  ('Azerbaijan', 7, 'Northern Africa and Western Asia'),
#  ('Bahamas', None, 'Latin America and the Caribbean'),
#  ('Bahamas', None, 'Latin America and the Caribbean'),
#  ('Bahamas', None, 'Latin America and the Caribbean'),
#  ('Bahamas', None, 'Latin America and the Caribbean'),
#  ('Bahamas', None, 'Latin America and the Caribbean'),
#  ('Bahrain', None, 'Northern Africa and Western Asia'),
#  ('Bahrain', None, 'Northern Africa and Western Asia'),
#  ('Bahrain', None, 'Northern Africa and Western Asia'),
#  ('Bahrain', None, 'Northern Africa and Western Asia'),
#  ('Bahrain', None, 'Northern Africa and Western Asia'),
#  ('Bahrain', None, 'Northern Africa and Western Asia'),
#  ('Bangladesh', None, 'Central and Southern Asia'),
#  ('Bangladesh', 4, 'Central and Southern Asia'),
#  ('Bangladesh', 4, 'Central and Southern Asia'),
#  ('Bangladesh', None, 'Central and Southern Asia'),
#  ('Bangladesh', None, 'Central and Southern Asia'),
#  ('Bangladesh', None, 'Central and Southern Asia'),
#  ('Barbados', 10, 'Latin America and the Caribbean'),
#  ('Barbados', 8, 'Latin America and the Caribbean'),
#  ('Barbados', 9, 'Latin America and the Caribbean'),
#  ('Barbados', 8, 'Latin America and the Caribbean'),
#  ('Barbados', 8, 'Latin America and the Caribbean'),
#  ('Barbados', None, 'Latin America and the Caribbean'),
#  ('Belize', 8, 'Latin America and the Caribbean'),
#  ('Belize', 7, 'Latin America and the Caribbean'),
#  ('Belize', 7, 'Latin America and the Caribbean'),
#  ('Belize', None, 'Latin America and the Caribbean'),
#  ('Belize', 9, 'Latin America and the Caribbean'),
#  ('Belize', None, 'Latin America and the Caribbean'),
#  ('Benin', None, 'Sub-Saharan Africa'),
#  ('Benin', None, 'Sub-Saharan Africa'),
#  ('Benin', None, 'Sub-Saharan Africa'),
#  ('Benin', 1, 'Sub-Saharan Africa'),
#  ('Benin', None, 'Sub-Saharan Africa'),
#  ('Benin', None, 'Sub-Saharan Africa'),
#  ('Bermuda', None, 'Europe and Northern America'),
#  ('Bermuda', None, 'Europe and Northern America'),
#  ('Bermuda', None, 'Europe and Northern America'),
#  ('Bermuda', None, 'Europe and Northern America'),
#  ('Bermuda', None, 'Europe and Northern America'),
#  ('Bermuda', None, 'Europe and Northern America'),
#  ('Bhutan', 2, 'Central and Southern Asia'),
#  ('Bhutan', None, 'Central and Southern Asia'),
#  ('Bhutan', None, 'Central and Southern Asia'),
#  ('Bhutan', 3, 'Central and Southern Asia'),
#  ('Bhutan', 3, 'Central and Southern Asia'),
#  ('Bhutan', 5, 'Central and Southern Asia'),
#  ('Bolivia (Plurinational State of)', None, 'Latin America and the Caribbean'),
#  ('Bolivia (Plurinational State of)', None, 'Latin America and the Caribbean'),
#  ('Bolivia (Plurinational State of)', None, 'Latin America and the Caribbean'),
#  ('Bolivia (Plurinational State of)', None, 'Latin America and the Caribbean'),
#  ('Bolivia (Plurinational State of)', None, 'Latin America and the Caribbean'),
#  ('Bolivia (Plurinational State of)', None, 'Latin America and the Caribbean'),
#  ('Botswana', None, 'Sub-Saharan Africa'),
#  ('Botswana', None, 'Sub-Saharan Africa'),
#  ('Botswana', None, 'Sub-Saharan Africa'),
#  ('Botswana', None, 'Sub-Saharan Africa'),
#  ('Botswana', 20, 'Sub-Saharan Africa'),
#  ('Botswana', 21, 'Sub-Saharan Africa'),
#  ('Brazil', 9, 'Latin America and the Caribbean'),
#  ('Brazil', 12, 'Latin America and the Caribbean'),
#  ('Brazil', 13, 'Latin America and the Caribbean'),
#  ('Brazil', 12, 'Latin America and the Caribbean'),
#  ('Brazil', 12, 'Latin America and the Caribbean'),
#  ('Brazil', 14, 'Latin America and the Caribbean'),
#  ('British Virgin Islands', None, 'Latin America and the Caribbean'),
#  ('British Virgin Islands', None, 'Latin America and the Caribbean'),
#  ('British Virgin Islands', None, 'Latin America and the Caribbean'),
#  ('British Virgin Islands', None, 'Latin America and the Caribbean'),
#  ('British Virgin Islands', None, 'Latin America and the Caribbean'),
#  ('British Virgin Islands', None, 'Latin America and the Caribbean'),
#  ('Brunei Darussalam', None, 'Eastern and South-Eastern Asia'),
#  ('Brunei Darussalam', None, 'Eastern and South-Eastern Asia'),
#  ('Brunei Darussalam', 9, 'Eastern and South-Eastern Asia'),
#  ('Brunei Darussalam', 9, 'Eastern and South-Eastern Asia'),
#  ('Brunei Darussalam', 7, 'Eastern and South-Eastern Asia'),
#  ('Brunei Darussalam', 7, 'Eastern and South-Eastern Asia'),
#  ('Burkina Faso', None, 'Sub-Saharan Africa'),
#  ('Burkina Faso', None, 'Sub-Saharan Africa'),
#  ('Burkina Faso', None, 'Sub-Saharan Africa'),
#  ('Burkina Faso', 5, 'Sub-Saharan Africa'),
#  ('Burkina Faso', None, 'Sub-Saharan Africa'),
#  ('Burkina Faso', None, 'Sub-Saharan Africa'),
#  ('Burundi', None, 'Sub-Saharan Africa'),
#  ('Burundi', None, 'Sub-Saharan Africa'),
#  ('Burundi', None, 'Sub-Saharan Africa'),
#  ('Burundi', None, 'Sub-Saharan Africa'),
#  ('Burundi', None, 'Sub-Saharan Africa'),
#  ('Burundi', 1, 'Sub-Saharan Africa'),
#  ('Cabo Verde', 31, 'Sub-Saharan Africa'),
#  ('Cabo Verde', None, 'Sub-Saharan Africa'),
#  ('Cabo Verde', 12, 'Sub-Saharan Africa'),
#  ('Cabo Verde', 12, 'Sub-Saharan Africa'),
#  ('Cabo Verde', 11, 'Sub-Saharan Africa'),
#  ('Cabo Verde', None, 'Sub-Saharan Africa'),
#  ('Cambodia', 0, 'Eastern and South-Eastern Asia'),
#  ('Cambodia', 1, 'Eastern and South-Eastern Asia'),
#  ('Cambodia', 0, 'Eastern and South-Eastern Asia'),
#  ('Cambodia', None, 'Eastern and South-Eastern Asia'),
#  ('Cambodia', 1, 'Eastern and South-Eastern Asia'),
#  ('Cambodia', None, 'Eastern and South-Eastern Asia'),
#  ('Cameroon', None, 'Sub-Saharan Africa'),
#  ('Cameroon', None, 'Sub-Saharan Africa'),
#  ('Cameroon', None, 'Sub-Saharan Africa'),
#  ('Cameroon', None, 'Sub-Saharan Africa'),
#  ('Cameroon', None, 'Sub-Saharan Africa'),
#  ('Cameroon', None, 'Sub-Saharan Africa'),
#  ('Canada', 7, 'Europe and Northern America'),
#  ('Canada', 7, 'Europe and Northern America'),
#  ('Canada', 6, 'Europe and Northern America'),
#  ('Canada', 6, 'Europe and Northern America'),
#  ('Canada', 6, 'Europe and Northern America'),
#  ('Canada', 9, 'Europe and Northern America'),
#  ('Cayman Islands', 4, 'Latin America and the Caribbean'),
#  ('Cayman Islands', None, 'Latin America and the Caribbean'),
#  ('Central African Republic', None, 'Sub-Saharan Africa'),
#  ('Central African Republic', None, 'Sub-Saharan Africa'),
#  ('Central African Republic', None, 'Sub-Saharan Africa'),
#  ('Central African Republic', None, 'Sub-Saharan Africa'),
#  ('Central African Republic', None, 'Sub-Saharan Africa'),
#  ('Central African Republic', None, 'Sub-Saharan Africa'),
#  ('Chad', None, 'Sub-Saharan Africa'),
#  ('Chad', None, 'Sub-Saharan Africa'),
#  ('Chad', None, 'Sub-Saharan Africa'),
#  ('Chad', 1, 'Sub-Saharan Africa'),
#  ('Chad', None, 'Sub-Saharan Africa'),
#  ('Chad', None, 'Sub-Saharan Africa'),
#  ('Chile', 6, 'Latin America and the Caribbean'),
#  ('Chile', 7, 'Latin America and the Caribbean'),
#  ('Chile', 7, 'Latin America and the Caribbean'),
#  ('Chile', 7, 'Latin America and the Caribbean'),
#  ('Chile', 7, 'Latin America and the Caribbean'),
#  ('Chile', 11, 'Latin America and the Caribbean'),
#  ('China', None, 'Eastern and South-Eastern Asia'),
#  ('China', None, 'Eastern and South-Eastern Asia'),
#  ('China', 4, 'Eastern and South-Eastern Asia'),
#  ('China', 5, 'Eastern and South-Eastern Asia'),
#  ('China', 5, 'Eastern and South-Eastern Asia'),
#  ('China', 6, 'Eastern and South-Eastern Asia'),
#  ('Colombia', 9, 'Latin America and the Caribbean'),
#  ('Colombia', 9, 'Latin America and the Caribbean'),
#  ('Colombia', 9, 'Latin America and the Caribbean'),
#  ('Colombia', 9, 'Latin America and the Caribbean'),
#  ('Colombia', 10, 'Latin America and the Caribbean'),
#  ('Colombia', 16, 'Latin America and the Caribbean'),
#  ('Comoros', None, 'Sub-Saharan Africa'),
#  ('Comoros', None, 'Sub-Saharan Africa'),
#  ('Comoros', None, 'Sub-Saharan Africa'),
#  ('Comoros', None, 'Sub-Saharan Africa'),
#  ('Comoros', None, 'Sub-Saharan Africa'),
#  ('Congo', None, 'Sub-Saharan Africa'),
#  ('Congo', None, 'Sub-Saharan Africa'),
#  ('Congo', None, 'Sub-Saharan Africa'),
#  ('Congo', None, 'Sub-Saharan Africa'),
#  ('Congo', None, 'Sub-Saharan Africa'),
#  ('Congo', None, 'Sub-Saharan Africa'),
#  ('Cook Islands', None, 'Oceania'),
#  ('Cook Islands', None, 'Oceania'),
#  ('Cook Islands', None, 'Oceania'),
#  ('Cook Islands', None, 'Oceania'),
#  ('Cook Islands', None, 'Oceania'),
#  ('Cook Islands', None, 'Oceania'),
#  ('Costa Rica', 8, 'Latin America and the Caribbean'),
#  ('Costa Rica', 8, 'Latin America and the Caribbean'),
#  ('Costa Rica', 8, 'Latin America and the Caribbean'),
#  ('Costa Rica', 9, 'Latin America and the Caribbean'),
#  ('Costa Rica', 11, 'Latin America and the Caribbean'),
#  ('Costa Rica', 16, 'Latin America and the Caribbean'),
#  ("Côte d'Ivoire", None, 'Sub-Saharan Africa'),
#  ("Côte d'Ivoire", None, 'Sub-Saharan Africa'),
#  ("Côte d'Ivoire", None, 'Sub-Saharan Africa'),
#  ("Côte d'Ivoire", None, 'Sub-Saharan Africa'),
#  ("Côte d'Ivoire", None, 'Sub-Saharan Africa'),
#  ("Côte d'Ivoire", None, 'Sub-Saharan Africa'),
#  ('Cuba', 2, 'Latin America and the Caribbean'),
#  ('Cuba', 2, 'Latin America and the Caribbean'),
#  ('Cuba', 2, 'Latin America and the Caribbean'),
#  ('Cuba', 2, 'Latin America and the Caribbean'),
#  ('Cuba', None, 'Latin America and the Caribbean'),
#  ('Cuba', None, 'Latin America and the Caribbean'),
#  ('Curaçao', None, 'Latin America and the Caribbean'),
#  ('Curaçao', None, 'Latin America and the Caribbean'),
#  ('Curaçao', None, 'Latin America and the Caribbean'),
#  ('Cyprus', 15, 'Northern Africa and Western Asia'),
#  ('Cyprus', 13, 'Northern Africa and Western Asia'),
#  ('Cyprus', 11, 'Northern Africa and Western Asia'),
#  ('Cyprus', 9, 'Northern Africa and Western Asia'),
#  ('Cyprus', 7, 'Northern Africa and Western Asia'),
#  ('Cyprus', 8, 'Northern Africa and Western Asia'),
#  ("Democratic People's Republic of Korea", None, 'Eastern and South-Eastern Asia'),
#  ("Democratic People's Republic of Korea", None, 'Eastern and South-Eastern Asia'),
#  ("Democratic People's Republic of Korea", None, 'Eastern and South-Eastern Asia'),
#  ("Democratic People's Republic of Korea", None, 'Eastern and South-Eastern Asia'),
#  ("Democratic People's Republic of Korea", None, 'Eastern and South-Eastern Asia'),
#  ("Democratic People's Republic of Korea", None, 'Eastern and South-Eastern Asia'),
#  ('Democratic Republic of the Congo', None, 'Sub-Saharan Africa'),
#  ('Democratic Republic of the Congo', None, 'Sub-Saharan Africa'),
#  ('Democratic Republic of the Congo', None, 'Sub-Saharan Africa'),
#  ('Democratic Republic of the Congo', None, 'Sub-Saharan Africa'),
#  ('Democratic Republic of the Congo', None, 'Sub-Saharan Africa'),
#  ('Democratic Republic of the Congo', None, 'Sub-Saharan Africa'),
#  ('Djibouti', None, 'Sub-Saharan Africa'),
#  ('Djibouti', None, 'Sub-Saharan Africa'),
#  ('Djibouti', 26, 'Sub-Saharan Africa'),
#  ('Djibouti', None, 'Sub-Saharan Africa'),
#  ('Djibouti', None, 'Sub-Saharan Africa'),
#  ('Djibouti', None, 'Sub-Saharan Africa'),
#  ('Dominica', None, 'Latin America and the Caribbean'),
#  ('Dominica', None, 'Latin America and the Caribbean'),
#  ('Dominica', None, 'Latin America and the Caribbean'),
#  ('Dominican Republic', 8, 'Latin America and the Caribbean'),
#  ('Dominican Republic', 7, 'Latin America and the Caribbean'),
#  ('Dominican Republic', 6, 'Latin America and the Caribbean'),
#  ('Dominican Republic', 6, 'Latin America and the Caribbean'),
#  ('Dominican Republic', 6, 'Latin America and the Caribbean'),
#  ('Dominican Republic', 6, 'Latin America and the Caribbean'),
#  ('Ecuador', 4, 'Latin America and the Caribbean'),
#  ('Ecuador', 5, 'Latin America and the Caribbean'),
#  ('Ecuador', 4, 'Latin America and the Caribbean'),
#  ('Ecuador', 4, 'Latin America and the Caribbean'),
#  ('Ecuador', 4, 'Latin America and the Caribbean'),
#  ('Ecuador', 6, 'Latin America and the Caribbean'),
#  ('Egypt', None, 'Northern Africa and Western Asia'),
#  ('Egypt', None, 'Northern Africa and Western Asia'),
#  ('Egypt', None, 'Northern Africa and Western Asia'),
#  ('Egypt', None, 'Northern Africa and Western Asia'),
#  ('Egypt', None, 'Northern Africa and Western Asia'),
#  ('Egypt', None, 'Northern Africa and Western Asia'),
#  ('El Salvador', 4, 'Latin America and the Caribbean'),
#  ('El Salvador', 4, 'Latin America and the Caribbean'),
#  ('El Salvador', 4, 'Latin America and the Caribbean'),
#  ('El Salvador', 4, 'Latin America and the Caribbean'),
#  ('El Salvador', 4, 'Latin America and the Caribbean'),
#  ('El Salvador', 5, 'Latin America and the Caribbean'),
#  ('Equatorial Guinea', None, 'Sub-Saharan Africa'),
#  ('Equatorial Guinea', None, 'Sub-Saharan Africa'),
#  ('Equatorial Guinea', None, 'Sub-Saharan Africa'),
#  ('Eritrea', None, 'Sub-Saharan Africa'),
#  ('Eritrea', None, 'Sub-Saharan Africa'),
#  ('Eswatini', None, 'Sub-Saharan Africa'),
#  ('Eswatini', 23, 'Sub-Saharan Africa'),
#  ('Eswatini', None, 'Sub-Saharan Africa'),
#  ('Eswatini', None, 'Sub-Saharan Africa'),
#  ('Eswatini', None, 'Sub-Saharan Africa'),
#  ('Eswatini', None, 'Sub-Saharan Africa'),
#  ('Ethiopia', None, 'Sub-Saharan Africa'),
#  ('Ethiopia', None, 'Sub-Saharan Africa'),
#  ('Ethiopia', None, 'Sub-Saharan Africa'),
#  ('Ethiopia', None, 'Sub-Saharan Africa'),
#  ('Ethiopia', None, 'Sub-Saharan Africa'),
#  ('Ethiopia', None, 'Sub-Saharan Africa'),
#  ('Falkland Islands (Malvinas)', None, 'Latin America and the Caribbean'),
#  ('Falkland Islands (Malvinas)', None, 'Latin America and the Caribbean'),
#  ('Falkland Islands (Malvinas)', None, 'Latin America and the Caribbean'),
#  ('Falkland Islands (Malvinas)', None, 'Latin America and the Caribbean'),
#  ('Falkland Islands (Malvinas)', None, 'Latin America and the Caribbean'),
#  ('Falkland Islands (Malvinas)', None, 'Latin America and the Caribbean'),
#  ('Fiji', None, 'Oceania'),
#  ('Fiji', 4, 'Oceania'),
#  ('Fiji', None, 'Oceania'),
#  ('Fiji', None, 'Oceania'),
#  ('Fiji', None, 'Oceania'),
#  ('Fiji', None, 'Oceania'),
#  ('French Guiana', None, 'Latin America and the Caribbean'),
#  ('French Guiana', None, 'Latin America and the Caribbean'),
#  ('French Guiana', None, 'Latin America and the Caribbean'),
#  ('French Guiana', None, 'Latin America and the Caribbean'),
#  ('French Guiana', None, 'Latin America and the Caribbean'),
#  ('French Guiana', None, 'Latin America and the Caribbean'),
#  ('French Polynesia', None, 'Oceania'),
#  ('French Polynesia', None, 'Oceania'),
#  ('French Polynesia', None, 'Oceania'),
#  ('French Polynesia', None, 'Oceania'),
#  ('French Polynesia', None, 'Oceania'),
#  ('French Polynesia', None, 'Oceania'),
#  ('Gabon', None, 'Sub-Saharan Africa'),
#  ('Gabon', None, 'Sub-Saharan Africa'),
#  ('Gabon', None, 'Sub-Saharan Africa'),
#  ('Gabon', None, 'Sub-Saharan Africa'),
#  ('Gabon', None, 'Sub-Saharan Africa'),
#  ('Gabon', None, 'Sub-Saharan Africa'),
#  ('Gambia', None, 'Sub-Saharan Africa'),
#  ('Gambia', None, 'Sub-Saharan Africa'),
#  ('Gambia', None, 'Sub-Saharan Africa'),
#  ('Gambia', None, 'Sub-Saharan Africa'),
#  ('Gambia', None, 'Sub-Saharan Africa'),
#  ('Gambia', None, 'Sub-Saharan Africa'),
#  ('Georgia', 17, 'Northern Africa and Western Asia'),
#  ('Georgia', 17, 'Northern Africa and Western Asia'),
#  ('Georgia', 14, 'Northern Africa and Western Asia'),
#  ('Georgia', 13, 'Northern Africa and Western Asia'),
#  ('Georgia', 12, 'Northern Africa and Western Asia'),
#  ('Georgia', 12, 'Northern Africa and Western Asia'),
#  ('Ghana', 7, 'Sub-Saharan Africa'),
#  ('Ghana', None, 'Sub-Saharan Africa'),
#  ('Ghana', 3, 'Sub-Saharan Africa'),
#  ('Ghana', None, 'Sub-Saharan Africa'),
#  ('Ghana', None, 'Sub-Saharan Africa'),
#  ('Ghana', None, 'Sub-Saharan Africa'),
#  ('Greenland', 9, 'Europe and Northern America'),
#  ('Greenland', None, 'Europe and Northern America'),
#  ('Greenland', None, 'Europe and Northern America'),
#  ('Greenland', None, 'Europe and Northern America'),
#  ('Greenland', None, 'Europe and Northern America'),
#  ('Greenland', None, 'Europe and Northern America'),
#  ('Grenada', 23, 'Latin America and the Caribbean'),
#  ('Grenada', None, 'Latin America and the Caribbean'),
#  ('Grenada', None, 'Latin America and the Caribbean'),
#  ('Guadeloupe', None, 'Latin America and the Caribbean'),
#  ('Guadeloupe', None, 'Latin America and the Caribbean'),
#  ('Guadeloupe', None, 'Latin America and the Caribbean'),
#  ('Guadeloupe', None, 'Latin America and the Caribbean'),
#  ('Guadeloupe', None, 'Latin America and the Caribbean'),
#  ('Guadeloupe', None, 'Latin America and the Caribbean'),
#  ('Guam', 7, 'Oceania'),
#  ('Guam', 5, 'Oceania'),
#  ('Guam', None, 'Oceania'),
#  ('Guam', None, 'Oceania'),
#  ('Guam', None, 'Oceania'),
#  ('Guam', None, 'Oceania'),
#  ('Guatemala', 3, 'Latin America and the Caribbean'),
#  ('Guatemala', 3, 'Latin America and the Caribbean'),
#  ('Guatemala', 2, 'Latin America and the Caribbean'),
#  ('Guatemala', 2, 'Latin America and the Caribbean'),
#  ('Guatemala', 2, 'Latin America and the Caribbean'),
#  ('Guatemala', None, 'Latin America and the Caribbean'),
#  ('Guinea', None, 'Sub-Saharan Africa'),
#  ('Guinea', None, 'Sub-Saharan Africa'),
#  ('Guinea', None, 'Sub-Saharan Africa'),
#  ('Guinea', None, 'Sub-Saharan Africa'),
#  ('Guinea', 5, 'Sub-Saharan Africa'),
#  ('Guinea', None, 'Sub-Saharan Africa'),
#  ('Guinea-Bissau', None, 'Sub-Saharan Africa'),
#  ('Guinea-Bissau', None, 'Sub-Saharan Africa'),
#  ('Guinea-Bissau', None, 'Sub-Saharan Africa'),
#  ('Guinea-Bissau', 3, 'Sub-Saharan Africa'),
#  ('Guinea-Bissau', None, 'Sub-Saharan Africa'),
#  ('Guinea-Bissau', None, 'Sub-Saharan Africa'),
#  ('Guyana', None, 'Latin America and the Caribbean'),
#  ('Guyana', None, 'Latin America and the Caribbean'),
#  ('Guyana', None, 'Latin America and the Caribbean'),
#  ('Guyana', 14, 'Latin America and the Caribbean'),
#  ('Guyana', 14, 'Latin America and the Caribbean'),
#  ('Guyana', None, 'Latin America and the Caribbean'),
#  ('Haiti', None, 'Latin America and the Caribbean'),
#  ('Haiti', None, 'Latin America and the Caribbean'),
#  ('Haiti', None, 'Latin America and the Caribbean'),
#  ('Haiti', None, 'Latin America and the Caribbean'),
#  ('Haiti', None, 'Latin America and the Caribbean'),
#  ('Haiti', None, 'Latin America and the Caribbean'),
#  ('Honduras', 6, 'Latin America and the Caribbean'),
#  ('Honduras', 7, 'Latin America and the Caribbean'),
#  ('Honduras', 6, 'Latin America and the Caribbean'),
#  ('Honduras', 6, 'Latin America and the Caribbean'),
#  ('Honduras', 6, 'Latin America and the Caribbean'),
#  ('Honduras', 11, 'Latin America and the Caribbean'),
#  ('India', None, 'Central and Southern Asia'),
#  ('India', None, 'Central and Southern Asia'),
#  ('India', None, 'Central and Southern Asia'),
#  ('India', 8, 'Central and Southern Asia'),
#  ('India', 7, 'Central and Southern Asia'),
#  ('India', 8, 'Central and Southern Asia'),
#  ('Indonesia', 5, 'Eastern and South-Eastern Asia'),
#  ('Indonesia', 4, 'Eastern and South-Eastern Asia'),
#  ('Indonesia', 4, 'Eastern and South-Eastern Asia'),
#  ('Indonesia', 4, 'Eastern and South-Eastern Asia'),
#  ('Indonesia', 4, 'Eastern and South-Eastern Asia'),
#  ('Indonesia', 4, 'Eastern and South-Eastern Asia'),
#  ('Iran (Islamic Republic of)', None, 'Central and Southern Asia'),
#  ('Iran (Islamic Republic of)', None, 'Central and Southern Asia'),
#  ('Iran (Islamic Republic of)', None, 'Central and Southern Asia'),
#  ('Iran (Islamic Republic of)', None, 'Central and Southern Asia'),
#  ('Iran (Islamic Republic of)', None, 'Central and Southern Asia'),
#  ('Iran (Islamic Republic of)', None, 'Central and Southern Asia'),
#  ('Iraq', None, 'Northern Africa and Western Asia'),
#  ('Iraq', 11, 'Northern Africa and Western Asia'),
#  ('Iraq', 13, 'Northern Africa and Western Asia'),
#  ('Iraq', None, 'Northern Africa and Western Asia'),
#  ('Iraq', None, 'Northern Africa and Western Asia'),
#  ('Iraq', None, 'Northern Africa and Western Asia'),
#  ('Israel', 5, 'Northern Africa and Western Asia'),
#  ('Israel', 5, 'Northern Africa and Western Asia'),
#  ('Israel', 4, 'Northern Africa and Western Asia'),
#  ('Israel', 4, 'Northern Africa and Western Asia'),
#  ('Israel', 4, 'Northern Africa and Western Asia'),
#  ('Israel', 4, 'Northern Africa and Western Asia'),
#  ('Jamaica', 14, 'Latin America and the Caribbean'),
#  ('Jamaica', 9, 'Latin America and the Caribbean'),
#  ('Jamaica', 7, 'Latin America and the Caribbean'),
#  ('Jamaica', 5, 'Latin America and the Caribbean'),
#  ('Jamaica', 5, 'Latin America and the Caribbean'),
#  ('Jamaica', 7, 'Latin America and the Caribbean'),
#  ('Japan', 3, 'Eastern and South-Eastern Asia'),
#  ('Japan', 3, 'Eastern and South-Eastern Asia'),
#  ('Japan', 3, 'Eastern and South-Eastern Asia'),
#  ('Japan', 2, 'Eastern and South-Eastern Asia'),
#  ('Japan', 2, 'Eastern and South-Eastern Asia'),
#  ('Japan', 3, 'Eastern and South-Eastern Asia'),
#  ('Jordan', 13, 'Northern Africa and Western Asia'),
#  ('Jordan', 15, 'Northern Africa and Western Asia'),
#  ('Jordan', 18, 'Northern Africa and Western Asia'),
#  ('Jordan', 18, 'Northern Africa and Western Asia'),
#  ('Jordan', 17, 'Northern Africa and Western Asia'),
#  ('Jordan', 19, 'Northern Africa and Western Asia'),
#  ('Kazakhstan', 5, 'Central and Southern Asia'),
#  ('Kazakhstan', 5, 'Central and Southern Asia'),
#  ('Kazakhstan', 5, 'Central and Southern Asia'),
#  ('Kazakhstan', 5, 'Central and Southern Asia'),
#  ('Kazakhstan', 5, 'Central and Southern Asia'),
#  ('Kazakhstan', 5, 'Central and Southern Asia'),
#  ('Kenya', None, 'Sub-Saharan Africa'),
#  ('Kenya', 3, 'Sub-Saharan Africa'),
#  ('Kenya', None, 'Sub-Saharan Africa'),
#  ('Kenya', None, 'Sub-Saharan Africa'),
#  ('Kenya', 5, 'Sub-Saharan Africa'),
#  ('Kenya', None, 'Sub-Saharan Africa'),
#  ('Kiribati', 9, 'Oceania'),
#  ('Kiribati', None, 'Oceania'),
#  ('Kiribati', None, 'Oceania'),
#  ('Kiribati', None, 'Oceania'),
#  ('Kiribati', 9, 'Oceania'),
#  ('Kiribati', 11, 'Oceania'),
#  ('Kuwait', 2, 'Northern Africa and Western Asia'),
#  ('Kuwait', 2, 'Northern Africa and Western Asia'),
#  ('Kuwait', None, 'Northern Africa and Western Asia'),
#  ('Kuwait', None, 'Northern Africa and Western Asia'),
#  ('Kuwait', None, 'Northern Africa and Western Asia'),
#  ('Kuwait', None, 'Northern Africa and Western Asia'),
#  ('Kyrgyzstan', None, 'Central and Southern Asia'),
#  ('Kyrgyzstan', None, 'Central and Southern Asia'),
#  ('Kyrgyzstan', None, 'Central and Southern Asia'),
#  ('Kyrgyzstan', None, 'Central and Southern Asia'),
#  ('Kyrgyzstan', None, 'Central and Southern Asia'),
#  ('Kyrgyzstan', None, 'Central and Southern Asia'),
#  ("Lao People's Democratic Republic", None, 'Eastern and South-Eastern Asia'),
#  ("Lao People's Democratic Republic", None, 'Eastern and South-Eastern Asia'),
#  ("Lao People's Democratic Republic", None, 'Eastern and South-Eastern Asia'),
#  ("Lao People's Democratic Republic", None, 'Eastern and South-Eastern Asia'),
#  ("Lao People's Democratic Republic", None, 'Eastern and South-Eastern Asia'),
#  ("Lao People's Democratic Republic", None, 'Eastern and South-Eastern Asia'),
#  ('Lebanon', None, 'Northern Africa and Western Asia'),
#  ('Lebanon', None, 'Northern Africa and Western Asia'),
#  ('Lebanon', None, 'Northern Africa and Western Asia'),
#  ('Lebanon', None, 'Northern Africa and Western Asia'),
#  ('Lebanon', 11, 'Northern Africa and Western Asia'),
#  ('Lebanon', None, 'Northern Africa and Western Asia'),
#  ('Lesotho', None, 'Sub-Saharan Africa'),
#  ('Lesotho', None, 'Sub-Saharan Africa'),
#  ('Lesotho', None, 'Sub-Saharan Africa'),
#  ('Lesotho', None, 'Sub-Saharan Africa'),
#  ('Lesotho', 17, 'Sub-Saharan Africa'),
#  ('Lesotho', None, 'Sub-Saharan Africa'),
#  ('Liberia', None, 'Sub-Saharan Africa'),
#  ('Liberia', 3, 'Sub-Saharan Africa'),
#  ('Liberia', 6, 'Sub-Saharan Africa'),
#  ('Liberia', None, 'Sub-Saharan Africa'),
#  ('Liberia', None, 'Sub-Saharan Africa'),
#  ('Liberia', None, 'Sub-Saharan Africa'),
#  ('Libya', None, 'Northern Africa and Western Asia'),
#  ('Libya', None, 'Northern Africa and Western Asia'),
#  ('Libya', None, 'Northern Africa and Western Asia'),
#  ('Libya', None, 'Northern Africa and Western Asia'),
#  ('Libya', None, 'Northern Africa and Western Asia'),
#  ('Libya', None, 'Northern Africa and Western Asia'),
#  ('Madagascar', 2, 'Sub-Saharan Africa'),
#  ('Madagascar', None, 'Sub-Saharan Africa'),
#  ('Madagascar', None, 'Sub-Saharan Africa'),
#  ('Madagascar', None, 'Sub-Saharan Africa'),
#  ('Madagascar', None, 'Sub-Saharan Africa'),
#  ('Madagascar', None, 'Sub-Saharan Africa'),
#  ('Malawi', None, 'Sub-Saharan Africa'),
#  ('Malawi', None, 'Sub-Saharan Africa'),
#  ('Malawi', 4, 'Sub-Saharan Africa'),
#  ('Malawi', None, 'Sub-Saharan Africa'),
#  ('Malawi', None, 'Sub-Saharan Africa'),
#  ('Malawi', 1, 'Sub-Saharan Africa'),
#  ('Malaysia', 3, 'Eastern and South-Eastern Asia'),
#  ('Malaysia', 3, 'Eastern and South-Eastern Asia'),
#  ('Malaysia', 3, 'Eastern and South-Eastern Asia'),
#  ('Malaysia', 3, 'Eastern and South-Eastern Asia'),
#  ('Malaysia', 3, 'Eastern and South-Eastern Asia'),
#  ('Malaysia', 5, 'Eastern and South-Eastern Asia'),
#  ('Maldives', None, 'Central and Southern Asia'),
#  ('Maldives', 6, 'Central and Southern Asia'),
#  ('Maldives', None, 'Central and Southern Asia'),
#  ('Maldives', None, 'Central and Southern Asia'),
#  ('Maldives', 5, 'Central and Southern Asia'),
#  ('Maldives', None, 'Central and Southern Asia'),
#  ('Mali', 8, 'Sub-Saharan Africa'),
#  ('Mali', 1, 'Sub-Saharan Africa'),
#  ('Mali', 7, 'Sub-Saharan Africa'),
#  ('Mali', 2, 'Sub-Saharan Africa'),
#  ('Mali', None, 'Sub-Saharan Africa'),
#  ('Mali', 4, 'Sub-Saharan Africa'),
#  ('Marshall Islands', None, 'Oceania'),
#  ('Marshall Islands', None, 'Oceania'),
#  ('Marshall Islands', None, 'Oceania'),
#  ('Marshall Islands', None, 'Oceania'),
#  ('Marshall Islands', 6, 'Oceania'),
#  ('Marshall Islands', None, 'Oceania'),
#  ('Martinique', None, 'Latin America and the Caribbean'),
#  ('Martinique', None, 'Latin America and the Caribbean'),
#  ('Martinique', None, 'Latin America and the Caribbean'),
#  ('Martinique', None, 'Latin America and the Caribbean'),
#  ('Martinique', None, 'Latin America and the Caribbean'),
#  ('Martinique', None, 'Latin America and the Caribbean'),
#  ('Mauritania', None, 'Sub-Saharan Africa'),
#  ('Mauritania', None, 'Sub-Saharan Africa'),
#  ('Mauritania', 10, 'Sub-Saharan Africa'),
#  ('Mauritania', None, 'Sub-Saharan Africa'),
#  ('Mauritania', 10, 'Sub-Saharan Africa'),
#  ('Mauritania', None, 'Sub-Saharan Africa'),
#  ('Mauritius', 7, 'Sub-Saharan Africa'),
#  ('Mauritius', 7, 'Sub-Saharan Africa'),
#  ('Mauritius', 7, 'Sub-Saharan Africa'),
#  ('Mauritius', 6, 'Sub-Saharan Africa'),
#  ('Mauritius', 6, 'Sub-Saharan Africa'),
#  ('Mauritius', 9, 'Sub-Saharan Africa'),
#  ('Mayotte', None, 'Sub-Saharan Africa'),
#  ('Mayotte', None, 'Sub-Saharan Africa'),
#  ('Mayotte', None, 'Sub-Saharan Africa'),
#  ('Mayotte', None, 'Sub-Saharan Africa'),
#  ('Mayotte', None, 'Sub-Saharan Africa'),
#  ('Mayotte', None, 'Sub-Saharan Africa'),
#  ('Mexico', 4, 'Latin America and the Caribbean'),
#  ('Mexico', 4, 'Latin America and the Caribbean'),
#  ('Mexico', 3, 'Latin America and the Caribbean'),
#  ('Mexico', 3, 'Latin America and the Caribbean'),
#  ('Mexico', 3, 'Latin America and the Caribbean'),
#  ('Mexico', 4, 'Latin America and the Caribbean'),
#  ('Micronesia (Federated States of)', None, 'Oceania'),
#  ('Micronesia (Federated States of)', None, 'Oceania'),
#  ('Micronesia (Federated States of)', None, 'Oceania'),
#  ('Micronesia (Federated States of)', None, 'Oceania'),
#  ('Micronesia (Federated States of)', None, 'Oceania'),
#  ('Mongolia', 5, 'Eastern and South-Eastern Asia'),
#  ('Mongolia', 7, 'Eastern and South-Eastern Asia'),
#  ('Mongolia', 6, 'Eastern and South-Eastern Asia'),
#  ('Mongolia', 5, 'Eastern and South-Eastern Asia'),
#  ('Mongolia', 9, 'Eastern and South-Eastern Asia'),
#  ('Mongolia', 7, 'Eastern and South-Eastern Asia'),
#  ('Montserrat', None, 'Latin America and the Caribbean'),
#  ('Montserrat', None, 'Latin America and the Caribbean'),
#  ('Montserrat', None, 'Latin America and the Caribbean'),
#  ('Montserrat', None, 'Latin America and the Caribbean'),
#  ('Montserrat', None, 'Latin America and the Caribbean'),
#  ('Montserrat', None, 'Latin America and the Caribbean'),
#  ('Morocco', 9, 'Northern Africa and Western Asia'),
#  ('Morocco', 9, 'Northern Africa and Western Asia'),
#  ('Morocco', None, 'Northern Africa and Western Asia'),
#  ('Morocco', None, 'Northern Africa and Western Asia'),
#  ('Morocco', None, 'Northern Africa and Western Asia'),
#  ('Morocco', None, 'Northern Africa and Western Asia'),
#  ('Mozambique', 3, 'Sub-Saharan Africa'),
#  ('Mozambique', None, 'Sub-Saharan Africa'),
#  ('Mozambique', None, 'Sub-Saharan Africa'),
#  ('Mozambique', None, 'Sub-Saharan Africa'),
#  ('Mozambique', None, 'Sub-Saharan Africa'),
#  ('Mozambique', None, 'Sub-Saharan Africa'),
#  ('Myanmar', 1, 'Eastern and South-Eastern Asia'),
#  ('Myanmar', None, 'Eastern and South-Eastern Asia'),
#  ('Myanmar', 1, 'Eastern and South-Eastern Asia'),
#  ('Myanmar', 1, 'Eastern and South-Eastern Asia'),
#  ('Myanmar', 0, 'Eastern and South-Eastern Asia'),
#  ('Myanmar', 1, 'Eastern and South-Eastern Asia'),
#  ('Namibia', None, 'Sub-Saharan Africa'),
#  ('Namibia', 23, 'Sub-Saharan Africa'),
#  ('Namibia', None, 'Sub-Saharan Africa'),
#  ('Namibia', 20, 'Sub-Saharan Africa'),
#  ('Namibia', None, 'Sub-Saharan Africa'),
#  ('Namibia', None, 'Sub-Saharan Africa'),
#  ('Nauru', None, 'Oceania'),
#  ('Nauru', None, 'Oceania'),
#  ('Nauru', None, 'Oceania'),
#  ('Nauru', None, 'Oceania'),
#  ('Nauru', None, 'Oceania'),
#  ('Nauru', None, 'Oceania'),
#  ('Nepal', 3, 'Central and Southern Asia'),
#  ('Nepal', None, 'Central and Southern Asia'),
#  ('Nepal', 11, 'Central and Southern Asia'),
#  ('Nepal', None, 'Central and Southern Asia'),
#  ('Nepal', None, 'Central and Southern Asia'),
#  ('Nepal', None, 'Central and Southern Asia'),
#  ('New Caledonia', None, 'Oceania'),
#  ('New Caledonia', None, 'Oceania'),
#  ('New Caledonia', 12, 'Oceania'),
#  ('New Caledonia', 12, 'Oceania'),
#  ('New Caledonia', 11, 'Oceania'),
#  ('New Caledonia', 14, 'Oceania'),
#  ('New Zealand', 5, 'Oceania'),
#  ('New Zealand', 5, 'Oceania'),
#  ('New Zealand', 5, 'Oceania'),
#  ('New Zealand', 4, 'Oceania'),
#  ('New Zealand', 4, 'Oceania'),
#  ('New Zealand', 5, 'Oceania'),
#  ('Nicaragua', 5, 'Latin America and the Caribbean'),
#  ('Nicaragua', 4, 'Latin America and the Caribbean'),
#  ('Nicaragua', 3, 'Latin America and the Caribbean'),
#  ('Nicaragua', 5, 'Latin America and the Caribbean'),
#  ('Nicaragua', None, 'Latin America and the Caribbean'),
#  ('Nicaragua', None, 'Latin America and the Caribbean'),
#  ('Niger', None, 'Sub-Saharan Africa'),
#  ('Niger', None, 'Sub-Saharan Africa'),
#  ('Niger', 8, 'Sub-Saharan Africa'),
#  ('Niger', None, 'Sub-Saharan Africa'),
#  ('Niger', None, 'Sub-Saharan Africa'),
#  ('Niger', None, 'Sub-Saharan Africa'),
#  ('Nigeria', 4, 'Sub-Saharan Africa'),
#  ('Nigeria', 7, 'Sub-Saharan Africa'),
#  ('Nigeria', 8, 'Sub-Saharan Africa'),
#  ('Nigeria', None, 'Sub-Saharan Africa'),
#  ('Nigeria', 11, 'Sub-Saharan Africa'),
#  ('Nigeria', None, 'Sub-Saharan Africa'),
#  ('Niue', None, 'Oceania'),
#  ('Niue', None, 'Oceania'),
#  ('Niue', None, 'Oceania'),
#  ('Niue', None, 'Oceania'),
#  ('Niue', None, 'Oceania'),
#  ('Niue', None, 'Oceania'),
#  ('Northern Mariana Islands', None, 'Oceania'),
#  ('Northern Mariana Islands', None, 'Oceania'),
#  ('Northern Mariana Islands', None, 'Oceania'),
#  ('Northern Mariana Islands', None, 'Oceania'),
#  ('Northern Mariana Islands', None, 'Oceania'),
#  ('Northern Mariana Islands', None, 'Oceania'),
#  ('Oman', None, 'Northern Africa and Western Asia'),
#  ('Oman', 3, 'Northern Africa and Western Asia'),
#  ('Oman', None, 'Northern Africa and Western Asia'),
#  ('Oman', 2, 'Northern Africa and Western Asia'),
#  ('Oman', None, 'Northern Africa and Western Asia'),
#  ('Oman', 3, 'Northern Africa and Western Asia'),
#  ('Pakistan', 4, 'Central and Southern Asia'),
#  ('Pakistan', None, 'Central and Southern Asia'),
#  ('Pakistan', None, 'Central and Southern Asia'),
#  ('Pakistan', 4, 'Central and Southern Asia'),
#  ('Pakistan', 5, 'Central and Southern Asia'),
#  ('Pakistan', None, 'Central and Southern Asia'),
#  ('Palau', None, 'Oceania'),
#  ('Palau', None, 'Oceania'),
#  ('Palau', None, 'Oceania'),
#  ('Palau', None, 'Oceania'),
#  ('Palau', None, 'Oceania'),
#  ('Palau', 1, 'Oceania'),
#  ('Panama', 4, 'Latin America and the Caribbean'),
#  ('Panama', 5, 'Latin America and the Caribbean'),
#  ('Panama', 5, 'Latin America and the Caribbean'),
#  ('Panama', 5, 'Latin America and the Caribbean'),
#  ('Panama', 6, 'Latin America and the Caribbean'),
#  ('Panama', 19, 'Latin America and the Caribbean'),
#  ('Papua New Guinea', None, 'Oceania'),
#  ('Papua New Guinea', None, 'Oceania'),
#  ('Papua New Guinea', None, 'Oceania'),
#  ('Papua New Guinea', None, 'Oceania'),
#  ('Papua New Guinea', None, 'Oceania'),
#  ('Papua New Guinea', None, 'Oceania'),
#  ('Paraguay', 5, 'Latin America and the Caribbean'),
#  ('Paraguay', 5, 'Latin America and the Caribbean'),
#  ('Paraguay', 5, 'Latin America and the Caribbean'),
#  ('Paraguay', 6, 'Latin America and the Caribbean'),
#  ('Paraguay', 7, 'Latin America and the Caribbean'),
#  ('Paraguay', 8, 'Latin America and the Caribbean'),
#  ('Peru', 3, 'Latin America and the Caribbean'),
#  ('Peru', 4, 'Latin America and the Caribbean'),
#  ('Peru', 4, 'Latin America and the Caribbean'),
#  ('Peru', 3, 'Latin America and the Caribbean'),
#  ('Peru', 3, 'Latin America and the Caribbean'),
#  ('Peru', 7, 'Latin America and the Caribbean'),
#  ('Philippines', 3, 'Eastern and South-Eastern Asia'),
#  ('Philippines', 3, 'Eastern and South-Eastern Asia'),
#  ('Philippines', 3, 'Eastern and South-Eastern Asia'),
#  ('Philippines', 2, 'Eastern and South-Eastern Asia'),
#  ('Philippines', 2, 'Eastern and South-Eastern Asia'),
#  ('Philippines', 3, 'Eastern and South-Eastern Asia'),
#  ('Puerto Rico', 12, 'Latin America and the Caribbean'),
#  ('Puerto Rico', 12, 'Latin America and the Caribbean'),
#  ('Puerto Rico', 11, 'Latin America and the Caribbean'),
#  ('Puerto Rico', 9, 'Latin America and the Caribbean'),
#  ('Puerto Rico', 8, 'Latin America and the Caribbean'),
#  ('Puerto Rico', None, 'Latin America and the Caribbean'),
#  ('Qatar', 0, 'Northern Africa and Western Asia'),
#  ('Qatar', 0, 'Northern Africa and Western Asia'),
#  ('Qatar', 0, 'Northern Africa and Western Asia'),
#  ('Qatar', 0, 'Northern Africa and Western Asia'),
#  ('Qatar', 0, 'Northern Africa and Western Asia'),
#  ('Qatar', 0, 'Northern Africa and Western Asia'),
#  ('Republic of Korea', None, 'Eastern and South-Eastern Asia'),
#  ('Republic of Korea', None, 'Eastern and South-Eastern Asia'),
#  ('Republic of Korea', None, 'Eastern and South-Eastern Asia'),
#  ('Republic of Korea', None, 'Eastern and South-Eastern Asia'),
#  ('Republic of Korea', None, 'Eastern and South-Eastern Asia'),
#  ('Republic of Korea', None, 'Eastern and South-Eastern Asia'),
#  ('Réunion', None, 'Sub-Saharan Africa'),
#  ('Réunion', None, 'Sub-Saharan Africa'),
#  ('Réunion', None, 'Sub-Saharan Africa'),
#  ('Réunion', None, 'Sub-Saharan Africa'),
#  ('Réunion', None, 'Sub-Saharan Africa'),
#  ('Réunion', None, 'Sub-Saharan Africa'),
#  ('Rwanda', None, 'Sub-Saharan Africa'),
#  ('Rwanda', None, 'Sub-Saharan Africa'),
#  ('Rwanda', 12, 'Sub-Saharan Africa'),
#  ('Rwanda', 11, 'Sub-Saharan Africa'),
#  ('Rwanda', 11, 'Sub-Saharan Africa'),
#  ('Rwanda', 12, 'Sub-Saharan Africa'),
#  ('Saint Barthélemy', None, 'Latin America and the Caribbean'),
#  ('Saint Barthélemy', None, 'Latin America and the Caribbean'),
#  ('Saint Barthélemy', None, 'Latin America and the Caribbean'),
#  ('Saint Barthélemy', None, 'Latin America and the Caribbean'),
#  ('Saint Barthélemy', None, 'Latin America and the Caribbean'),
#  ('Saint Barthélemy', None, 'Latin America and the Caribbean'),
#  ('Saint Helena', None, 'Sub-Saharan Africa'),
#  ('Saint Helena', None, 'Sub-Saharan Africa'),
#  ('Saint Helena', None, 'Sub-Saharan Africa'),
#  ('Saint Helena', None, 'Sub-Saharan Africa'),
#  ('Saint Helena', None, 'Sub-Saharan Africa'),
#  ('Saint Helena', None, 'Sub-Saharan Africa'),
#  ('Saint Kitts and Nevis', None, 'Latin America and the Caribbean'),
#  ('Saint Kitts and Nevis', None, 'Latin America and the Caribbean'),
#  ('Saint Kitts and Nevis', None, 'Latin America and the Caribbean'),
#  ('Saint Lucia', None, 'Latin America and the Caribbean'),
#  ('Saint Lucia', None, 'Latin America and the Caribbean'),
#  ('Saint Lucia', None, 'Latin America and the Caribbean'),
#  ('Saint Lucia', None, 'Latin America and the Caribbean'),
#  ('Saint Lucia', None, 'Latin America and the Caribbean'),
#  ('Saint Lucia', None, 'Latin America and the Caribbean'),
#  ('Saint Martin (French Part)', None, 'Latin America and the Caribbean'),
#  ('Saint Martin (French Part)', None, 'Latin America and the Caribbean'),
#  ('Saint Martin (French Part)', None, 'Latin America and the Caribbean'),
#  ('Saint Martin (French Part)', None, 'Latin America and the Caribbean'),
#  ('Saint Martin (French Part)', None, 'Latin America and the Caribbean'),
#  ('Saint Martin (French Part)', None, 'Latin America and the Caribbean'),
#  ('Saint Pierre and Miquelon', None, 'Europe and Northern America'),
#  ('Saint Pierre and Miquelon', None, 'Europe and Northern America'),
#  ('Saint Pierre and Miquelon', None, 'Europe and Northern America'),
#  ('Saint Pierre and Miquelon', None, 'Europe and Northern America'),
#  ('Saint Pierre and Miquelon', None, 'Europe and Northern America'),
#  ('Saint Pierre and Miquelon', None, 'Europe and Northern America'),
#  ('Saint Vincent and the Grenadines', None, 'Latin America and the Caribbean'),
#  ('Saint Vincent and the Grenadines', None, 'Latin America and the Caribbean'),
#  ('Saint Vincent and the Grenadines', None, 'Latin America and the Caribbean'),
#  ('Saint Vincent and the Grenadines', None, 'Latin America and the Caribbean'),
#  ('Samoa', None, 'Oceania'),
#  ('Samoa', None, 'Oceania'),
#  ('Samoa', 9, 'Oceania'),
#  ('Samoa', None, 'Oceania'),
#  ('Samoa', None, 'Oceania'),
#  ('Samoa', None, 'Oceania'),
#  ('Sao Tome and Principe', None, 'Sub-Saharan Africa'),
#  ('Sao Tome and Principe', None, 'Sub-Saharan Africa'),
#  ('Sao Tome and Principe', None, 'Sub-Saharan Africa'),
#  ('Sao Tome and Principe', None, 'Sub-Saharan Africa'),
#  ('Sao Tome and Principe', None, 'Sub-Saharan Africa'),
#  ('Sao Tome and Principe', None, 'Sub-Saharan Africa'),
#  ('Saudi Arabia', 6, 'Northern Africa and Western Asia'),
#  ('Saudi Arabia', 6, 'Northern Africa and Western Asia'),
#  ('Saudi Arabia', 6, 'Northern Africa and Western Asia'),
#  ('Saudi Arabia', 6, 'Northern Africa and Western Asia'),
#  ('Saudi Arabia', 6, 'Northern Africa and Western Asia'),
#  ('Saudi Arabia', 8, 'Northern Africa and Western Asia'),
#  ('Senegal', 7, 'Sub-Saharan Africa'),
#  ('Senegal', 4, 'Sub-Saharan Africa'),
#  ('Senegal', 4, 'Sub-Saharan Africa'),
#  ('Senegal', 4, 'Sub-Saharan Africa'),
#  ('Senegal', 3, 'Sub-Saharan Africa'),
#  ('Senegal', None, 'Sub-Saharan Africa'),
#  ('Seychelles', 4, 'Sub-Saharan Africa'),
#  ('Seychelles', 4, 'Sub-Saharan Africa'),
#  ('Seychelles', 4, 'Sub-Saharan Africa'),
#  ('Seychelles', 4, 'Sub-Saharan Africa'),
#  ('Seychelles', 3, 'Sub-Saharan Africa'),
#  ('Sierra Leone', None, 'Sub-Saharan Africa'),
#  ('Sierra Leone', None, 'Sub-Saharan Africa'),
#  ('Sierra Leone', None, 'Sub-Saharan Africa'),
#  ('Sierra Leone', 3, 'Sub-Saharan Africa'),
#  ('Sierra Leone', None, 'Sub-Saharan Africa'),
#  ('Sierra Leone', None, 'Sub-Saharan Africa'),
#  ('Singapore', 4, 'Eastern and South-Eastern Asia'),
#  ('Singapore', 4, 'Eastern and South-Eastern Asia'),
#  ('Singapore', 4, 'Eastern and South-Eastern Asia'),
#  ('Singapore', None, 'Eastern and South-Eastern Asia'),
#  ('Singapore', 3, 'Eastern and South-Eastern Asia'),
#  ('Singapore', 4, 'Eastern and South-Eastern Asia'),
#  ('Sint Maarten (Dutch part)', None, 'Latin America and the Caribbean'),
#  ('Sint Maarten (Dutch part)', None, 'Latin America and the Caribbean'),
#  ('Sint Maarten (Dutch part)', None, 'Latin America and the Caribbean'),
#  ('Solomon Islands', None, 'Oceania'),
#  ('Solomon Islands', None, 'Oceania'),
#  ('Solomon Islands', None, 'Oceania'),
#  ('Solomon Islands', None, 'Oceania'),
#  ('Solomon Islands', None, 'Oceania'),
#  ('Solomon Islands', None, 'Oceania'),
#  ('Somalia', None, 'Sub-Saharan Africa'),
#  ('Somalia', None, 'Sub-Saharan Africa'),
#  ('Somalia', None, 'Sub-Saharan Africa'),
#  ('Somalia', None, 'Sub-Saharan Africa'),
#  ('Somalia', 19, 'Sub-Saharan Africa'),
#  ('Somalia', None, 'Sub-Saharan Africa'),
#  ('South Africa', 23, 'Sub-Saharan Africa'),
#  ('South Africa', 24, 'Sub-Saharan Africa'),
#  ('South Africa', 24, 'Sub-Saharan Africa'),
#  ('South Africa', 24, 'Sub-Saharan Africa'),
#  ('South Africa', 26, 'Sub-Saharan Africa'),
#  ('South Africa', 24, 'Sub-Saharan Africa'),
#  ('South Sudan', None, 'Sub-Saharan Africa'),
#  ('South Sudan', None, 'Sub-Saharan Africa'),
#  ('South Sudan', None, 'Sub-Saharan Africa'),
#  ('South Sudan', None, 'Sub-Saharan Africa'),
#  ('South Sudan', None, 'Sub-Saharan Africa'),
#  ('South Sudan', None, 'Sub-Saharan Africa'),
#  ('Sri Lanka', 5, 'Central and Southern Asia'),
#  ('Sri Lanka', 4, 'Central and Southern Asia'),
#  ('Sri Lanka', 4, 'Central and Southern Asia'),
#  ('Sri Lanka', 4, 'Central and Southern Asia'),
#  ('Sri Lanka', 5, 'Central and Southern Asia'),
#  ('Sri Lanka', 5, 'Central and Southern Asia'),
#  ('State of Palestine', None, 'Northern Africa and Western Asia'),
#  ('State of Palestine', None, 'Northern Africa and Western Asia'),
#  ('State of Palestine', None, 'Northern Africa and Western Asia'),
#  ('State of Palestine', None, 'Northern Africa and Western Asia'),
#  ('State of Palestine', None, 'Northern Africa and Western Asia'),
#  ('State of Palestine', None, 'Northern Africa and Western Asia'),
#  ('Sudan', None, 'Northern Africa and Western Asia'),
#  ('Sudan', None, 'Northern Africa and Western Asia'),
#  ('Sudan', None, 'Northern Africa and Western Asia'),
#  ('Sudan', None, 'Northern Africa and Western Asia'),
#  ('Sudan', None, 'Northern Africa and Western Asia'),
#  ('Sudan', None, 'Northern Africa and Western Asia'),
#  ('Suriname', 7, 'Latin America and the Caribbean'),
#  ('Suriname', 8, 'Latin America and the Caribbean'),
#  ('Suriname', None, 'Latin America and the Caribbean'),
#  ('Suriname', None, 'Latin America and the Caribbean'),
#  ('Suriname', None, 'Latin America and the Caribbean'),
#  ('Suriname', None, 'Latin America and the Caribbean'),
#  ('Syrian Arab Republic', None, 'Northern Africa and Western Asia'),
#  ('Syrian Arab Republic', None, 'Northern Africa and Western Asia'),
#  ('Syrian Arab Republic', None, 'Northern Africa and Western Asia'),
#  ('Syrian Arab Republic', None, 'Northern Africa and Western Asia'),
#  ('Syrian Arab Republic', None, 'Northern Africa and Western Asia'),
#  ('Syrian Arab Republic', None, 'Northern Africa and Western Asia'),
#  ('Tajikistan', None, 'Central and Southern Asia'),
#  ('Tajikistan', 7, 'Central and Southern Asia'),
#  ('Tajikistan', None, 'Central and Southern Asia'),
#  ('Tajikistan', None, 'Central and Southern Asia'),
#  ('Tajikistan', None, 'Central and Southern Asia'),
#  ('Tajikistan', None, 'Central and Southern Asia'),
#  ('Thailand', 1, 'Eastern and South-Eastern Asia'),
#  ('Thailand', 1, 'Eastern and South-Eastern Asia'),
#  ('Thailand', 1, 'Eastern and South-Eastern Asia'),
#  ('Thailand', 1, 'Eastern and South-Eastern Asia'),
#  ('Thailand', 1, 'Eastern and South-Eastern Asia'),
#  ('Thailand', 1, 'Eastern and South-Eastern Asia'),
#  ('Timor-Leste', None, 'Eastern and South-Eastern Asia'),
#  ('Timor-Leste', 5, 'Eastern and South-Eastern Asia'),
#  ('Timor-Leste', None, 'Eastern and South-Eastern Asia'),
#  ('Timor-Leste', None, 'Eastern and South-Eastern Asia'),
#  ('Timor-Leste', None, 'Eastern and South-Eastern Asia'),
#  ('Timor-Leste', None, 'Eastern and South-Eastern Asia'),
#  ('Togo', 2, 'Sub-Saharan Africa'),
#  ('Togo', None, 'Sub-Saharan Africa'),
#  ('Togo', 4, 'Sub-Saharan Africa'),
#  ('Togo', None, 'Sub-Saharan Africa'),
#  ('Togo', None, 'Sub-Saharan Africa'),
#  ('Togo', None, 'Sub-Saharan Africa'),
#  ('Tokelau', None, 'Oceania'),
#  ('Tokelau', None, 'Oceania'),
#  ('Tokelau', None, 'Oceania'),
#  ('Tokelau', None, 'Oceania'),
#  ('Tokelau', None, 'Oceania'),
#  ('Tokelau', None, 'Oceania'),
#  ('Tonga', None, 'Oceania'),
#  ('Tonga', None, 'Oceania'),
#  ('Tonga', None, 'Oceania'),
#  ('Tonga', 2, 'Oceania'),
#  ('Tonga', None, 'Oceania'),
#  ('Tonga', None, 'Oceania'),
#  ('Trinidad and Tobago', 2, 'Latin America and the Caribbean'),
#  ('Trinidad and Tobago', 3, 'Latin America and the Caribbean'),
#  ('Trinidad and Tobago', None, 'Latin America and the Caribbean'),
#  ('Trinidad and Tobago', None, 'Latin America and the Caribbean'),
#  ('Trinidad and Tobago', 4, 'Latin America and the Caribbean'),
#  ('Trinidad and Tobago', 4, 'Latin America and the Caribbean'),
#  ('Tunisia', 15, 'Northern Africa and Western Asia'),
#  ('Tunisia', 16, 'Northern Africa and Western Asia'),
#  ('Tunisia', 15, 'Northern Africa and Western Asia'),
#  ('Tunisia', 15, 'Northern Africa and Western Asia'),
#  ('Tunisia', 15, 'Northern Africa and Western Asia'),
#  ('Tunisia', None, 'Northern Africa and Western Asia'),
#  ('Türkiye', None, 'Northern Africa and Western Asia'),
#  ('Türkiye', None, 'Northern Africa and Western Asia'),
#  ('Türkiye', None, 'Northern Africa and Western Asia'),
#  ('Türkiye', None, 'Northern Africa and Western Asia'),
#  ('Türkiye', None, 'Northern Africa and Western Asia'),
#  ('Türkiye', None, 'Northern Africa and Western Asia'),
#  ('Turkmenistan', None, 'Central and Southern Asia'),
#  ('Turkmenistan', None, 'Central and Southern Asia'),
#  ('Turkmenistan', None, 'Central and Southern Asia'),
#  ('Turkmenistan', None, 'Central and Southern Asia'),
#  ('Turkmenistan', None, 'Central and Southern Asia'),
#  ('Turkmenistan', None, 'Central and Southern Asia'),
#  ('Turks and Caicos Islands', None, 'Latin America and the Caribbean'),
#  ('Turks and Caicos Islands', None, 'Latin America and the Caribbean'),
#  ('Turks and Caicos Islands', None, 'Latin America and the Caribbean'),
#  ('Turks and Caicos Islands', None, 'Latin America and the Caribbean'),
#  ('Tuvalu', None, 'Oceania'),
#  ('Tuvalu', 8, 'Oceania'),
#  ('Tuvalu', 27, 'Oceania'),
#  ('Tuvalu', None, 'Oceania'),
#  ('Tuvalu', None, 'Oceania'),
#  ('Tuvalu', None, 'Oceania'),
#  ('Uganda', None, 'Sub-Saharan Africa'),
#  ('Uganda', None, 'Sub-Saharan Africa'),
#  ('Uganda', 4, 'Sub-Saharan Africa'),
#  ('Uganda', None, 'Sub-Saharan Africa'),
#  ('Uganda', None, 'Sub-Saharan Africa'),
#  ('Uganda', None, 'Sub-Saharan Africa'),
#  ('United Arab Emirates', None, 'Northern Africa and Western Asia'),
#  ('United Arab Emirates', 2, 'Northern Africa and Western Asia'),
#  ('United Arab Emirates', 2, 'Northern Africa and Western Asia'),
#  ('United Arab Emirates', 2, 'Northern Africa and Western Asia'),
#  ('United Arab Emirates', 2, 'Northern Africa and Western Asia'),
#  ('United Arab Emirates', 4, 'Northern Africa and Western Asia'),
#  ('United Republic of Tanzania', None, 'Sub-Saharan Africa'),
#  ('United Republic of Tanzania', None, 'Sub-Saharan Africa'),
#  ('United Republic of Tanzania', None, 'Sub-Saharan Africa'),
#  ('United Republic of Tanzania', None, 'Sub-Saharan Africa'),
#  ('United Republic of Tanzania', None, 'Sub-Saharan Africa'),
#  ('United Republic of Tanzania', None, 'Sub-Saharan Africa'),
#  ('United States of America', None, 'Europe and Northern America'),
#  ('United States of America', None, 'Europe and Northern America'),
#  ('United States of America', None, 'Europe and Northern America'),
#  ('United States of America', None, 'Europe and Northern America'),
#  ('United States of America', None, 'Europe and Northern America'),
#  ('United States of America', None, 'Europe and Northern America'),
#  ('United States Virgin Islands', None, 'Latin America and the Caribbean'),
#  ('United States Virgin Islands', None, 'Latin America and the Caribbean'),
#  ('United States Virgin Islands', None, 'Latin America and the Caribbean'),
#  ('United States Virgin Islands', None, 'Latin America and the Caribbean'),
#  ('United States Virgin Islands', None, 'Latin America and the Caribbean'),
#  ('United States Virgin Islands', None, 'Latin America and the Caribbean'),
#  ('Uruguay', 7, 'Latin America and the Caribbean'),
#  ('Uruguay', 8, 'Latin America and the Caribbean'),
#  ('Uruguay', 8, 'Latin America and the Caribbean'),
#  ('Uruguay', 8, 'Latin America and the Caribbean'),
#  ('Uruguay', 9, 'Latin America and the Caribbean'),
#  ('Uruguay', 10, 'Latin America and the Caribbean'),
#  ...]

# %%
# %%sql
# SELECT
# *
# FROM Economic_indicators
# LIMIT 5
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Afghanistan', 2015, 20, 34, None),
#  ('Afghanistan', 2016, 18, 35, None),
#  ('Afghanistan', 2017, 19, 36, 11),
#  ('Afghanistan', 2018, 18, 37, None),
#  ('Afghanistan', 2019, 19, 38, None)]

# %%
# %%sql
# SELECT
# *
# FROM Geographic_location
# LIMIT 5
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', 652230),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', 2381741),
#  ('American Samoa', 'Polynesia', 'Oceania', 200),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', 1246700),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None)]

# %% [markdown]
# ### Task 2
#
# After joining our tables, the query  now returns a table with the unemployment rate, country, and region. This allows us to filter for countries in Sub-Saharan Africa. So let's filter this table ensuring that we include Sub Sub-Saharan Africa only. Use the `WHERE` clause to filter our results for `Sub-Saharan Africa`. The table should include the following columns: `Country_name`, `Time_period`, and `Pct_unemployment`.

# %%
# %%sql
# SELECT
#     Geo.Country_name,
#     Econ.Pct_unemployment,
#     Econ.Time_period
# FROM
#     Economic_indicators AS Econ
# JOIN
#     Geographic_location AS Geo
#         ON Econ.Country_name = Geo.Country_name
# WHERE
#     Geo.Region = 'Sub-Saharan Africa';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 297 rows affected.
# [('Angola', None, 2015),
#  ('Angola', None, 2016),
#  ('Angola', None, 2017),
#  ('Angola', None, 2018),
#  ('Angola', 17, 2019),
#  ('Angola', None, 2020),
#  ('Benin', None, 2015),
#  ('Benin', None, 2016),
#  ('Benin', None, 2017),
#  ('Benin', 1, 2018),
#  ('Benin', None, 2019),
#  ('Benin', None, 2020),
#  ('Botswana', None, 2015),
#  ('Botswana', None, 2016),
#  ('Botswana', None, 2017),
#  ('Botswana', None, 2018),
#  ('Botswana', 20, 2019),
#  ('Botswana', 21, 2020),
#  ('Burkina Faso', None, 2015),
#  ('Burkina Faso', None, 2016),
#  ('Burkina Faso', None, 2017),
#  ('Burkina Faso', 5, 2018),
#  ('Burkina Faso', None, 2019),
#  ('Burkina Faso', None, 2020),
#  ('Burundi', None, 2015),
#  ('Burundi', None, 2016),
#  ('Burundi', None, 2017),
#  ('Burundi', None, 2018),
#  ('Burundi', None, 2019),
#  ('Burundi', 1, 2020),
#  ('Cabo Verde', 31, 2015),
#  ('Cabo Verde', None, 2016),
#  ('Cabo Verde', 12, 2017),
#  ('Cabo Verde', 12, 2018),
#  ('Cabo Verde', 11, 2019),
#  ('Cabo Verde', None, 2020),
#  ('Cameroon', None, 2015),
#  ('Cameroon', None, 2016),
#  ('Cameroon', None, 2017),
#  ('Cameroon', None, 2018),
#  ('Cameroon', None, 2019),
#  ('Cameroon', None, 2020),
#  ('Central African Republic', None, 2015),
#  ('Central African Republic', None, 2016),
#  ('Central African Republic', None, 2017),
#  ('Central African Republic', None, 2018),
#  ('Central African Republic', None, 2019),
#  ('Central African Republic', None, 2020),
#  ('Chad', None, 2015),
#  ('Chad', None, 2016),
#  ('Chad', None, 2017),
#  ('Chad', 1, 2018),
#  ('Chad', None, 2019),
#  ('Chad', None, 2020),
#  ('Comoros', None, 2015),
#  ('Comoros', None, 2016),
#  ('Comoros', None, 2017),
#  ('Comoros', None, 2018),
#  ('Comoros', None, 2019),
#  ('Congo', None, 2015),
#  ('Congo', None, 2016),
#  ('Congo', None, 2017),
#  ('Congo', None, 2018),
#  ('Congo', None, 2019),
#  ('Congo', None, 2020),
#  ("Côte d'Ivoire", None, 2015),
#  ("Côte d'Ivoire", None, 2016),
#  ("Côte d'Ivoire", None, 2017),
#  ("Côte d'Ivoire", None, 2018),
#  ("Côte d'Ivoire", None, 2019),
#  ("Côte d'Ivoire", None, 2020),
#  ('Democratic Republic of the Congo', None, 2015),
#  ('Democratic Republic of the Congo', None, 2016),
#  ('Democratic Republic of the Congo', None, 2017),
#  ('Democratic Republic of the Congo', None, 2018),
#  ('Democratic Republic of the Congo', None, 2019),
#  ('Democratic Republic of the Congo', None, 2020),
#  ('Djibouti', None, 2015),
#  ('Djibouti', None, 2016),
#  ('Djibouti', 26, 2017),
#  ('Djibouti', None, 2018),
#  ('Djibouti', None, 2019),
#  ('Djibouti', None, 2020),
#  ('Equatorial Guinea', None, 2015),
#  ('Equatorial Guinea', None, 2016),
#  ('Equatorial Guinea', None, 2017),
#  ('Eritrea', None, 2015),
#  ('Eritrea', None, 2016),
#  ('Eswatini', None, 2015),
#  ('Eswatini', 23, 2016),
#  ('Eswatini', None, 2017),
#  ('Eswatini', None, 2018),
#  ('Eswatini', None, 2019),
#  ('Eswatini', None, 2020),
#  ('Ethiopia', None, 2015),
#  ('Ethiopia', None, 2016),
#  ('Ethiopia', None, 2017),
#  ('Ethiopia', None, 2018),
#  ('Ethiopia', None, 2019),
#  ('Ethiopia', None, 2020),
#  ('Gabon', None, 2015),
#  ('Gabon', None, 2016),
#  ('Gabon', None, 2017),
#  ('Gabon', None, 2018),
#  ('Gabon', None, 2019),
#  ('Gabon', None, 2020),
#  ('Gambia', None, 2015),
#  ('Gambia', None, 2016),
#  ('Gambia', None, 2017),
#  ('Gambia', None, 2018),
#  ('Gambia', None, 2019),
#  ('Gambia', None, 2020),
#  ('Ghana', 7, 2015),
#  ('Ghana', None, 2016),
#  ('Ghana', 3, 2017),
#  ('Ghana', None, 2018),
#  ('Ghana', None, 2019),
#  ('Ghana', None, 2020),
#  ('Guinea', None, 2015),
#  ('Guinea', None, 2016),
#  ('Guinea', None, 2017),
#  ('Guinea', None, 2018),
#  ('Guinea', 5, 2019),
#  ('Guinea', None, 2020),
#  ('Guinea-Bissau', None, 2015),
#  ('Guinea-Bissau', None, 2016),
#  ('Guinea-Bissau', None, 2017),
#  ('Guinea-Bissau', 3, 2018),
#  ('Guinea-Bissau', None, 2019),
#  ('Guinea-Bissau', None, 2020),
#  ('Kenya', None, 2015),
#  ('Kenya', 3, 2016),
#  ('Kenya', None, 2017),
#  ('Kenya', None, 2018),
#  ('Kenya', 5, 2019),
#  ('Kenya', None, 2020),
#  ('Lesotho', None, 2015),
#  ('Lesotho', None, 2016),
#  ('Lesotho', None, 2017),
#  ('Lesotho', None, 2018),
#  ('Lesotho', 17, 2019),
#  ('Lesotho', None, 2020),
#  ('Liberia', None, 2015),
#  ('Liberia', 3, 2016),
#  ('Liberia', 6, 2017),
#  ('Liberia', None, 2018),
#  ('Liberia', None, 2019),
#  ('Liberia', None, 2020),
#  ('Madagascar', 2, 2015),
#  ('Madagascar', None, 2016),
#  ('Madagascar', None, 2017),
#  ('Madagascar', None, 2018),
#  ('Madagascar', None, 2019),
#  ('Madagascar', None, 2020),
#  ('Malawi', None, 2015),
#  ('Malawi', None, 2016),
#  ('Malawi', 4, 2017),
#  ('Malawi', None, 2018),
#  ('Malawi', None, 2019),
#  ('Malawi', 1, 2020),
#  ('Mali', 8, 2015),
#  ('Mali', 1, 2016),
#  ('Mali', 7, 2017),
#  ('Mali', 2, 2018),
#  ('Mali', None, 2019),
#  ('Mali', 4, 2020),
#  ('Mauritania', None, 2015),
#  ('Mauritania', None, 2016),
#  ('Mauritania', 10, 2017),
#  ('Mauritania', None, 2018),
#  ('Mauritania', 10, 2019),
#  ('Mauritania', None, 2020),
#  ('Mauritius', 7, 2015),
#  ('Mauritius', 7, 2016),
#  ('Mauritius', 7, 2017),
#  ('Mauritius', 6, 2018),
#  ('Mauritius', 6, 2019),
#  ('Mauritius', 9, 2020),
#  ('Mayotte', None, 2015),
#  ('Mayotte', None, 2016),
#  ('Mayotte', None, 2017),
#  ('Mayotte', None, 2018),
#  ('Mayotte', None, 2019),
#  ('Mayotte', None, 2020),
#  ('Mozambique', 3, 2015),
#  ('Mozambique', None, 2016),
#  ('Mozambique', None, 2017),
#  ('Mozambique', None, 2018),
#  ('Mozambique', None, 2019),
#  ('Mozambique', None, 2020),
#  ('Namibia', None, 2015),
#  ('Namibia', 23, 2016),
#  ('Namibia', None, 2017),
#  ('Namibia', 20, 2018),
#  ('Namibia', None, 2019),
#  ('Namibia', None, 2020),
#  ('Niger', None, 2015),
#  ('Niger', None, 2016),
#  ('Niger', 8, 2017),
#  ('Niger', None, 2018),
#  ('Niger', None, 2019),
#  ('Niger', None, 2020),
#  ('Nigeria', 4, 2015),
#  ('Nigeria', 7, 2016),
#  ('Nigeria', 8, 2017),
#  ('Nigeria', None, 2018),
#  ('Nigeria', 11, 2019),
#  ('Nigeria', None, 2020),
#  ('Réunion', None, 2015),
#  ('Réunion', None, 2016),
#  ('Réunion', None, 2017),
#  ('Réunion', None, 2018),
#  ('Réunion', None, 2019),
#  ('Réunion', None, 2020),
#  ('Rwanda', None, 2015),
#  ('Rwanda', None, 2016),
#  ('Rwanda', 12, 2017),
#  ('Rwanda', 11, 2018),
#  ('Rwanda', 11, 2019),
#  ('Rwanda', 12, 2020),
#  ('Saint Helena', None, 2015),
#  ('Saint Helena', None, 2016),
#  ('Saint Helena', None, 2017),
#  ('Saint Helena', None, 2018),
#  ('Saint Helena', None, 2019),
#  ('Saint Helena', None, 2020),
#  ('Sao Tome and Principe', None, 2015),
#  ('Sao Tome and Principe', None, 2016),
#  ('Sao Tome and Principe', None, 2017),
#  ('Sao Tome and Principe', None, 2018),
#  ('Sao Tome and Principe', None, 2019),
#  ('Sao Tome and Principe', None, 2020),
#  ('Senegal', 7, 2015),
#  ('Senegal', 4, 2016),
#  ('Senegal', 4, 2017),
#  ('Senegal', 4, 2018),
#  ('Senegal', 3, 2019),
#  ('Senegal', None, 2020),
#  ('Seychelles', 4, 2015),
#  ('Seychelles', 4, 2016),
#  ('Seychelles', 4, 2017),
#  ('Seychelles', 4, 2018),
#  ('Seychelles', 3, 2019),
#  ('Sierra Leone', None, 2015),
#  ('Sierra Leone', None, 2016),
#  ('Sierra Leone', None, 2017),
#  ('Sierra Leone', 3, 2018),
#  ('Sierra Leone', None, 2019),
#  ('Sierra Leone', None, 2020),
#  ('Somalia', None, 2015),
#  ('Somalia', None, 2016),
#  ('Somalia', None, 2017),
#  ('Somalia', None, 2018),
#  ('Somalia', 19, 2019),
#  ('Somalia', None, 2020),
#  ('South Africa', 23, 2015),
#  ('South Africa', 24, 2016),
#  ('South Africa', 24, 2017),
#  ('South Africa', 24, 2018),
#  ('South Africa', 26, 2019),
#  ('South Africa', 24, 2020),
#  ('South Sudan', None, 2015),
#  ('South Sudan', None, 2016),
#  ('South Sudan', None, 2017),
#  ('South Sudan', None, 2018),
#  ('South Sudan', None, 2019),
#  ('South Sudan', None, 2020),
#  ('Togo', 2, 2015),
#  ('Togo', None, 2016),
#  ('Togo', 4, 2017),
#  ('Togo', None, 2018),
#  ('Togo', None, 2019),
#  ('Togo', None, 2020),
#  ('Uganda', None, 2015),
#  ('Uganda', None, 2016),
#  ('Uganda', 4, 2017),
#  ('Uganda', None, 2018),
#  ('Uganda', None, 2019),
#  ('Uganda', None, 2020),
#  ('United Republic of Tanzania', None, 2015),
#  ('United Republic of Tanzania', None, 2016),
#  ('United Republic of Tanzania', None, 2017),
#  ('United Republic of Tanzania', None, 2018),
#  ('United Republic of Tanzania', None, 2019),
#  ('United Republic of Tanzania', None, 2020),
#  ('Zambia', None, 2015),
#  ('Zambia', None, 2016),
#  ('Zambia', 9, 2017),
#  ('Zambia', 5, 2018),
#  ('Zambia', 6, 2019),
#  ('Zambia', 6, 2020),
#  ('Zimbabwe', None, 2015),
#  ('Zimbabwe', None, 2016),
#  ('Zimbabwe', None, 2017),
#  ('Zimbabwe', None, 2018),
#  ('Zimbabwe', 7, 2019),
#  ('Zimbabwe', None, 2020)]

# %% [markdown]
# ### Task 3
#
# After filtering, we will notice that there are Null values in the `Pct_unemployment` column. Fill in the Null values with 33.65. Rename the imputed column, `Pct_unemployment_imputed`.

# %%
# %%sql
# SELECT
#     Geo.Country_name,
#     IFNULL(Econ.Pct_unemployment, 33.65) AS Pct_unemployment_imputed,
#     Econ.Time_period
# FROM
#     Economic_indicators AS Econ
# JOIN
#     Geographic_location AS Geo
#         ON Econ.Country_name = Geo.Country_name
# WHERE
#     Geo.Region = 'Sub-Saharan Africa';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 297 rows affected.
# [('Angola', Decimal('33.65'), 2015),
#  ('Angola', Decimal('33.65'), 2016),
#  ('Angola', Decimal('33.65'), 2017),
#  ('Angola', Decimal('33.65'), 2018),
#  ('Angola', Decimal('17.00'), 2019),
#  ('Angola', Decimal('33.65'), 2020),
#  ('Benin', Decimal('33.65'), 2015),
#  ('Benin', Decimal('33.65'), 2016),
#  ('Benin', Decimal('33.65'), 2017),
#  ('Benin', Decimal('1.00'), 2018),
#  ('Benin', Decimal('33.65'), 2019),
#  ('Benin', Decimal('33.65'), 2020),
#  ('Botswana', Decimal('33.65'), 2015),
#  ('Botswana', Decimal('33.65'), 2016),
#  ('Botswana', Decimal('33.65'), 2017),
#  ('Botswana', Decimal('33.65'), 2018),
#  ('Botswana', Decimal('20.00'), 2019),
#  ('Botswana', Decimal('21.00'), 2020),
#  ('Burkina Faso', Decimal('33.65'), 2015),
#  ('Burkina Faso', Decimal('33.65'), 2016),
#  ('Burkina Faso', Decimal('33.65'), 2017),
#  ('Burkina Faso', Decimal('5.00'), 2018),
#  ('Burkina Faso', Decimal('33.65'), 2019),
#  ('Burkina Faso', Decimal('33.65'), 2020),
#  ('Burundi', Decimal('33.65'), 2015),
#  ('Burundi', Decimal('33.65'), 2016),
#  ('Burundi', Decimal('33.65'), 2017),
#  ('Burundi', Decimal('33.65'), 2018),
#  ('Burundi', Decimal('33.65'), 2019),
#  ('Burundi', Decimal('1.00'), 2020),
#  ('Cabo Verde', Decimal('31.00'), 2015),
#  ('Cabo Verde', Decimal('33.65'), 2016),
#  ('Cabo Verde', Decimal('12.00'), 2017),
#  ('Cabo Verde', Decimal('12.00'), 2018),
#  ('Cabo Verde', Decimal('11.00'), 2019),
#  ('Cabo Verde', Decimal('33.65'), 2020),
#  ('Cameroon', Decimal('33.65'), 2015),
#  ('Cameroon', Decimal('33.65'), 2016),
#  ('Cameroon', Decimal('33.65'), 2017),
#  ('Cameroon', Decimal('33.65'), 2018),
#  ('Cameroon', Decimal('33.65'), 2019),
#  ('Cameroon', Decimal('33.65'), 2020),
#  ('Central African Republic', Decimal('33.65'), 2015),
#  ('Central African Republic', Decimal('33.65'), 2016),
#  ('Central African Republic', Decimal('33.65'), 2017),
#  ('Central African Republic', Decimal('33.65'), 2018),
#  ('Central African Republic', Decimal('33.65'), 2019),
#  ('Central African Republic', Decimal('33.65'), 2020),
#  ('Chad', Decimal('33.65'), 2015),
#  ('Chad', Decimal('33.65'), 2016),
#  ('Chad', Decimal('33.65'), 2017),
#  ('Chad', Decimal('1.00'), 2018),
#  ('Chad', Decimal('33.65'), 2019),
#  ('Chad', Decimal('33.65'), 2020),
#  ('Comoros', Decimal('33.65'), 2015),
#  ('Comoros', Decimal('33.65'), 2016),
#  ('Comoros', Decimal('33.65'), 2017),
#  ('Comoros', Decimal('33.65'), 2018),
#  ('Comoros', Decimal('33.65'), 2019),
#  ('Congo', Decimal('33.65'), 2015),
#  ('Congo', Decimal('33.65'), 2016),
#  ('Congo', Decimal('33.65'), 2017),
#  ('Congo', Decimal('33.65'), 2018),
#  ('Congo', Decimal('33.65'), 2019),
#  ('Congo', Decimal('33.65'), 2020),
#  ("Côte d'Ivoire", Decimal('33.65'), 2015),
#  ("Côte d'Ivoire", Decimal('33.65'), 2016),
#  ("Côte d'Ivoire", Decimal('33.65'), 2017),
#  ("Côte d'Ivoire", Decimal('33.65'), 2018),
#  ("Côte d'Ivoire", Decimal('33.65'), 2019),
#  ("Côte d'Ivoire", Decimal('33.65'), 2020),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2015),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2016),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2017),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2018),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2019),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2020),
#  ('Djibouti', Decimal('33.65'), 2015),
#  ('Djibouti', Decimal('33.65'), 2016),
#  ('Djibouti', Decimal('26.00'), 2017),
#  ('Djibouti', Decimal('33.65'), 2018),
#  ('Djibouti', Decimal('33.65'), 2019),
#  ('Djibouti', Decimal('33.65'), 2020),
#  ('Equatorial Guinea', Decimal('33.65'), 2015),
#  ('Equatorial Guinea', Decimal('33.65'), 2016),
#  ('Equatorial Guinea', Decimal('33.65'), 2017),
#  ('Eritrea', Decimal('33.65'), 2015),
#  ('Eritrea', Decimal('33.65'), 2016),
#  ('Eswatini', Decimal('33.65'), 2015),
#  ('Eswatini', Decimal('23.00'), 2016),
#  ('Eswatini', Decimal('33.65'), 2017),
#  ('Eswatini', Decimal('33.65'), 2018),
#  ('Eswatini', Decimal('33.65'), 2019),
#  ('Eswatini', Decimal('33.65'), 2020),
#  ('Ethiopia', Decimal('33.65'), 2015),
#  ('Ethiopia', Decimal('33.65'), 2016),
#  ('Ethiopia', Decimal('33.65'), 2017),
#  ('Ethiopia', Decimal('33.65'), 2018),
#  ('Ethiopia', Decimal('33.65'), 2019),
#  ('Ethiopia', Decimal('33.65'), 2020),
#  ('Gabon', Decimal('33.65'), 2015),
#  ('Gabon', Decimal('33.65'), 2016),
#  ('Gabon', Decimal('33.65'), 2017),
#  ('Gabon', Decimal('33.65'), 2018),
#  ('Gabon', Decimal('33.65'), 2019),
#  ('Gabon', Decimal('33.65'), 2020),
#  ('Gambia', Decimal('33.65'), 2015),
#  ('Gambia', Decimal('33.65'), 2016),
#  ('Gambia', Decimal('33.65'), 2017),
#  ('Gambia', Decimal('33.65'), 2018),
#  ('Gambia', Decimal('33.65'), 2019),
#  ('Gambia', Decimal('33.65'), 2020),
#  ('Ghana', Decimal('7.00'), 2015),
#  ('Ghana', Decimal('33.65'), 2016),
#  ('Ghana', Decimal('3.00'), 2017),
#  ('Ghana', Decimal('33.65'), 2018),
#  ('Ghana', Decimal('33.65'), 2019),
#  ('Ghana', Decimal('33.65'), 2020),
#  ('Guinea', Decimal('33.65'), 2015),
#  ('Guinea', Decimal('33.65'), 2016),
#  ('Guinea', Decimal('33.65'), 2017),
#  ('Guinea', Decimal('33.65'), 2018),
#  ('Guinea', Decimal('5.00'), 2019),
#  ('Guinea', Decimal('33.65'), 2020),
#  ('Guinea-Bissau', Decimal('33.65'), 2015),
#  ('Guinea-Bissau', Decimal('33.65'), 2016),
#  ('Guinea-Bissau', Decimal('33.65'), 2017),
#  ('Guinea-Bissau', Decimal('3.00'), 2018),
#  ('Guinea-Bissau', Decimal('33.65'), 2019),
#  ('Guinea-Bissau', Decimal('33.65'), 2020),
#  ('Kenya', Decimal('33.65'), 2015),
#  ('Kenya', Decimal('3.00'), 2016),
#  ('Kenya', Decimal('33.65'), 2017),
#  ('Kenya', Decimal('33.65'), 2018),
#  ('Kenya', Decimal('5.00'), 2019),
#  ('Kenya', Decimal('33.65'), 2020),
#  ('Lesotho', Decimal('33.65'), 2015),
#  ('Lesotho', Decimal('33.65'), 2016),
#  ('Lesotho', Decimal('33.65'), 2017),
#  ('Lesotho', Decimal('33.65'), 2018),
#  ('Lesotho', Decimal('17.00'), 2019),
#  ('Lesotho', Decimal('33.65'), 2020),
#  ('Liberia', Decimal('33.65'), 2015),
#  ('Liberia', Decimal('3.00'), 2016),
#  ('Liberia', Decimal('6.00'), 2017),
#  ('Liberia', Decimal('33.65'), 2018),
#  ('Liberia', Decimal('33.65'), 2019),
#  ('Liberia', Decimal('33.65'), 2020),
#  ('Madagascar', Decimal('2.00'), 2015),
#  ('Madagascar', Decimal('33.65'), 2016),
#  ('Madagascar', Decimal('33.65'), 2017),
#  ('Madagascar', Decimal('33.65'), 2018),
#  ('Madagascar', Decimal('33.65'), 2019),
#  ('Madagascar', Decimal('33.65'), 2020),
#  ('Malawi', Decimal('33.65'), 2015),
#  ('Malawi', Decimal('33.65'), 2016),
#  ('Malawi', Decimal('4.00'), 2017),
#  ('Malawi', Decimal('33.65'), 2018),
#  ('Malawi', Decimal('33.65'), 2019),
#  ('Malawi', Decimal('1.00'), 2020),
#  ('Mali', Decimal('8.00'), 2015),
#  ('Mali', Decimal('1.00'), 2016),
#  ('Mali', Decimal('7.00'), 2017),
#  ('Mali', Decimal('2.00'), 2018),
#  ('Mali', Decimal('33.65'), 2019),
#  ('Mali', Decimal('4.00'), 2020),
#  ('Mauritania', Decimal('33.65'), 2015),
#  ('Mauritania', Decimal('33.65'), 2016),
#  ('Mauritania', Decimal('10.00'), 2017),
#  ('Mauritania', Decimal('33.65'), 2018),
#  ('Mauritania', Decimal('10.00'), 2019),
#  ('Mauritania', Decimal('33.65'), 2020),
#  ('Mauritius', Decimal('7.00'), 2015),
#  ('Mauritius', Decimal('7.00'), 2016),
#  ('Mauritius', Decimal('7.00'), 2017),
#  ('Mauritius', Decimal('6.00'), 2018),
#  ('Mauritius', Decimal('6.00'), 2019),
#  ('Mauritius', Decimal('9.00'), 2020),
#  ('Mayotte', Decimal('33.65'), 2015),
#  ('Mayotte', Decimal('33.65'), 2016),
#  ('Mayotte', Decimal('33.65'), 2017),
#  ('Mayotte', Decimal('33.65'), 2018),
#  ('Mayotte', Decimal('33.65'), 2019),
#  ('Mayotte', Decimal('33.65'), 2020),
#  ('Mozambique', Decimal('3.00'), 2015),
#  ('Mozambique', Decimal('33.65'), 2016),
#  ('Mozambique', Decimal('33.65'), 2017),
#  ('Mozambique', Decimal('33.65'), 2018),
#  ('Mozambique', Decimal('33.65'), 2019),
#  ('Mozambique', Decimal('33.65'), 2020),
#  ('Namibia', Decimal('33.65'), 2015),
#  ('Namibia', Decimal('23.00'), 2016),
#  ('Namibia', Decimal('33.65'), 2017),
#  ('Namibia', Decimal('20.00'), 2018),
#  ('Namibia', Decimal('33.65'), 2019),
#  ('Namibia', Decimal('33.65'), 2020),
#  ('Niger', Decimal('33.65'), 2015),
#  ('Niger', Decimal('33.65'), 2016),
#  ('Niger', Decimal('8.00'), 2017),
#  ('Niger', Decimal('33.65'), 2018),
#  ('Niger', Decimal('33.65'), 2019),
#  ('Niger', Decimal('33.65'), 2020),
#  ('Nigeria', Decimal('4.00'), 2015),
#  ('Nigeria', Decimal('7.00'), 2016),
#  ('Nigeria', Decimal('8.00'), 2017),
#  ('Nigeria', Decimal('33.65'), 2018),
#  ('Nigeria', Decimal('11.00'), 2019),
#  ('Nigeria', Decimal('33.65'), 2020),
#  ('Réunion', Decimal('33.65'), 2015),
#  ('Réunion', Decimal('33.65'), 2016),
#  ('Réunion', Decimal('33.65'), 2017),
#  ('Réunion', Decimal('33.65'), 2018),
#  ('Réunion', Decimal('33.65'), 2019),
#  ('Réunion', Decimal('33.65'), 2020),
#  ('Rwanda', Decimal('33.65'), 2015),
#  ('Rwanda', Decimal('33.65'), 2016),
#  ('Rwanda', Decimal('12.00'), 2017),
#  ('Rwanda', Decimal('11.00'), 2018),
#  ('Rwanda', Decimal('11.00'), 2019),
#  ('Rwanda', Decimal('12.00'), 2020),
#  ('Saint Helena', Decimal('33.65'), 2015),
#  ('Saint Helena', Decimal('33.65'), 2016),
#  ('Saint Helena', Decimal('33.65'), 2017),
#  ('Saint Helena', Decimal('33.65'), 2018),
#  ('Saint Helena', Decimal('33.65'), 2019),
#  ('Saint Helena', Decimal('33.65'), 2020),
#  ('Sao Tome and Principe', Decimal('33.65'), 2015),
#  ('Sao Tome and Principe', Decimal('33.65'), 2016),
#  ('Sao Tome and Principe', Decimal('33.65'), 2017),
#  ('Sao Tome and Principe', Decimal('33.65'), 2018),
#  ('Sao Tome and Principe', Decimal('33.65'), 2019),
#  ('Sao Tome and Principe', Decimal('33.65'), 2020),
#  ('Senegal', Decimal('7.00'), 2015),
#  ('Senegal', Decimal('4.00'), 2016),
#  ('Senegal', Decimal('4.00'), 2017),
#  ('Senegal', Decimal('4.00'), 2018),
#  ('Senegal', Decimal('3.00'), 2019),
#  ('Senegal', Decimal('33.65'), 2020),
#  ('Seychelles', Decimal('4.00'), 2015),
#  ('Seychelles', Decimal('4.00'), 2016),
#  ('Seychelles', Decimal('4.00'), 2017),
#  ('Seychelles', Decimal('4.00'), 2018),
#  ('Seychelles', Decimal('3.00'), 2019),
#  ('Sierra Leone', Decimal('33.65'), 2015),
#  ('Sierra Leone', Decimal('33.65'), 2016),
#  ('Sierra Leone', Decimal('33.65'), 2017),
#  ('Sierra Leone', Decimal('3.00'), 2018),
#  ('Sierra Leone', Decimal('33.65'), 2019),
#  ('Sierra Leone', Decimal('33.65'), 2020),
#  ('Somalia', Decimal('33.65'), 2015),
#  ('Somalia', Decimal('33.65'), 2016),
#  ('Somalia', Decimal('33.65'), 2017),
#  ('Somalia', Decimal('33.65'), 2018),
#  ('Somalia', Decimal('19.00'), 2019),
#  ('Somalia', Decimal('33.65'), 2020),
#  ('South Africa', Decimal('23.00'), 2015),
#  ('South Africa', Decimal('24.00'), 2016),
#  ('South Africa', Decimal('24.00'), 2017),
#  ('South Africa', Decimal('24.00'), 2018),
#  ('South Africa', Decimal('26.00'), 2019),
#  ('South Africa', Decimal('24.00'), 2020),
#  ('South Sudan', Decimal('33.65'), 2015),
#  ('South Sudan', Decimal('33.65'), 2016),
#  ('South Sudan', Decimal('33.65'), 2017),
#  ('South Sudan', Decimal('33.65'), 2018),
#  ('South Sudan', Decimal('33.65'), 2019),
#  ('South Sudan', Decimal('33.65'), 2020),
#  ('Togo', Decimal('2.00'), 2015),
#  ('Togo', Decimal('33.65'), 2016),
#  ('Togo', Decimal('4.00'), 2017),
#  ('Togo', Decimal('33.65'), 2018),
#  ('Togo', Decimal('33.65'), 2019),
#  ('Togo', Decimal('33.65'), 2020),
#  ('Uganda', Decimal('33.65'), 2015),
#  ('Uganda', Decimal('33.65'), 2016),
#  ('Uganda', Decimal('4.00'), 2017),
#  ('Uganda', Decimal('33.65'), 2018),
#  ('Uganda', Decimal('33.65'), 2019),
#  ('Uganda', Decimal('33.65'), 2020),
#  ('United Republic of Tanzania', Decimal('33.65'), 2015),
#  ('United Republic of Tanzania', Decimal('33.65'), 2016),
#  ('United Republic of Tanzania', Decimal('33.65'), 2017),
#  ('United Republic of Tanzania', Decimal('33.65'), 2018),
#  ('United Republic of Tanzania', Decimal('33.65'), 2019),
#  ('United Republic of Tanzania', Decimal('33.65'), 2020),
#  ('Zambia', Decimal('33.65'), 2015),
#  ('Zambia', Decimal('33.65'), 2016),
#  ('Zambia', Decimal('9.00'), 2017),
#  ('Zambia', Decimal('5.00'), 2018),
#  ('Zambia', Decimal('6.00'), 2019),
#  ('Zambia', Decimal('6.00'), 2020),
#  ('Zimbabwe', Decimal('33.65'), 2015),
#  ('Zimbabwe', Decimal('33.65'), 2016),
#  ('Zimbabwe', Decimal('33.65'), 2017),
#  ('Zimbabwe', Decimal('33.65'), 2018),
#  ('Zimbabwe', Decimal('7.00'), 2019),
#  ('Zimbabwe', Decimal('33.65'), 2020)]

# %% [markdown]
# ### Task 4
#
# Now that we have the query constructed, let's create a VIEW of that query. Name the VIEW, `united_nations.Country_Unemployment_Rate`.

# %%
# %%sql
#
# CREATE VIEW united_nations.Country_Unemployment_Rate
# AS
# SELECT
#     Geo.Country_name,
#     IFNULL(Econ.Pct_unemployment, 33.65) AS Pct_unemployment_imputed,
#     Econ.Time_period
# FROM
#     Economic_indicators AS Econ
# JOIN
#     Geographic_location AS Geo
#         ON Econ.Country_name = Geo.Country_name
# WHERE
#     Geo.Region = 'Sub-Saharan Africa';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %% [markdown]
# ### Task 5
#
# Finally, let's have a look at the VIEW.

# %%
# %%sql
# SELECT
#     *
# FROM
#     Country_Unemployment_Rate
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 297 rows affected.
# [('Angola', Decimal('33.65'), 2015),
#  ('Angola', Decimal('33.65'), 2016),
#  ('Angola', Decimal('33.65'), 2017),
#  ('Angola', Decimal('33.65'), 2018),
#  ('Angola', Decimal('17.00'), 2019),
#  ('Angola', Decimal('33.65'), 2020),
#  ('Benin', Decimal('33.65'), 2015),
#  ('Benin', Decimal('33.65'), 2016),
#  ('Benin', Decimal('33.65'), 2017),
#  ('Benin', Decimal('1.00'), 2018),
#  ('Benin', Decimal('33.65'), 2019),
#  ('Benin', Decimal('33.65'), 2020),
#  ('Botswana', Decimal('33.65'), 2015),
#  ('Botswana', Decimal('33.65'), 2016),
#  ('Botswana', Decimal('33.65'), 2017),
#  ('Botswana', Decimal('33.65'), 2018),
#  ('Botswana', Decimal('20.00'), 2019),
#  ('Botswana', Decimal('21.00'), 2020),
#  ('Burkina Faso', Decimal('33.65'), 2015),
#  ('Burkina Faso', Decimal('33.65'), 2016),
#  ('Burkina Faso', Decimal('33.65'), 2017),
#  ('Burkina Faso', Decimal('5.00'), 2018),
#  ('Burkina Faso', Decimal('33.65'), 2019),
#  ('Burkina Faso', Decimal('33.65'), 2020),
#  ('Burundi', Decimal('33.65'), 2015),
#  ('Burundi', Decimal('33.65'), 2016),
#  ('Burundi', Decimal('33.65'), 2017),
#  ('Burundi', Decimal('33.65'), 2018),
#  ('Burundi', Decimal('33.65'), 2019),
#  ('Burundi', Decimal('1.00'), 2020),
#  ('Cabo Verde', Decimal('31.00'), 2015),
#  ('Cabo Verde', Decimal('33.65'), 2016),
#  ('Cabo Verde', Decimal('12.00'), 2017),
#  ('Cabo Verde', Decimal('12.00'), 2018),
#  ('Cabo Verde', Decimal('11.00'), 2019),
#  ('Cabo Verde', Decimal('33.65'), 2020),
#  ('Cameroon', Decimal('33.65'), 2015),
#  ('Cameroon', Decimal('33.65'), 2016),
#  ('Cameroon', Decimal('33.65'), 2017),
#  ('Cameroon', Decimal('33.65'), 2018),
#  ('Cameroon', Decimal('33.65'), 2019),
#  ('Cameroon', Decimal('33.65'), 2020),
#  ('Central African Republic', Decimal('33.65'), 2015),
#  ('Central African Republic', Decimal('33.65'), 2016),
#  ('Central African Republic', Decimal('33.65'), 2017),
#  ('Central African Republic', Decimal('33.65'), 2018),
#  ('Central African Republic', Decimal('33.65'), 2019),
#  ('Central African Republic', Decimal('33.65'), 2020),
#  ('Chad', Decimal('33.65'), 2015),
#  ('Chad', Decimal('33.65'), 2016),
#  ('Chad', Decimal('33.65'), 2017),
#  ('Chad', Decimal('1.00'), 2018),
#  ('Chad', Decimal('33.65'), 2019),
#  ('Chad', Decimal('33.65'), 2020),
#  ('Comoros', Decimal('33.65'), 2015),
#  ('Comoros', Decimal('33.65'), 2016),
#  ('Comoros', Decimal('33.65'), 2017),
#  ('Comoros', Decimal('33.65'), 2018),
#  ('Comoros', Decimal('33.65'), 2019),
#  ('Congo', Decimal('33.65'), 2015),
#  ('Congo', Decimal('33.65'), 2016),
#  ('Congo', Decimal('33.65'), 2017),
#  ('Congo', Decimal('33.65'), 2018),
#  ('Congo', Decimal('33.65'), 2019),
#  ('Congo', Decimal('33.65'), 2020),
#  ("Côte d'Ivoire", Decimal('33.65'), 2015),
#  ("Côte d'Ivoire", Decimal('33.65'), 2016),
#  ("Côte d'Ivoire", Decimal('33.65'), 2017),
#  ("Côte d'Ivoire", Decimal('33.65'), 2018),
#  ("Côte d'Ivoire", Decimal('33.65'), 2019),
#  ("Côte d'Ivoire", Decimal('33.65'), 2020),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2015),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2016),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2017),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2018),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2019),
#  ('Democratic Republic of the Congo', Decimal('33.65'), 2020),
#  ('Djibouti', Decimal('33.65'), 2015),
#  ('Djibouti', Decimal('33.65'), 2016),
#  ('Djibouti', Decimal('26.00'), 2017),
#  ('Djibouti', Decimal('33.65'), 2018),
#  ('Djibouti', Decimal('33.65'), 2019),
#  ('Djibouti', Decimal('33.65'), 2020),
#  ('Equatorial Guinea', Decimal('33.65'), 2015),
#  ('Equatorial Guinea', Decimal('33.65'), 2016),
#  ('Equatorial Guinea', Decimal('33.65'), 2017),
#  ('Eritrea', Decimal('33.65'), 2015),
#  ('Eritrea', Decimal('33.65'), 2016),
#  ('Eswatini', Decimal('33.65'), 2015),
#  ('Eswatini', Decimal('23.00'), 2016),
#  ('Eswatini', Decimal('33.65'), 2017),
#  ('Eswatini', Decimal('33.65'), 2018),
#  ('Eswatini', Decimal('33.65'), 2019),
#  ('Eswatini', Decimal('33.65'), 2020),
#  ('Ethiopia', Decimal('33.65'), 2015),
#  ('Ethiopia', Decimal('33.65'), 2016),
#  ('Ethiopia', Decimal('33.65'), 2017),
#  ('Ethiopia', Decimal('33.65'), 2018),
#  ('Ethiopia', Decimal('33.65'), 2019),
#  ('Ethiopia', Decimal('33.65'), 2020),
#  ('Gabon', Decimal('33.65'), 2015),
#  ('Gabon', Decimal('33.65'), 2016),
#  ('Gabon', Decimal('33.65'), 2017),
#  ('Gabon', Decimal('33.65'), 2018),
#  ('Gabon', Decimal('33.65'), 2019),
#  ('Gabon', Decimal('33.65'), 2020),
#  ('Gambia', Decimal('33.65'), 2015),
#  ('Gambia', Decimal('33.65'), 2016),
#  ('Gambia', Decimal('33.65'), 2017),
#  ('Gambia', Decimal('33.65'), 2018),
#  ('Gambia', Decimal('33.65'), 2019),
#  ('Gambia', Decimal('33.65'), 2020),
#  ('Ghana', Decimal('7.00'), 2015),
#  ('Ghana', Decimal('33.65'), 2016),
#  ('Ghana', Decimal('3.00'), 2017),
#  ('Ghana', Decimal('33.65'), 2018),
#  ('Ghana', Decimal('33.65'), 2019),
#  ('Ghana', Decimal('33.65'), 2020),
#  ('Guinea', Decimal('33.65'), 2015),
#  ('Guinea', Decimal('33.65'), 2016),
#  ('Guinea', Decimal('33.65'), 2017),
#  ('Guinea', Decimal('33.65'), 2018),
#  ('Guinea', Decimal('5.00'), 2019),
#  ('Guinea', Decimal('33.65'), 2020),
#  ('Guinea-Bissau', Decimal('33.65'), 2015),
#  ('Guinea-Bissau', Decimal('33.65'), 2016),
#  ('Guinea-Bissau', Decimal('33.65'), 2017),
#  ('Guinea-Bissau', Decimal('3.00'), 2018),
#  ('Guinea-Bissau', Decimal('33.65'), 2019),
#  ('Guinea-Bissau', Decimal('33.65'), 2020),
#  ('Kenya', Decimal('33.65'), 2015),
#  ('Kenya', Decimal('3.00'), 2016),
#  ('Kenya', Decimal('33.65'), 2017),
#  ('Kenya', Decimal('33.65'), 2018),
#  ('Kenya', Decimal('5.00'), 2019),
#  ('Kenya', Decimal('33.65'), 2020),
#  ('Lesotho', Decimal('33.65'), 2015),
#  ('Lesotho', Decimal('33.65'), 2016),
#  ('Lesotho', Decimal('33.65'), 2017),
#  ('Lesotho', Decimal('33.65'), 2018),
#  ('Lesotho', Decimal('17.00'), 2019),
#  ('Lesotho', Decimal('33.65'), 2020),
#  ('Liberia', Decimal('33.65'), 2015),
#  ('Liberia', Decimal('3.00'), 2016),
#  ('Liberia', Decimal('6.00'), 2017),
#  ('Liberia', Decimal('33.65'), 2018),
#  ('Liberia', Decimal('33.65'), 2019),
#  ('Liberia', Decimal('33.65'), 2020),
#  ('Madagascar', Decimal('2.00'), 2015),
#  ('Madagascar', Decimal('33.65'), 2016),
#  ('Madagascar', Decimal('33.65'), 2017),
#  ('Madagascar', Decimal('33.65'), 2018),
#  ('Madagascar', Decimal('33.65'), 2019),
#  ('Madagascar', Decimal('33.65'), 2020),
#  ('Malawi', Decimal('33.65'), 2015),
#  ('Malawi', Decimal('33.65'), 2016),
#  ('Malawi', Decimal('4.00'), 2017),
#  ('Malawi', Decimal('33.65'), 2018),
#  ('Malawi', Decimal('33.65'), 2019),
#  ('Malawi', Decimal('1.00'), 2020),
#  ('Mali', Decimal('8.00'), 2015),
#  ('Mali', Decimal('1.00'), 2016),
#  ('Mali', Decimal('7.00'), 2017),
#  ('Mali', Decimal('2.00'), 2018),
#  ('Mali', Decimal('33.65'), 2019),
#  ('Mali', Decimal('4.00'), 2020),
#  ('Mauritania', Decimal('33.65'), 2015),
#  ('Mauritania', Decimal('33.65'), 2016),
#  ('Mauritania', Decimal('10.00'), 2017),
#  ('Mauritania', Decimal('33.65'), 2018),
#  ('Mauritania', Decimal('10.00'), 2019),
#  ('Mauritania', Decimal('33.65'), 2020),
#  ('Mauritius', Decimal('7.00'), 2015),
#  ('Mauritius', Decimal('7.00'), 2016),
#  ('Mauritius', Decimal('7.00'), 2017),
#  ('Mauritius', Decimal('6.00'), 2018),
#  ('Mauritius', Decimal('6.00'), 2019),
#  ('Mauritius', Decimal('9.00'), 2020),
#  ('Mayotte', Decimal('33.65'), 2015),
#  ('Mayotte', Decimal('33.65'), 2016),
#  ('Mayotte', Decimal('33.65'), 2017),
#  ('Mayotte', Decimal('33.65'), 2018),
#  ('Mayotte', Decimal('33.65'), 2019),
#  ('Mayotte', Decimal('33.65'), 2020),
#  ('Mozambique', Decimal('3.00'), 2015),
#  ('Mozambique', Decimal('33.65'), 2016),
#  ('Mozambique', Decimal('33.65'), 2017),
#  ('Mozambique', Decimal('33.65'), 2018),
#  ('Mozambique', Decimal('33.65'), 2019),
#  ('Mozambique', Decimal('33.65'), 2020),
#  ('Namibia', Decimal('33.65'), 2015),
#  ('Namibia', Decimal('23.00'), 2016),
#  ('Namibia', Decimal('33.65'), 2017),
#  ('Namibia', Decimal('20.00'), 2018),
#  ('Namibia', Decimal('33.65'), 2019),
#  ('Namibia', Decimal('33.65'), 2020),
#  ('Niger', Decimal('33.65'), 2015),
#  ('Niger', Decimal('33.65'), 2016),
#  ('Niger', Decimal('8.00'), 2017),
#  ('Niger', Decimal('33.65'), 2018),
#  ('Niger', Decimal('33.65'), 2019),
#  ('Niger', Decimal('33.65'), 2020),
#  ('Nigeria', Decimal('4.00'), 2015),
#  ('Nigeria', Decimal('7.00'), 2016),
#  ('Nigeria', Decimal('8.00'), 2017),
#  ('Nigeria', Decimal('33.65'), 2018),
#  ('Nigeria', Decimal('11.00'), 2019),
#  ('Nigeria', Decimal('33.65'), 2020),
#  ('Réunion', Decimal('33.65'), 2015),
#  ('Réunion', Decimal('33.65'), 2016),
#  ('Réunion', Decimal('33.65'), 2017),
#  ('Réunion', Decimal('33.65'), 2018),
#  ('Réunion', Decimal('33.65'), 2019),
#  ('Réunion', Decimal('33.65'), 2020),
#  ('Rwanda', Decimal('33.65'), 2015),
#  ('Rwanda', Decimal('33.65'), 2016),
#  ('Rwanda', Decimal('12.00'), 2017),
#  ('Rwanda', Decimal('11.00'), 2018),
#  ('Rwanda', Decimal('11.00'), 2019),
#  ('Rwanda', Decimal('12.00'), 2020),
#  ('Saint Helena', Decimal('33.65'), 2015),
#  ('Saint Helena', Decimal('33.65'), 2016),
#  ('Saint Helena', Decimal('33.65'), 2017),
#  ('Saint Helena', Decimal('33.65'), 2018),
#  ('Saint Helena', Decimal('33.65'), 2019),
#  ('Saint Helena', Decimal('33.65'), 2020),
#  ('Sao Tome and Principe', Decimal('33.65'), 2015),
#  ('Sao Tome and Principe', Decimal('33.65'), 2016),
#  ('Sao Tome and Principe', Decimal('33.65'), 2017),
#  ('Sao Tome and Principe', Decimal('33.65'), 2018),
#  ('Sao Tome and Principe', Decimal('33.65'), 2019),
#  ('Sao Tome and Principe', Decimal('33.65'), 2020),
#  ('Senegal', Decimal('7.00'), 2015),
#  ('Senegal', Decimal('4.00'), 2016),
#  ('Senegal', Decimal('4.00'), 2017),
#  ('Senegal', Decimal('4.00'), 2018),
#  ('Senegal', Decimal('3.00'), 2019),
#  ('Senegal', Decimal('33.65'), 2020),
#  ('Seychelles', Decimal('4.00'), 2015),
#  ('Seychelles', Decimal('4.00'), 2016),
#  ('Seychelles', Decimal('4.00'), 2017),
#  ('Seychelles', Decimal('4.00'), 2018),
#  ('Seychelles', Decimal('3.00'), 2019),
#  ('Sierra Leone', Decimal('33.65'), 2015),
#  ('Sierra Leone', Decimal('33.65'), 2016),
#  ('Sierra Leone', Decimal('33.65'), 2017),
#  ('Sierra Leone', Decimal('3.00'), 2018),
#  ('Sierra Leone', Decimal('33.65'), 2019),
#  ('Sierra Leone', Decimal('33.65'), 2020),
#  ('Somalia', Decimal('33.65'), 2015),
#  ('Somalia', Decimal('33.65'), 2016),
#  ('Somalia', Decimal('33.65'), 2017),
#  ('Somalia', Decimal('33.65'), 2018),
#  ('Somalia', Decimal('19.00'), 2019),
#  ('Somalia', Decimal('33.65'), 2020),
#  ('South Africa', Decimal('23.00'), 2015),
#  ('South Africa', Decimal('24.00'), 2016),
#  ('South Africa', Decimal('24.00'), 2017),
#  ('South Africa', Decimal('24.00'), 2018),
#  ('South Africa', Decimal('26.00'), 2019),
#  ('South Africa', Decimal('24.00'), 2020),
#  ('South Sudan', Decimal('33.65'), 2015),
#  ('South Sudan', Decimal('33.65'), 2016),
#  ('South Sudan', Decimal('33.65'), 2017),
#  ('South Sudan', Decimal('33.65'), 2018),
#  ('South Sudan', Decimal('33.65'), 2019),
#  ('South Sudan', Decimal('33.65'), 2020),
#  ('Togo', Decimal('2.00'), 2015),
#  ('Togo', Decimal('33.65'), 2016),
#  ('Togo', Decimal('4.00'), 2017),
#  ('Togo', Decimal('33.65'), 2018),
#  ('Togo', Decimal('33.65'), 2019),
#  ('Togo', Decimal('33.65'), 2020),
#  ('Uganda', Decimal('33.65'), 2015),
#  ('Uganda', Decimal('33.65'), 2016),
#  ('Uganda', Decimal('4.00'), 2017),
#  ('Uganda', Decimal('33.65'), 2018),
#  ('Uganda', Decimal('33.65'), 2019),
#  ('Uganda', Decimal('33.65'), 2020),
#  ('United Republic of Tanzania', Decimal('33.65'), 2015),
#  ('United Republic of Tanzania', Decimal('33.65'), 2016),
#  ('United Republic of Tanzania', Decimal('33.65'), 2017),
#  ('United Republic of Tanzania', Decimal('33.65'), 2018),
#  ('United Republic of Tanzania', Decimal('33.65'), 2019),
#  ('United Republic of Tanzania', Decimal('33.65'), 2020),
#  ('Zambia', Decimal('33.65'), 2015),
#  ('Zambia', Decimal('33.65'), 2016),
#  ('Zambia', Decimal('9.00'), 2017),
#  ('Zambia', Decimal('5.00'), 2018),
#  ('Zambia', Decimal('6.00'), 2019),
#  ('Zambia', Decimal('6.00'), 2020),
#  ('Zimbabwe', Decimal('33.65'), 2015),
#  ('Zimbabwe', Decimal('33.65'), 2016),
#  ('Zimbabwe', Decimal('33.65'), 2017),
#  ('Zimbabwe', Decimal('33.65'), 2018),
#  ('Zimbabwe', Decimal('7.00'), 2019),
#  ('Zimbabwe', Decimal('33.65'), 2020)]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Task 1

# %%
# %%sql
#
# SELECT
#     loc.Country_name,
#     eco.Time_period,
#     eco.Pct_unemployment
# FROM
#     united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# ON eco.Country_name = loc.Country_name;
#
# # Use LIMIT if you think the results set will be too large

# %% [markdown]
# ### Task 2

# %%
# %%sql
#
# SELECT
#     loc.Country_name,
#     eco.Time_period,
#     eco.Pct_unemployment
# FROM
#     united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# ON eco.Country_name = loc.Country_name
# WHERE REGION = 'Sub-Saharan Africa';

# %% [markdown]
# ### Task 3

# %%
# %%sql
#
# SELECT
#     loc.Country_name,
#     eco.Time_period,
#     IFNULL (eco.Pct_unemployment,33.65) as Pct_unemployment_imputed
# FROM
#     united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# ON eco.Country_name = loc.Country_name
# WHERE REGION = 'Sub-Saharan Africa';

# %% [markdown]
# ### Task 4

# %%
# %%sql
#
# CREATE VIEW united_nations.Country_Unemployment_Rate
# AS
#
# SELECT
#     loc.Country_name,
#     eco.Time_period,
#     IFNULL (eco.Pct_unemployment,33.65) as PCT_unemployment_imputed
# FROM
#     united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# ON eco.Country_name = loc.Country_name
# WHERE REGION = 'Sub-Saharan Africa';

# %% [markdown]
# ### Task 5

# %%
# %%sql
#
# SELECT *
# FROM
#     united_nations.Country_unemployment_Rate
# LIMIT 10;

# %% [markdown]
# ## Summary

# %% [markdown]
# In this notebook, we created a join with the `Economic_Indicators` table and the `Geographical_Locations` table. This allowed us to filter our data by `Region`, specifically the `Sub-Saharan African` region. We then imputed the Null values in the `Pct_unemployment` column. Finally, we saved this complex query in a VIEW and named that VIEW `united_nations.Country_unemployment_Rate`.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
